# %%
import pydicom
import matplotlib.pyplot as plt

# %%
targetdir = '/home/r079a/Desktop/de-identification/dataset/images/manifest-1617826555824/\
Pseudo-PHI-DICOM-Data/292821506/07-13-2013-NA-XR CHEST AP PORTABLE for Douglas Davidson-46198/1001.000000-NA-37718'

# %%
print(targetdir)
# Out:
# /home/r079a/Desktop/de-identification/dataset/images/manifest-1617826555824/Pseudo-PHI-DICOM-Data/292821506/07-13-2013-NA-XR CHEST AP PORTABLE for Douglas Davidson-46198/1001.000000-NA-37718

# %%
from os import listdir
from os.path import isfile, join
from pathlib import Path

# %%
onlyfiles = [f for f in listdir(targetdir) if isfile(join(targetdir, f))]
print(onlyfiles)
# Out:
# ['1-1.dcm']

# %%
sampledcm = Path(targetdir,onlyfiles[0])

# %%
ds = pydicom.dcmread(sampledcm)

# %%
plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %%
import pandas as pd

# %%
metadatafile = '/home/r079a/Desktop/de-identification/dataset/images/manifest-1617826555824/metadata.csv'

samplemetadata = pd.read_csv(metadatafile)

# %%
samplemetadata.head()
# Out:
#                                      Series UID             Collection  \
# 0   2.25.22373700284337223907674770690654453238  Pseudo-PHI-DICOM-Data
# 1  2.25.159938781348401988370074200042204937718  Pseudo-PHI-DICOM-Data
# 2   2.25.16889725737787757262937018243711876598  Pseudo-PHI-DICOM-Data
# 3   2.25.45367868844278747809947145409050295798  Pseudo-PHI-DICOM-Data
# 4   2.25.30562807935945476104184698489410272758  Pseudo-PHI-DICOM-Data
#
#   3rd Party Analysis              Data Description URI  Subject ID  \
# 0                 NO  https://doi.org/10.7937/s17zr072   292821506
# 1                 NO  https://doi.org/10.7937/s17zr072   292821506
# 2                 NO  https://doi.org/10.7937/s17zr072  3642991663
# 3                 NO  https://doi.org/10.7937/s17zr072  3209648408
# 4                 NO  https://doi.org/10.7937/s17zr072  4025360156
#
#                                       Study UID  \
# 0  2.25.106461954783291641048254423668956446198
# 1  2.25.106461954783291641048254423668956446198
# 2  2.25.274128889631512605961383205193865870838
# 3  2.25.186760260011452398476108131496539831798
# 4  2.25.229096719175496207600372892792583208438
#
#                            Study Description  Study Date  \
# 0  XR CHEST AP PORTABLE for Douglas Davidson  07-13-2013
# 1  XR CHEST AP PORTABLE for Douglas Davidson  07-13-2013
# 2            PET-CT STUDY for Shelly Wallace  07-05-1961
# 3                                 CT UROGRAM  09-23-1999
# 4                            CT Urogram w 3D  10-25-1993
#
#           Series Description          Manufacturer Modality  \
# 0                        NaN  FUJIFILM Corporation       CR
# 1                        NaN  FUJIFILM Corporation       CR
# 2              PET-CT SERIES    GE MEDICAL SYSTEMS       PT
# 3  PARENCHYMAL PHASE Sep1999    GE MEDICAL SYSTEMS       CT
# 4                      NONE   FUJIFILM Corporation       CR
#
#                                SOP Class Name                SOP Class UID  \
# 0          Computed Radiography Image Storage    1.2.840.10008.5.1.4.1.1.1
# 1          Computed Radiography Image Storage    1.2.840.10008.5.1.4.1.1.1
# 2  Positron Emission Tomography Image Storage  1.2.840.10008.5.1.4.1.1.128
# 3                            CT Image Storage    1.2.840.10008.5.1.4.1.1.2
# 4          Computed Radiography Image Storage    1.2.840.10008.5.1.4.1.1.1
#
#    Number of Images File Size  \
# 0                 1   7.53 MB
# 1                 1   7.53 MB
# 2               174   6.63 MB
# 3               152  80.10 MB
# 4                 1   6.21 MB
#
#                                        File Location       Download Timestamp
# 0  ./Pseudo-PHI-DICOM-Data/292821506/07-13-2013-N...  2024-06-03T18:20:37.027
# 1  ./Pseudo-PHI-DICOM-Data/292821506/07-13-2013-N...  2024-06-03T18:20:38.616
# 2  ./Pseudo-PHI-DICOM-Data/3642991663/07-05-1961-...  2024-06-03T18:20:47.041
# 3  ./Pseudo-PHI-DICOM-Data/3209648408/09-23-1999-...  2024-06-03T18:20:55.924
# 4  ./Pseudo-PHI-DICOM-Data/4025360156/10-25-1993-...  2024-06-03T18:20:57.728

# %% [markdown]
# ### Map between Eval and Deidentified UIDs

# %%
import csv

uidmapfile = '/home/r079a/Desktop/de-identification/dataset/Pseudo-PHI-DICOM-Dataset-uid_crosswalk.csv'
eval_2_deid =  {}
deid_2_eval = {}

with open(uidmapfile, newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    linecount = 0
    for row in spamreader:
        if linecount == 0:
            linecount += 1
            continue
        eval_2_deid[row[0]] = row[1]
        deid_2_eval[row[1]] = row[0]
        linecount += 1

# %%
def load_metadata(filename: str):
    return pd.read_csv(filename)

def load_dicoms_from_path(dicompath: str):
    alldicompaths = [f for f in listdir(dicompath) if isfile(join(dicompath, f))]
    alldicoms = []
    for dcm in alldicompaths:
        dcmpath = Path(dicompath, dcm)
        ds = pydicom.dcmread(dcmpath)
        alldicoms.append(ds)
    return alldicoms

# %%
def load_series_by_index(metadatafile: str, seriesidx: int):
    metadata = load_metadata(metadatafile)
    assert seriesidx < len(metadata), f"Patient index greater than available patient dicoms. Available patients {len(metadata)}"
    
    target_row = metadata.loc[seriesidx]
    targetdcmdir = Path(Path(metadatafile).parent, str(target_row['File Location']))
    alldicoms = load_dicoms_from_path(targetdcmdir)
    
    return alldicoms, target_row.to_dict()

def get_series_index_from_id(metadatafile: str, seriesid: str):
    metadata_df = load_metadata(metadatafile)
    indexes = metadata_df[metadata_df['Series UID'] == seriesid].index.tolist()
    if len(indexes) == 0:
        return -1
    else:
        return indexes[0]
    

def display_dicoms_grid(dicoms: list, rows: int = 2, cols: int = 3):
    fig = plt.figure(figsize=(10,10))
    
    for idx, ds in enumerate(dicoms):
        if idx >= rows*cols:
            break
        fig.add_subplot(rows, cols, idx+1)
        plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

def display_dicom(ds):
    plt.imshow(ds.pixel_array, cmap=plt.cm.bone)

# %% [markdown]
# ### Explore Raw dicoms

# %%
TARGETSERIESIDX = 14

# %%
metadatafile = '/home/r079a/Desktop/de-identification/dataset/images/manifest-1617826555824/metadata.csv'

# %%
alldicoms, patientmetadata = load_series_by_index(metadatafile, seriesidx=TARGETSERIESIDX)

# %%
display_dicoms_grid(alldicoms)

# %%
sampleds = alldicoms[0]

# %%
display_dicom(sampleds)

# %%
for element in sampleds:
    print(element)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'LOCALIZER']
# (0008, 0012) Instance Creation Date              DA: '19990908'
# (0008, 0013) Instance Creation Time              TM: '133228'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.24988633710936769796383448125889166838
# (0008, 0020) Study Date                          DA: '19990908'
# (0008, 0021) Series Date                         DA: '19990908'
# (0008, 0022) Acquisition Date                    DA: '19990908'
# (0008, 0023) Content Date                        DA: '19990908'
# (0008, 0030) Study Time                          TM: '133157'
# (0008, 0031) Series Time                         TM: '133157'
# (0008, 0032) Acquisition Time                    TM: '133221.484357'
# (0008, 0033) Content Time                        TM: '133228'
# (0008, 0050) Accession Number                    SH: '664B2583'
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0080) Institution Name                    LO: 'Williams-Johnson Medical Center'
# (0008, 0081) Institution Address                 ST: 'Unit 4899 Box 3625 DPO AP 93015'
# (0008, 0090) Referring Physician's Name          PN: 'THOMAS^CHRISTOPHER'
# (0008, 1030) Study Description                   LO: 'FORFILE CT CH/AB/PEL - CD for 8155012288'
# (0008, 1032) Procedure Code Sequence             SQ: <Sequence, length 1>
# (0008, 103e) Series Description                  LO: 'SCOUT'
# (0008, 1050) Performing Physician's Name         PN: 'SMITH^MEGHAN'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0008, 1110) Referenced Study Sequence           SQ: <Sequence, length 1>
# (0009, 0010) Private Creator                     LO: 'GEMS_IDEN_01'
# (0009, 0011) Private Creator                     LO: 'GEIIS'
# (0010, 0010) Patient's Name                      PN: 'HOOVER^RODNEY'
# (0010, 0020) Patient ID                          LO: '8155012288'
# (0010, 0030) Patient's Birth Date                DA: '19420728'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '057Y'
# (0010, 21b0) Additional Patient History          LT: 'BLADDER TUMORS'
# (0011, 0010) Private Creator                     LO: 'DLX_PATNT_01'
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'Pseudo-PHI-DICOM-Data'
# (0013, 1013) Private tag data                    LO: '87009668'
# (0018, 0015) Body Part Examined                  CS: 'BLADDER'
# (0018, 0022) Scan Options                        CS: 'SCOUT MODE'
# (0018, 0050) Slice Thickness                     DS: '660.636308'
# (0018, 0060) KVP                                 DS: '80.0'
# (0018, 0088) Spacing Between Slices              DS: '10.0'
# (0018, 0090) Data Collection Diameter            DS: '500.0'
# (0018, 1020) Software Versions                   LO: '09MW08.11'
# (0018, 1030) Protocol Name                       LO: '5.10 WALL  CHEST ABDOMEN PELVIS WITH CONTRAST'
# (0018, 1100) Reconstruction Diameter             DS: None
# (0018, 1110) Distance Source to Detector         DS: '949.147'
# (0018, 1111) Distance Source to Patient          DS: '541.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1130) Table Height                        DS: '151.0'
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '6676'
# (0018, 1151) X-Ray Tube Current                  IS: '10'
# (0018, 1152) Exposure                            IS: '66'
# (0018, 1160) Filter Type                         SH: 'BODY FILTER'
# (0018, 1170) Generator Power                     IS: '800'
# (0018, 1190) Focal Spot(s)                       DS: '0.7'
# (0018, 1210) Convolution Kernel                  SH: 'STANDARD'
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0019, 0010) Private Creator                     LO: 'GEMS_ACQU_01'
# (0020, 000d) Study Instance UID                  UI: 2.25.27157770470249991394859340106290544118
# (0020, 000e) Series Instance UID                 UI: 2.25.138715083337522222202549203339113512438
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: [-0.000, 265.000, 60.000]
# (0020, 0037) Image Orientation (Patient)         DS: [0.000000, -1.000000, 0.000000, 0.000000, 0.000000, -1.000000]
# (0020, 0052) Frame of Reference UID              UI: 2.25.98585402628942974234872714721995898358
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '60.0'
# (0021, 0010) Private Creator                     LO: 'GEMS_RELA_01'
# (0023, 0010) Private Creator                     LO: 'GEMS_STDY_01'
# (0027, 0010) Private Creator                     LO: 'GEMS_IMAG_01'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1211
# (0028, 0011) Columns                             US: 888
# (0028, 0030) Pixel Spacing                       DS: [0.545455, 0.596847]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '50.0'
# (0028, 1051) Window Width                        DS: '500.0'
# (0028, 1052) Rescale Intercept                   DS: '-1024.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0244) Performed Procedure Step Start Date DA: '19990908'
# (0040, 0245) Performed Procedure Step Start Time TM: '133157'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'C/A/P C'
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (0043, 0010) Private Creator                     LO: 'GEMS_PARM_01'
# (0045, 0010) Private Creator                     LO: 'GEMS_HELIOS_01'
# (0053, 0010) Private Creator                     LO: 'GEHC_CT_ADVAPP_001'
# (0903, 0010) Private Creator                     LO: 'GEIIS PACS'
# (0905, 0010) Private Creator                     LO: 'GEIIS'
# (7fd1, 0010) Private Creator                     LO: 'GEIIS'
# (7fe0, 0010) Pixel Data                          OW: Array of 2150736 elements

# %%
from pprint import pprint

pprint(patientmetadata)
# Out:
# {'3rd Party Analysis': 'NO',
#  'Collection': 'Pseudo-PHI-DICOM-Data',
#  'Data Description URI': 'https://doi.org/10.7937/s17zr072',
#  'Download Timestamp': '2024-06-03T18:21:49.137',
#  'File Location': './Pseudo-PHI-DICOM-Data/8155012288/09-08-1999-NA-FORFILE CT '
#                   'CHABPEL - CD for 8155012288-44118/1.000000-SCOUT-12438',
#  'File Size': '4.39 MB',
#  'Manufacturer': 'GE MEDICAL SYSTEMS',
#  'Modality': 'CT',
#  'Number of Images': 2,
#  'SOP Class Name': 'CT Image Storage',
#  'SOP Class UID': '1.2.840.10008.5.1.4.1.1.2',
#  'Series Description': 'SCOUT',
#  'Series UID': '2.25.138715083337522222202549203339113512438',
#  'Study Date': '09-08-1999',
#  'Study Description': 'FORFILE CT CHABPEL - CD for 8155012288',
#  'Study UID': '2.25.27157770470249991394859340106290544118',
#  'Subject ID': 8155012288}

# %% [markdown]
# ### Explore deidentified Dicoms

# %%
deidmetafile = '/home/r079a/Desktop/de-identification/dataset/images-2/manifest-1617826161202/metadata.csv'

# %%
deid_series = eval_2_deid[patientmetadata['Series UID']]
deid_idx = get_series_index_from_id(deidmetafile, deid_series)

deid_dicoms, deid_pateintmetadata = load_series_by_index(deidmetafile, seriesidx=deid_idx)

# %%
display_dicom(deid_dicoms[0])

# %%
for element in deid_dicoms[0]:
    print(element)
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'LOCALIZER']
# (0008, 0012) Instance Creation Date              DA: '19890821'
# (0008, 0013) Instance Creation Time              TM: '133228'
# (0008, 0016) SOP Class UID                       UI: CT Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.155579066617036611891254696954
# (0008, 0020) Study Date                          DA: '19890821'
# (0008, 0021) Series Date                         DA: '19890821'
# (0008, 0022) Acquisition Date                    DA: '19890821'
# (0008, 0023) Content Date                        DA: '19890821'
# (0008, 0030) Study Time                          TM: '133157'
# (0008, 0031) Series Time                         TM: '133157'
# (0008, 0032) Acquisition Time                    TM: '133221.484357'
# (0008, 0033) Content Time                        TM: '133228'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CT'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 1030) Study Description                   LO: 'CT CH/AB/PEL'
# (0008, 1032) Procedure Code Sequence             SQ: <Sequence, length 1>
# (0008, 103e) Series Description                  LO: 'SCOUT'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0008, 1110) Referenced Study Sequence           SQ: <Sequence, length 1>
# (0009, 0010) Private Creator                     LO: 'GEMS_IDEN_01'
# (0009, 0011) Private Creator                     LO: 'GEIIS'
# (0010, 0010) Patient's Name                      PN: 'Pseudo-PHI-014'
# (0010, 0020) Patient ID                          LO: 'Pseudo-PHI-014'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '057Y'
# (0010, 21b0) Additional Patient History          LT: 'BLADDER TUMORS'
# (0011, 0010) Private Creator                     LO: 'DLX_PATNT_01'
# (0012, 0050) Clinical Trial Time Point ID        LO: ''
# (0012, 0062) Patient Identity Removed            CS: 'YES'
# (0012, 0063) De-identification Method            LO: 'Per DICOM PS 3.15 AnnexE. Details in 0012,0064'
# (0012, 0064) De-identification Method Code Seque SQ: <Sequence, length 8>
# (0013, 0010) Private Creator                     LO: 'CTP'
# (0013, 1010) Private tag data                    LO: 'Pseudo-PHI-DICOM-Data'
# (0013, 1013) Private tag data                    LO: '87009668'
# (0018, 0015) Body Part Examined                  CS: 'BLADDER'
# (0018, 0022) Scan Options                        CS: 'SCOUT MODE'
# (0018, 0050) Slice Thickness                     DS: '660.636308'
# (0018, 0060) KVP                                 DS: '80.0'
# (0018, 0088) Spacing Between Slices              DS: '10.0'
# (0018, 0090) Data Collection Diameter            DS: '500.0'
# (0018, 1020) Software Versions                   LO: '09MW08.11'
# (0018, 1030) Protocol Name                       LO: '5.10 WALL  CHEST ABDOMEN PELVIS WITH CONTRAST'
# (0018, 1100) Reconstruction Diameter             DS: None
# (0018, 1110) Distance Source to Detector         DS: '949.147'
# (0018, 1111) Distance Source to Patient          DS: '541.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1130) Table Height                        DS: '151.0'
# (0018, 1140) Rotation Direction                  CS: 'CW'
# (0018, 1150) Exposure Time                       IS: '6676'
# (0018, 1151) X-Ray Tube Current                  IS: '10'
# (0018, 1152) Exposure                            IS: '66'
# (0018, 1160) Filter Type                         SH: 'BODY FILTER'
# (0018, 1170) Generator Power                     IS: '800'
# (0018, 1190) Focal Spot(s)                       DS: '0.7'
# (0018, 1210) Convolution Kernel                  SH: 'STANDARD'
# (0018, 5100) Patient Position                    CS: 'FFS'
# (0019, 0010) Private Creator                     LO: 'GEMS_ACQU_01'
# (0020, 000d) Study Instance UID                  UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.747640813546474991688004814833
# (0020, 000e) Series Instance UID                 UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.153468882187660986881241722199
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0012) Acquisition Number                  IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0032) Image Position (Patient)            DS: [-0.000, 265.000, 60.000]
# (0020, 0037) Image Orientation (Patient)         DS: [0.000000, -1.000000, 0.000000, 0.000000, 0.000000, -1.000000]
# (0020, 0052) Frame of Reference UID              UI: 1.3.6.1.4.1.14519.5.2.1.8700.9668.206986332791699863086881399302
# (0020, 1040) Position Reference Indicator        LO: 'SN'
# (0020, 1041) Slice Location                      DS: '60.0'
# (0021, 0010) Private Creator                     LO: 'GEMS_RELA_01'
# (0023, 0010) Private Creator                     LO: 'GEMS_STDY_01'
# (0027, 0010) Private Creator                     LO: 'GEMS_IMAG_01'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1211
# (0028, 0011) Columns                             US: 888
# (0028, 0030) Pixel Spacing                       DS: [0.545455, 0.596847]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0303) Longitudinal Temporal Information M CS: 'MODIFIED'
# (0028, 1050) Window Center                       DS: '50.0'
# (0028, 1051) Window Width                        DS: '500.0'
# (0028, 1052) Rescale Intercept                   DS: '-1024.0'
# (0028, 1053) Rescale Slope                       DS: '1.0'
# (0028, 1054) Rescale Type                        LO: 'HU'
# (0040, 0244) Performed Procedure Step Start Date DA: '19890821'
# (0040, 0245) Performed Procedure Step Start Time TM: '133157'
# (0040, 0254) Performed Procedure Step Descriptio LO: 'C/A/P C'
# (0040, 2017) Filler Order Number / Imaging Servi LO: ''
# (0043, 0010) Private Creator                     LO: 'GEMS_PARM_01'
# (0045, 0010) Private Creator                     LO: 'GEMS_HELIOS_01'
# (0053, 0010) Private Creator                     LO: 'GEHC_CT_ADVAPP_001'
# (0903, 0010) Private Creator                     LO: 'GEIIS PACS'
# (0905, 0010) Private Creator                     LO: 'GEIIS'
# (7fd1, 0010) Private Creator                     LO: 'GEIIS'
# (7fe0, 0010) Pixel Data                          OW: Array of 2150736 elements

# %%
pprint(deid_pateintmetadata)
# Out:
# {'3rd Party Analysis': 'NO',
#  'Collection': 'Pseudo-PHI-DICOM-Data',
#  'Data Description URI': 'https://doi.org/10.7937/s17zr072',
#  'Download Timestamp': '2024-06-03T18:26:07.527',
#  'File Location': './Pseudo-PHI-DICOM-Data/Pseudo-PHI-014/08-21-1989-NA-CT '
#                   'CHABPEL-14833/1.000000-SCOUT-22199',
#  'File Size': '4.39 MB',
#  'Manufacturer': 'GE MEDICAL SYSTEMS',
#  'Modality': 'CT',
#  'Number of Images': 2,
#  'SOP Class Name': 'CT Image Storage',
#  'SOP Class UID': '1.2.840.10008.5.1.4.1.1.2',
#  'Series Description': 'SCOUT',
#  'Series UID': '1.3.6.1.4.1.14519.5.2.1.8700.9668.153468882187660986881241722199',
#  'Study Date': '08-21-1989',
#  'Study Description': 'CT CHABPEL',
#  'Study UID': '1.3.6.1.4.1.14519.5.2.1.8700.9668.747640813546474991688004814833',
#  'Subject ID': 'Pseudo-PHI-014'}
