# %%
import pandas as pd
from pprint import pprint

# %%
# report_path = '/home/r079a/Desktop/de-identification/dataset/midi-validation-data/output_data_tcia_private_tags_06/discrepancy_report_participant.csv'
report_path = '/home/r079a/Desktop/de-identification/dataset/midi-test-data/output_data/discrepancy_report_participant.csv'

# %%
report_df = pd.read_csv(report_path)

# %%
report_df
# Out:
#         index  check_passed  check_score         tag_ds              tag_name  \
# 0       26676             0     0.666667  <(0008,103e)>  <Series Description>
# 1       28580             0     0.666667  <(0008,103e)>  <Series Description>
# 2       38526             0     0.000000  <(0008,1030)>   <Study Description>
# 3       38761             0     0.000000  <(0008,1030)>   <Study Description>
# 4       48036             0     0.000000  <(0008,1030)>   <Study Description>
# ...       ...           ...          ...            ...                   ...
# 8671  8035298             0     0.750000  <(0018,1030)>       <Protocol Name>
# 8672  8035443             0     0.750000  <(0018,1030)>       <Protocol Name>
# 8673  8035588             0     0.750000  <(0018,1030)>       <Protocol Name>
# 8674  8035733             0     0.750000  <(0018,1030)>       <Protocol Name>
# 8675  8035878             0     0.750000  <(0018,1030)>       <Protocol Name>
#
#                       file_value  \
# 0             <^I0, Gated, 0.0%>
# 1     <P4^^S108^I0, Gated, 0.0%>
# 2                             <>
# 3                             <>
# 4                             <>
# ...                          ...
# 8671   <4.6 COLONOSCOPY (ACRIN)>
# 8672   <4.6 COLONOSCOPY (ACRIN)>
# 8673   <4.6 COLONOSCOPY (ACRIN)>
# 8674   <4.6 COLONOSCOPY (ACRIN)>
# 8675   <4.6 COLONOSCOPY (ACRIN)>
#
#                                            answer_value           action  \
# 0               <P4^P101^S108^I0, Gated, 0.0% 20140321>  <text_retained>
# 1               <P4^P101^S108^I0, Gated, 0.0% 20140321>  <text_retained>
# 2                                         <p4 20190619>  <text_retained>
# 3                                         <p4 20190619>  <text_retained>
# 4                                         <p4 20190619>  <text_retained>
# ...                                                 ...              ...
# 8671  <4.6 COLONOSCOPY (ACRIN) DR.IYER for Nicholas ...  <text_retained>
# 8672  <4.6 COLONOSCOPY (ACRIN) DR.IYER for Nicholas ...  <text_retained>
# 8673  <4.6 COLONOSCOPY (ACRIN) DR.IYER for Nicholas ...  <text_retained>
# 8674  <4.6 COLONOSCOPY (ACRIN) DR.IYER for Nicholas ...  <text_retained>
# 8675  <4.6 COLONOSCOPY (ACRIN) DR.IYER for Nicholas ...  <text_retained>
#
#                             action_text category      subcategory modality  \
# 0        <P4^P101^S108^I0, Gated, 0.0%>     tcia  TCIA-P15-DESC-C     <CT>
# 1        <P4^P101^S108^I0, Gated, 0.0%>     tcia  TCIA-P15-DESC-C     <CT>
# 2                                  <p4>     tcia  TCIA-P15-DESC-C     <CT>
# 3                                  <p4>     tcia  TCIA-P15-DESC-C     <CT>
# 4                                  <p4>     tcia  TCIA-P15-DESC-C     <CT>
# ...                                 ...      ...              ...      ...
# 8671  <4.6 COLONOSCOPY (ACRIN) DR.IYER>     tcia  TCIA-P15-DESC-C     <CT>
# 8672  <4.6 COLONOSCOPY (ACRIN) DR.IYER>     tcia  TCIA-P15-DESC-C     <CT>
# 8673  <4.6 COLONOSCOPY (ACRIN) DR.IYER>     tcia  TCIA-P15-DESC-C     <CT>
# 8674  <4.6 COLONOSCOPY (ACRIN) DR.IYER>     tcia  TCIA-P15-DESC-C     <CT>
# 8675  <4.6 COLONOSCOPY (ACRIN) DR.IYER>     tcia  TCIA-P15-DESC-C     <CT>
#
#                             class           patient  \
# 0     <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-002>
# 1     <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-002>
# 2     <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-002>
# 3     <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-002>
# 4     <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-002>
# ...                           ...               ...
# 8671  <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-322>
# 8672  <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-322>
# 8673  <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-322>
# 8674  <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-322>
# 8675  <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-322>
#
#                                                   study  \
# 0     <1.2.826.0.1.3680043.8.498.8849318224334599931...
# 1     <1.2.826.0.1.3680043.8.498.8849318224334599931...
# 2     <1.2.826.0.1.3680043.8.498.9913898290958110028...
# 3     <1.2.826.0.1.3680043.8.498.9913898290958110028...
# 4     <1.2.826.0.1.3680043.8.498.9913898290958110028...
# ...                                                 ...
# 8671  <1.2.826.0.1.3680043.8.498.5829007931145690492...
# 8672  <1.2.826.0.1.3680043.8.498.5829007931145690492...
# 8673  <1.2.826.0.1.3680043.8.498.5829007931145690492...
# 8674  <1.2.826.0.1.3680043.8.498.5829007931145690492...
# 8675  <1.2.826.0.1.3680043.8.498.5829007931145690492...
#
#                                                  series  \
# 0     <1.2.826.0.1.3680043.8.498.9781346443622077721...
# 1     <1.2.826.0.1.3680043.8.498.9781346443622077721...
# 2     <1.2.826.0.1.3680043.8.498.1400684307842597423...
# 3     <1.2.826.0.1.3680043.8.498.1400684307842597423...
# 4     <1.2.826.0.1.3680043.8.498.1400684307842597423...
# ...                                                 ...
# 8671  <1.2.826.0.1.3680043.8.498.6678047076865490237...
# 8672  <1.2.826.0.1.3680043.8.498.6678047076865490237...
# 8673  <1.2.826.0.1.3680043.8.498.6678047076865490237...
# 8674  <1.2.826.0.1.3680043.8.498.6678047076865490237...
# 8675  <1.2.826.0.1.3680043.8.498.6678047076865490237...
#
#                                                instance  file_name
# 0     <1.2.826.0.1.3680043.8.498.1269513511005866172...        NaN
# 1     <1.2.826.0.1.3680043.8.498.1387071203237797062...        NaN
# 2     <1.2.826.0.1.3680043.8.498.1169117305742646349...        NaN
# 3     <1.2.826.0.1.3680043.8.498.1005680162770048198...        NaN
# 4     <1.2.826.0.1.3680043.8.498.1135099578331262406...        NaN
# ...                                                 ...        ...
# 8671  <1.2.826.0.1.3680043.8.498.8180104851235192273...        NaN
# 8672  <1.2.826.0.1.3680043.8.498.1531641893573396120...        NaN
# 8673  <1.2.826.0.1.3680043.8.498.1088999776723597031...        NaN
# 8674  <1.2.826.0.1.3680043.8.498.1095447903538858271...        NaN
# 8675  <1.2.826.0.1.3680043.8.498.1172748157330959056...        NaN
#
# [8676 rows x 18 columns]

# %%
report_df['tag_name'].value_counts().head(100)
# Out:
# tag_name
# <Protocol Name>                                962
# <Series Description>                           908
# <Study Description>                            709
# <Medical Alerts>                               661
# <Additional Patient History>                   510
# <Private Creator>                              409
# <Requested Procedure Description>              278
# <Derivation Description>                       256
# <[Unknown]>                                    230
# <[SFOV Type]>                                  201
# <[PET tpluse_frame_id]>                        182
# <Contrast/Bolus Agent>                         171
# <Study Comments>                               132
# <[Vma clip]>                                   119
# <Performed Procedure Step Description>         117
# <Image Type>                                   101
# <Referenced SOP Class UID>                      96
# <[Start time(secs) in first axial]>             90
# <[Mean Z error]>                                82
# <[Window value]>                                82
# <[X-ray chain]>                                 82
# <[Trigger on position]>                         82
# <[Degree of rotation]>                          82
# <[Start scan to X-ray on delay]>                82
# <[Duration of X-ray on]>                        82
# <[Z smoothing Factor]>                          82
# <[Macro width at ISO Center]>                   82
# <[DAS gain]>                                    82
# <[Maximum Offset Value]>                        82
# <[Sigma Row number]>                            82
# <[Scan Start Location]>                         82
# <[Z tracking Error]>                            82
# <[Minimum DAS value]>                           82
# <[Scan End Location]>                           82
# <[Center A coord of plane image]>               82
# <[Normal S coord]>                              82
# <[Normal R coord]>                              82
# <[Center S coord of plane image]>               82
# <[Center R coord of plane image]>               82
# <[Biopsy ref location]>                         82
# <[Biopsy T location]>                           82
# <[Number of triggers]>                          82
# <[Tube Azimuth [degree]]>                       82
# <[Detector Channel]>                            82
# <[Normal A coord]>                              82
# <Referenced File ID>                            64
# <[Number of overranges]>                        61
# <Presentation LUT Shape>                        39
# <Presentation Intent Type>                      36
# <Comments on the Performed Procedure Step>      32
# <Text Value>                                    23
# <Image Comments>                                20
# <Image Laterality>                              10
# <Acquisition Device Processing Description>      3
# <Burned In Annotation>                           2
# <Pixel Intensity Relationship>                   2
# <Rescale Type>                                   2
# <Scheduled Procedure Step Description>           1
# <Reason for the Imaging Service Request>         1
# Name: count, dtype: int64

# %% [markdown]
# #### Priority List:
#
# * `<[Actual series data time stamp]>` covered
# * `<Clinical Trial Sponsor Name>`, // need to verify if it required in custom rules
# * `<Scheduled Procedure Step ID>`, // need to verify if it is required in custom rules
# * `<[Suite id]>` // Private tags needs to search with creators
# * `<Mapping Resource UID>` // Covered, added to custom rules
# * `<Code Value>` // Covered, by only checking element with Date(Time)? in its name
# * `<Requested Procedure Comments>` // MRI BREAST getting removed
# * `<KVP>` // not present in the original dataset
# * `<Acquisition Number> ` // not present in the original dataset
# * `<Referenced SOP Class UID>` // tag not present in the original dataset
# * `<Position Reference Indicator>` // tag not present in the original dataset
# * `<Presentation Intent Type>` // Tag not present in the original dataset
# * `<Presentation LUT Shape>` // Tag not present in the original dataset

# %%
report_df[(report_df['patient'] == '<Pseudo-PHI-072>') & (report_df['file_name'] == '<00000039.dcm>')]
# Out:
# Empty DataFrame
# Columns: [index, check_passed, check_score, tag_ds, tag_name, file_value, answer_value, action, action_text, category, subcategory, modality, class, patient, study, series, instance, file_name]
# Index: []

# %%
report_df[(report_df['tag_name'] == '<Presentation LUT Shape>')]
# Out:
#         index  check_passed  check_score         tag_ds  \
# 1219   907704             0          0.0  <(2050,0020)>
# 1221   907858             0          0.0  <(2050,0020)>
# 1223   908012             0          0.0  <(2050,0020)>
# 1226   908741             0          0.0  <(2050,0020)>
# 1278  1441781             0          0.0  <(2050,0020)>
# 1280  1441940             0          0.0  <(2050,0020)>
# 1448  1487234             0          0.0  <(2050,0020)>
# 1863  1684036             0          0.0  <(2050,0020)>
# 2104  1768987             0          0.0  <(2050,0020)>
# 2107  1769147             0          0.0  <(2050,0020)>
# 2114  1821194             0          0.0  <(2050,0020)>
# 2116  1857857             0          0.0  <(2050,0020)>
# 2118  1885079             0          0.0  <(2050,0020)>
# 2120  1885233             0          0.0  <(2050,0020)>
# 2698  2097828             0          0.0  <(2050,0020)>
# 5944  2914394             0          0.0  <(2050,0020)>
# 5946  2914547             0          0.0  <(2050,0020)>
# 6088  3129775             0          0.0  <(2050,0020)>
# 6219  4221759             0          0.0  <(2050,0020)>
# 6272  4496393             0          0.0  <(2050,0020)>
# 6274  4496547             0          0.0  <(2050,0020)>
# 6300  4513192             0          0.0  <(2050,0020)>
# 6302  4513347             0          0.0  <(2050,0020)>
# 6922  5217945             0          0.0  <(2050,0020)>
# 6928  5218080             0          0.0  <(2050,0020)>
# 6955  5233203             0          0.0  <(2050,0020)>
# 7043  5291371             0          0.0  <(2050,0020)>
# 7045  5291534             0          0.0  <(2050,0020)>
# 7365  6120711             0          0.0  <(2050,0020)>
# 7379  6140598             0          0.0  <(2050,0020)>
# 7382  6140752             0          0.0  <(2050,0020)>
# 7385  6140908             0          0.0  <(2050,0020)>
# 7472  6201198             0          0.0  <(2050,0020)>
# 7509  6824774             0          0.0  <(2050,0020)>
# 7971  7524444             0          0.0  <(2050,0020)>
# 8117  7597769             0          0.0  <(2050,0020)>
# 8119  7597912             0          0.0  <(2050,0020)>
# 8143  7799205             0          0.0  <(2050,0020)>
# 8146  7799360             0          0.0  <(2050,0020)>
#
#                       tag_name file_value answer_value          action  \
# 1219  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 1221  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 1223  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 1226  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 1278  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 1280  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 1448  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 1863  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 2104  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 2107  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 2114  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 2116  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 2118  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 2120  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 2698  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 5944  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 5946  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6088  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6219  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6272  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6274  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6300  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6302  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6922  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6928  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 6955  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7043  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7045  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7365  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7379  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7382  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7385  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7472  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7509  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 7971  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 8117  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 8119  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 8143  <Presentation LUT Shape>         <>          NaN  <text_notnull>
# 8146  <Presentation LUT Shape>         <>          NaN  <text_notnull>
#
#      action_text category  subcategory modality  \
# 1219         NaN    dicom  DICOM-IOD-1     <DX>
# 1221         NaN    dicom  DICOM-IOD-1     <DX>
# 1223         NaN    dicom  DICOM-IOD-1     <DX>
# 1226         NaN    dicom  DICOM-IOD-1     <DX>
# 1278         NaN    dicom  DICOM-IOD-1     <DX>
# 1280         NaN    dicom  DICOM-IOD-1     <DX>
# 1448         NaN    dicom  DICOM-IOD-1     <DX>
# 1863         NaN    dicom  DICOM-IOD-1     <DX>
# 2104         NaN    dicom  DICOM-IOD-1     <DX>
# 2107         NaN    dicom  DICOM-IOD-1     <DX>
# 2114         NaN    dicom  DICOM-IOD-1     <DX>
# 2116         NaN    dicom  DICOM-IOD-1     <DX>
# 2118         NaN    dicom  DICOM-IOD-1     <DX>
# 2120         NaN    dicom  DICOM-IOD-1     <DX>
# 2698         NaN    dicom  DICOM-IOD-1     <DX>
# 5944         NaN    dicom  DICOM-IOD-1     <DX>
# 5946         NaN    dicom  DICOM-IOD-1     <DX>
# 6088         NaN    dicom  DICOM-IOD-1     <DX>
# 6219         NaN    dicom  DICOM-IOD-1     <DX>
# 6272         NaN    dicom  DICOM-IOD-1     <DX>
# 6274         NaN    dicom  DICOM-IOD-1     <DX>
# 6300         NaN    dicom  DICOM-IOD-1     <DX>
# 6302         NaN    dicom  DICOM-IOD-1     <DX>
# 6922         NaN    dicom  DICOM-IOD-1     <DX>
# 6928         NaN    dicom  DICOM-IOD-1     <DX>
# 6955         NaN    dicom  DICOM-IOD-1     <DX>
# 7043         NaN    dicom  DICOM-IOD-1     <DX>
# 7045         NaN    dicom  DICOM-IOD-1     <DX>
# 7365         NaN    dicom  DICOM-IOD-1     <DX>
# 7379         NaN    dicom  DICOM-IOD-1     <DX>
# 7382         NaN    dicom  DICOM-IOD-1     <DX>
# 7385         NaN    dicom  DICOM-IOD-1     <DX>
# 7472         NaN    dicom  DICOM-IOD-1     <DX>
# 7509         NaN    dicom  DICOM-IOD-1     <DX>
# 7971         NaN    dicom  DICOM-IOD-1     <DX>
# 8117         NaN    dicom  DICOM-IOD-1     <DX>
# 8119         NaN    dicom  DICOM-IOD-1     <DX>
# 8143         NaN    dicom  DICOM-IOD-1     <DX>
# 8146         NaN    dicom  DICOM-IOD-1     <DX>
#
#                               class           patient  \
# 1219  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-036>
# 1221  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-036>
# 1223  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-037>
# 1226  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-042>
# 1278  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-056>
# 1280  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-056>
# 1448  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-059>
# 1863  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-074>
# 2104  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-083>
# 2107  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-083>
# 2114  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-085>
# 2116  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-093>
# 2118  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-097>
# 2120  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-097>
# 2698  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-109>
# 5944  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-158>
# 5946  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-158>
# 6088  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-171>
# 6219  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-189>
# 6272  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-219>
# 6274  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-219>
# 6300  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-215>
# 6302  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-215>
# 6922  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-243>
# 6928  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-243>
# 6955  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-247>
# 7043  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-262>
# 7045  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-262>
# 7365  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-279>
# 7379  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-286>
# 7382  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-286>
# 7385  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-287>
# 7472  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-275>
# 7509  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-291>
# 7971  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-299>
# 8117  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-301>
# 8119  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-302>
# 8143  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-307>
# 8146  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-307>
#
#                                                   study  \
# 1219  <1.2.826.0.1.3680043.8.498.3061495225920572052...
# 1221  <1.2.826.0.1.3680043.8.498.3061495225920572052...
# 1223  <1.2.826.0.1.3680043.8.498.4621352056282270819...
# 1226  <1.2.826.0.1.3680043.8.498.1170958104253550093...
# 1278  <1.2.826.0.1.3680043.8.498.1167795730387754662...
# 1280  <1.2.826.0.1.3680043.8.498.1167795730387754662...
# 1448  <1.2.826.0.1.3680043.8.498.1097250031717689706...
# 1863  <1.2.826.0.1.3680043.8.498.1127349924169261656...
# 6272  <1.2.826.0.1.3680043.8.498.1365749182637003433...        NaN
# 6274  <1.2.826.0.1.3680043.8.498.3671558050055647024...        NaN
# 6300  <1.2.826.0.1.3680043.8.498.6339755332757022576...        NaN
# 6302  <1.2.826.0.1.3680043.8.498.9248077207220765778...        NaN
# 6922  <1.2.826.0.1.3680043.8.498.2259356932170091134...        NaN
# 6928  <1.2.826.0.1.3680043.8.498.4529431452548342967...        NaN
# 6955  <1.2.826.0.1.3680043.8.498.4176604648037711272...        NaN
# 7043  <1.2.826.0.1.3680043.8.498.3923022531441735320...        NaN
# 7045  <1.2.826.0.1.3680043.8.498.1262011331010938042...        NaN
# 7365  <1.2.826.0.1.3680043.8.498.1308806265609717771...        NaN
# 7379  <1.2.826.0.1.3680043.8.498.1200997920479200364...        NaN
# 7382  <1.2.826.0.1.3680043.8.498.3965562590797393193...        NaN
# 7385  <1.2.826.0.1.3680043.8.498.1261340797146628946...        NaN
# 7472  <1.2.826.0.1.3680043.8.498.1644209591630153009...        NaN
# 7509  <1.2.826.0.1.3680043.8.498.2978690240620724554...        NaN
# 7971  <1.2.826.0.1.3680043.8.498.5737688969291561436...        NaN
# 8117  <1.2.826.0.1.3680043.8.498.6470183275905269561...        NaN
# 8119  <1.2.826.0.1.3680043.8.498.8755149405808405236...        NaN
# 8143  <1.2.826.0.1.3680043.8.498.6895832133043263730...        NaN
# 8146  <1.2.826.0.1.3680043.8.498.1182550199955702381...        NaN

# %%
df_check_failes = pd.DataFrame({'Total Check Fails': [5145, 272, 64, 3195]}, index=['PHI detection error', 'DICOM Validation', 'Rules Mismatch', 'Private Tags Mismatch'])

# %%
total = 8676
def fmt(x):
    return '{}'.format(round(total*x/100))

# %%
df_check_failes.plot.pie(
    y='Total Check Fails', figsize=(8, 8), autopct=fmt,
    legend=False,
    title="Distribution of Failed Tags by Cause in DICOM De-identification Process"
)
# Out:
# <Axes: title={'center': 'Distribution of Failed Tags by Cause in DICOM De-identification Process'}, ylabel='Total Check Fails'>

# %%
bins = [0.0, 0.25, 0.4, 0.5, 0.7, 0.8, 0.99]
report_df[report_df['check_score'] != 0.000]['check_score'].value_counts(bins=bins)
# Out:
# (0.7, 0.8]        1130
# (0.25, 0.4]        582
# (0.8, 0.99]        395
# (0.5, 0.7]         305
# (0.4, 0.5]         204
# (-0.001, 0.25]       0
# Name: count, dtype: int64

# %%
# report_df[report_df['check_score'] != 0.000]['check_score'].value_counts()

# %%
df_phi_detection_errs = pd.DataFrame({'Check Score': [582, 204, 305, 1130, 395, 2528]}, index=['0.25 - 0.4', '0.4 - 0.5', '0.5 - 0.7', '0.7 - 0.8', '0.8 - 1.0', '0.0'])

# %%
total = 5145
df_phi_detection_errs.plot.pie(
    y='Check Score', figsize=(8, 8), autopct=fmt,
    legend=False,
    title="Check Score Distribution of PHI Detection Error Fails"
)
# Out:
# <Axes: title={'center': 'Check Score Distribution of Failed tags due to PHI Detection Errors'}, ylabel='Check Score'>
