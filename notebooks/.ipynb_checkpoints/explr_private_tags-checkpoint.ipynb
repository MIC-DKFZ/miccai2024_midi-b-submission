# %%
import pandas as pd
from pprint import pprint

# %%
private_tags_table = pd.read_csv('../docs/TCIAPrivateTagKB-02-01-2024-formatted.csv')

# %%
private_tags_table
# Out:
#                                     element_sig_pattern  \
# 0     (0008,1084)[<0>](312f,"Ramsoft Diagnosis Datet...
# 1     (0008,1084)[<0>](312f,Ramsoft Diagnosis Dateti...
# 2     (0008,1084)[<0>](3131,Ramsoft Diagnosis Modifi...
# 3     (0008,1084)[<0>](3131,Ramsoft Diagnosis Modifi...
# 4     (0008,1084)[<0>](3133,Ramsoft Diagnosis Status...
# ...                                                 ...
# 8782              (8053,Unnamed Private Block - 10",00)
# 8783                              (f215,PB group A",17)
# 8784                              (f215,PB group A",17)
# 8785                              (f215,PB group A",18)
# 8786                              (f215,PB group A",18)
#
#                                        tag_name  vr private_disposition
# 0     Admitting Diagnoses Code Sequence:Unknown  DA                   d
# 1     Admitting Diagnoses Code Sequence:Unknown  TM                   d
# 2     Admitting Diagnoses Code Sequence:Unknown  DA                   d
# 3     Admitting Diagnoses Code Sequence:Unknown  TM                   d
# 4     Admitting Diagnoses Code Sequence:Unknown  IS                   d
# ...                                         ...  ..                 ...
# 8782                                    Unknown  OB                   d
# 8783                                    Unknown  DA                   d
# 8784                                    Unknown  UN                   d
# 8785                                    Unknown  TM                   d
# 8786                                    Unknown  UN                   d
#
# [8787 rows x 4 columns]

# %%
private_tags_table['element_sig_pattern']
# Out:
# 0       (0008,1084)[<0>](312f,"Ramsoft Diagnosis Datet...
# 1       (0008,1084)[<0>](312f,Ramsoft Diagnosis Dateti...
# 2       (0008,1084)[<0>](3131,Ramsoft Diagnosis Modifi...
# 3       (0008,1084)[<0>](3131,Ramsoft Diagnosis Modifi...
# 4       (0008,1084)[<0>](3133,Ramsoft Diagnosis Status...
#                               ...
# 8782                (8053,Unnamed Private Block - 10",00)
# 8783                                (f215,PB group A",17)
# 8784                                (f215,PB group A",17)
# 8785                                (f215,PB group A",18)
# 8786                                (f215,PB group A",18)
# Name: element_sig_pattern, Length: 8787, dtype: object

# %%
private_tags_table['private_disposition'].value_counts()
# Out:
# private_disposition
# d     4585
# k     3811
# na     210
# h       84
# o       46
#  k      23
# oi       9
# K        2
# D        2
# Name: count, dtype: int64

# %%
private_tags_table[
    (private_tags_table['element_sig_pattern'].str.match('\\(0021,.*,36')) & (private_tags_table['vr'] == 'SS')
]
# Out:
#           element_sig_pattern                     tag_name  vr  \
# 2294  (0021,GEMS_RELA_01",36)  Image From Which Prescribed  SS
#
#      private_disposition
# 2294                   k

# %%
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()
    
def replace_non_alphanumeric_with_space(input_string):
    # Replace all non-alphanumeric characters with a space
    result = re.sub(r'[^a-zA-Z0-9]', ' ', input_string)
    return result

class PrivateTagsAnonymizer:
    def __init__(self, private_tags_dict_path: str):
        self.private_tag_dict_path = private_tags_dict_path
        self.private_tag_df = None
        self.filtered_private_tag_df = None

        self._load_private_tag_dict()

    def _load_private_tag_dict(self):
        self.private_tag_df = pd.read_csv(self.private_tag_dict_path)
        self.private_tag_df['vr'] = self.private_tag_df['vr'].astype('category')
        self.private_tag_df['private_disposition'] = self.private_tag_df['private_disposition'].astype('category')

        self.private_tag_df['tag_group'] = self.private_tag_df['element_sig_pattern'].str[1:5]
        self.private_tag_df['tag_group'] = self.private_tag_df['tag_group'].astype('category')

    def filter_by_tag_group(self, tag_groups: list):
        return self.private_tag_df[self.private_tag_df['tag_group'].isin(tag_groups)]

    def filter_by_pattern_n_vr(self, filter_pattern, vr):
        df = self.private_tag_df
        if self.filtered_private_tag_df is not None:
            df = self.filtered_private_tag_df
        return df[
            (df['element_sig_pattern'].str.match(filter_pattern)) & 
            (df['vr'] == vr)
        ]
        
    def search_patterns_from_element(self, element, creators: list = [], include_base_tag_pattrn: bool = False):
        # Get the group and element separately
        group = element.tag.group
        dataelement = element.tag.element
        
        # Convert to hexadecimal string format
        group_str = f"{group:04x}"   # Output: '0010'
        element_str = f"{dataelement:04x}" # Output: '0010'

        all_patterns = []

        for creator in creators:
            pttrn = fr'\({group_str},{creator}.*,{element_str[2:]}\)'
            all_patterns.append(pttrn)

        all_patterns.append(fr'\({group_str},.*,{element_str[2:]}\)')
        if include_base_tag_pattrn:
            all_patterns.append(fr'\({group_str},.*{element_str[2:]}\)')

        return all_patterns

    def get_filtered_rows_from_patterns(self, patterns: list, element, strict: bool = True):
        filtered = []
        for pttrn in patterns:
            filtered_rules = anonymizer.filter_by_pattern_n_vr(pttrn, element.VR)
            if not strict:
                filtered = filtered_rules
            if len(filtered_rules) == 1:
                filtered = filtered_rules
                break
        return filtered

    def get_private_disposition_from_rows(self, filtered_rows, element, match_names: bool = True):
        if len(filtered_rows) == 0:
            return 'k'
        disposition_val = 'k'
        
        first_row = filtered_rows.iloc[0]

        if match_names:
            # get the similarity of the tag name with the element name
            row_name = first_row['tag_name']
            similarity = similar(
                element.name.lower(), 
                replace_non_alphanumeric_with_space(row_name.lower())
            )            
            if similarity > 0.5:
                disposition_val = first_row['private_disposition']
        else:
            disposition_val = first_row['private_disposition']
            
        return disposition_val.lower().strip()

# %%
anonymizer = PrivateTagsAnonymizer(
    private_tags_dict_path='../docs/TCIAPrivateTagKB-02-01-2024-formatted.csv'
)

# %%
import sys
import re
 
# setting path
sys.path.append('../')
import csv
from difflib import SequenceMatcher

from utils.dataloaders import MIDIEvalDataLoader
from utils.display import display_dicom
from dcm_anonymizers.utils import list_all_files
from IPython.display import display, HTML

from pathlib import Path

# %%
root_data_dir = '/home/r079a/Desktop/de-identification/dataset'

loader = MIDIEvalDataLoader(
    rawimagespath=Path(root_data_dir, 'images/manifest-1617826555824'),
    deidimagespath=Path(root_data_dir, 'images-2/manifest-1617826161202'),
    uidsmappath=Path(root_data_dir, 'Pseudo-PHI-DICOM-Dataset-uid_crosswalk.csv'),
)

# %%
(rawdcm, metadata), (deiddcm, deiddcm_metadata) = loader.get_raw_n_deid_patient(2, include_metadata=True)

# %%
dataset = rawdcm[0]

# %%
def extract_private_groups_n_creators(dataset):
    creators = []
    groups = []
    for element in dataset:
        if element.VR == 'OW':
            continue
        if element.tag.is_private:
            groups.append(f"{element.tag.group:04x}")
            if element.name == 'Private Creator' and element.value not in creators:                
                creators.append(element.value)

    groups = list(set(groups))

    return groups, creators

# %%
count = 0
groups, creators = extract_private_groups_n_creators(dataset)

groups_df = anonymizer.filter_by_tag_group(groups)
anonymizer.filtered_private_tag_df = groups_df

for element in dataset:
    if element.VR == 'OW':
        continue
    if element.tag.is_private:
        all_patterns = anonymizer.search_patterns_from_element(element, creators)        
        filtered = anonymizer.get_filtered_rows_from_patterns(all_patterns, element)

        # display(filtered)

        disposition_val = anonymizer.get_private_disposition_from_rows(filtered, element)
        print(element.tag, element.name, disposition_val)
        
        count += 1
        # if count > 5:
        #     break

anonymizer.filtered_private_tag_df = None
# Out:
# (0009, 0010) Private Creator k
# (0009, 1001) [GE Discovery PET Implementation Version Name] k
# (0009, 1003) [PET compatible_version] k
# (0009, 1004) [GE Advance Patient.software_version] k
# (0009, 1005) [PET patient_datetime] o
# (0009, 1007) [PET exam_id] h
# (0009, 1008) [PET compatible_version] k
# (0009, 1009) [PET software_version] k
# (0009, 100a) [PET scan_id] h
# (0009, 100b) [PET compatible_version] k
# (0009, 100c) [PET software_version] k
# (0009, 100d) [PET scan_datetime] o
# (0009, 100e) [PET scan_ready] o
# (0009, 100f) [PET scan_description] d
# (0009, 1011) [PET scanner_desc] k
# (0009, 1012) [PET manufacturer] k
# (0009, 1013) [PET for_identifier] h
# (0009, 1014) [PET landmark_name] k
# (0009, 1015) [PET landmark_abbrev] k
# (0009, 1016) [PET patient_position] k
# (0009, 1017) [PET scan_perspective] k
# (0009, 1018) [PET scan_type] k
# (0009, 1019) [PET scan_mode] k
# (0009, 101a) [PET start_condition] k
# (0009, 101b) [PET start_cond_data] k
# (0009, 101c) [PET sel_stop_cond] k
# (0009, 101d) [PET sel_stop_cond_data] k
# (0009, 101e) [PET collect_deadtime] k
# (0009, 101f) [PET collect_singles] k
# (0009, 1020) [PET collect_countrate] k
# (0009, 1021) [PET countrate_period] k
# (0009, 1022) [PET delayed_events] k
# (0009, 1023) [PET delayed_bias] k
# (0009, 1024) [PET word_size] k
# (0009, 1025) [PET axial_acceptance] k
# (0009, 1026) [PET axial_angle_3d] k
# (0009, 1027) [PET theta_compression] k
# (0009, 1028) [PET axial_compression] k
# (0009, 1029) [PET gantry_tilt_angle] k
# (0009, 102a) [PET collimation] k
# (0009, 102b) [PET scan_fov] k
# (0009, 102c) [PET axial_fov] k
# (0009, 102d) [PET event_separation] k
# (0009, 102e) [PET mask_width] k
# (0009, 1034) [PET triggers_acquired] k
# (0009, 1035) [PET triggers_rejected] k
# (0009, 1036) [PET tracer_name] k
# (0009, 1038) [PET tracer_activity] k
# (0009, 1039) [PET meas_datetime] o
# (0009, 103a) [PET pre_inj_volume] k
# (0009, 103b) [PET admin_datetime] o
# (0009, 103c) [PET post_inj_activity] k
# (0009, 103d) [PET post_inj_datetime] o
# (0009, 103e) [PET radionuclide_name] k
# (0009, 103f) [PET half_life] k
# (0009, 1040) [PET positron_fraction] k
# (0009, 104d) [PET emission_present] k
# (0009, 104e) [PET lower_axial_acc] k
# (0009, 104f) [PET upper_axial_acc] k
# (0009, 1050) [PET lower_coinc_limit] k
# (0009, 1051) [PET upper_coinc_limit] k
# (0009, 1052) [PET coinc_delay_offset] k
# (0009, 1053) [PET coinc_output_mode] k
# (0009, 1054) [PET upper_energy_limit] k
# (0009, 1055) [PET lower_energy_limit] k
# (0009, 1056) [PET normal_cal_id] h
# (0009, 1057) [PET normal_2d_cal_id] h
# (0009, 1059) [PET wc_cal_id] h
# (0009, 105a) [PET derived] k
# (0009, 105c) [PET frame_id] h
# (0009, 105d) [PET scan_id] h
# (0009, 105e) [PET exam_id] h
# (0009, 1060) [PET compatible_version] k
# (0009, 1061) [PET software_version] k
# (0009, 1066) [PET table_height] k
# (0009, 1067) [PET table_z_position] k
# (0009, 1068) [PET landmark_datetime] o
# (0009, 1069) [PET slice_count] k
# (0009, 106a) [PET start_location] k
# (0009, 106b) [PET acq_delay] k
# (0009, 106c) [PET acq_start] o
# (0009, 106d) [PET acq_duration] k
# (0009, 1070) [PET actual_stop_cond] k
# (0009, 1073) [PET frame_valid] k
# (0009, 1074) [PET validity_info] k
# (0009, 1075) [PET archived] k
# (0009, 1076) [PET compression] k
# (0009, 1077) [PET uncompressed_size] k
# (0009, 1079) [PET compatible_version] k
# (0009, 107a) [PET software_version] k
# (0009, 107b) [PET is_datetime] o
# (0009, 107c) [PET is_source] k
# (0009, 107d) [PET is_contents] k
# (0009, 107e) [PET is_type] k
# (0009, 107f) [PET is_reference] k
# (0009, 1080) [PET multi_patient] k
# (0009, 1084) [PET rotate] k
# (0009, 1085) [PET flip] k
# (0009, 1086) [PET zoom] k
# (0009, 1087) [PET pan_x] k
# (0009, 1088) [PET pan_y] k
# (0009, 108b) [PET recon_method] k
# (0009, 108c) [PET attenuation] k
# (0009, 108d) [PET atten_coefficient] k
# (0009, 108e) [PET bp_filter] k
# (0009, 1090) [PET bp_filter_order] k
# (0009, 1091) [PET bp_center_l] k
# (0009, 1092) [PET bp_center_p] k
# (0009, 1093) [PET atten_smooth] k
# (0009, 1094) [PET atten_smooth_param] k
# (0009, 1095) [PET angle_smooth_param] k
# (0009, 1097) [PET trans_scan_id] h
# (0009, 1098) [PET norm_cal_id] h
# (0009, 109a) [PET cac_edge_threshold] k
# (0009, 109b) [PET cac_skull_offset] k
# (0009, 10a4) [PET compatible_version] k
# (0009, 10a5) [PET software_version] k
# (0009, 10a6) [PET slice_number] k
# (0009, 10a7) [PET total_counts] k
# (0009, 10aa) [PET archived] k
# (0009, 10ab) [PET bp_center_x] k
# (0009, 10ac) [PET bp_center_y] k
# (0009, 10ad) [PET trans_frame_id] h
# (0009, 10b2) [PET ir_num_iterations] k
# (0009, 10b3) [PET ir_num_subsets] k
# (0009, 10b4) [PET ir_recon_fov] k
# (0009, 10b6) [PET ir_loop_filter] k
# (0009, 10b8) [PET ir_loop_filt_parm] k
# (0009, 10b9) [PET response_filt_parm] k
# (0009, 10ba) [PET post_filter] k
# (0009, 10bb) [PET post_filt_parm] k
# (0009, 10c7) [PET overlap] k
# (0009, 10cb) [PET vqc_x_axis_trans] k
# (0009, 10cc) [PET vqc_x_axis_tilt] k
# (0009, 10cd) [PET vqc_y_axis_trans] k
# (0009, 10ce) [PET vqc_y_axis_swivel] k
# (0009, 10cf) [PET vqc_z_axis_trans] k
# (0009, 10d0) [PET vqc_z_axis_roll] k
# (0009, 10d5) [PET loop_filter_parm] k
# (0011, 0010) Private Creator k
# (0013, 0010) Private Creator k
# (0013, 1010) Private tag data k
# (0013, 1013) Private tag data k

# %%
deiddataset = deiddcm[0]

# %%
for element in dataset:
    if element.VR == 'OW':
        continue
    if element.tag.is_private:
        deidelem = deiddataset.get(element.tag)

        deidval = 'Not Available'
        if deidelem is not None:
            deidval = deidelem.value
        
        print(element.tag, element.name, element.VR)
        print(f"{element.value} -> {deidval}")
        if element.value == deidval:
            print("k")
        else:
            print("Changed")
            print("======================")
# Out:
# (0009, 0010) Private Creator LO
# GEMS_PETD_01 -> GEMS_PETD_01
# k
# (0009, 1001) [GE Discovery PET Implementation Version Name] LO
# GE Advance -> GE Advance
# k
# (0009, 1003) [PET compatible_version] SH
# 05.00 -> 05.00
# k
# (0009, 1004) [GE Advance Patient.software_version] SH
# 16.01 -> 16.01
# k
# (0009, 1005) [PET patient_datetime] DT
#  ->
# k
# (0009, 1007) [PET exam_id] UI
# 2.25.274128889631512605961383205193865870838 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.295597077400414441954848071527
# Changed
# ======================
# (0009, 1008) [PET compatible_version] SH
# 05.00 -> 05.00
# k
# (0009, 1009) [PET software_version] SH
# 16.01 -> 16.01
# k
# (0009, 100a) [PET scan_id] UI
# 2.25.173228199981161944442560079805241998838 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.380972221829913586024126040548
# Changed
# ======================
# (0009, 100b) [PET compatible_version] SH
# 05.00 -> 05.00
# k
# (0009, 100c) [PET software_version] SH
# 16.01 -> 16.01
# k
# (0009, 100d) [PET scan_datetime] DT
#  ->
# k
# (0009, 100e) [PET scan_ready] DT
#  ->
# k
# (0009, 100f) [PET scan_description] ST
# PET CT INFERIOR TO SUPERIOR -> Not Available
# Changed
# ======================
# (0009, 1011) [PET scanner_desc] LO
# Discovery LS -> Discovery LS
# k
# (0009, 1012) [PET manufacturer] LO
# GE MEDICAL SYSTEMS -> GE MEDICAL SYSTEMS
# k
# (0009, 1013) [PET for_identifier] UI
# 2.25.151640615734952038741545071028091862518 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.299460966432303051592719656844
# Changed
# ======================
# (0009, 1014) [PET landmark_name] LO
# Orbital Meatal Line -> Orbital Meatal Line
# k
# (0009, 1015) [PET landmark_abbrev] SH
# OM -> OM
# k
# (0009, 1016) [PET patient_position] SL
# 0 -> 0
# k
# (0009, 1017) [PET scan_perspective] SL
# 0 -> 0
# k
# (0009, 1018) [PET scan_type] SL
# 0 -> 0
# k
# (0009, 1019) [PET scan_mode] SL
# 0 -> 0
# k
# (0009, 101a) [PET start_condition] SL
# 1 -> 1
# k
# (0009, 101b) [PET start_cond_data] SL
# 0 -> 0
# k
# (0009, 101c) [PET sel_stop_cond] SL
# 1 -> 1
# k
# (0009, 101d) [PET sel_stop_cond_data] SL
# 0 -> 0
# k
# (0009, 101e) [PET collect_deadtime] SL
# 1 -> 1
# k
# (0009, 101f) [PET collect_singles] SL
# 1 -> 1
# k
# (0009, 1020) [PET collect_countrate] SL
# 0 -> 0
# k
# (0009, 1021) [PET countrate_period] SL
# 1 -> 1
# k
# (0009, 1022) [PET delayed_events] SL
# 2 -> 2
# k
# (0009, 1023) [PET delayed_bias] SL
# 100 -> 100
# k
# (0009, 1024) [PET word_size] SL
# 2 -> 2
# k
# (0009, 1025) [PET axial_acceptance] SL
# 1 -> 1
# k
# (0009, 1026) [PET axial_angle_3d] SL
# 0 -> 0
# k
# (0009, 1027) [PET theta_compression] SL
# 0 -> 0
# k
# (0009, 1028) [PET axial_compression] SL
# 1 -> 1
# k
# (0009, 1029) [PET gantry_tilt_angle] FL
# 0.0 -> 0.0
# k
# (0009, 102a) [PET collimation] SL
# 1 -> 1
# k
# (0009, 102b) [PET scan_fov] SL
# 55 -> 55
# k
# (0009, 102c) [PET axial_fov] SL
# 153 -> 153
# k
# (0009, 102d) [PET event_separation] SL
# 2 -> 2
# k
# (0009, 102e) [PET mask_width] SL
# 0 -> 0
# k
# (0009, 1034) [PET triggers_acquired] SL
# 0 -> 0
# k
# (0009, 1035) [PET triggers_rejected] SL
# 0 -> 0
# k
# (0009, 1036) [PET tracer_name] LO
# FDG -- fluorodeoxyglucose -> FDG -- fluorodeoxyglucose
# k
# (0009, 1038) [PET tracer_activity] FL
# 534.3170166015625 -> 534.3170166015625
# k
# (0009, 1039) [PET meas_datetime] DT
#  ->
# k
# (0009, 103a) [PET pre_inj_volume] FL
# 1.600000023841858 -> 1.600000023841858
# k
# (0009, 103b) [PET admin_datetime] DT
#  ->
# k
# (0009, 103c) [PET post_inj_activity] FL
# 8.694999694824219 -> 8.694999694824219
# k
# (0009, 103d) [PET post_inj_datetime] DT
#  ->
# k
# (0009, 103e) [PET radionuclide_name] SH
# 18F -> 18F
# k
# (0009, 103f) [PET half_life] FL
# 6588.0 -> 6588.0
# k
# (0009, 1040) [PET positron_fraction] FL
# 0.9700000286102295 -> 0.9700000286102295
# k
# (0009, 104d) [PET emission_present] SL
# 0 -> 0
# k
# (0009, 104e) [PET lower_axial_acc] SL
# -4 -> -4
# k
# (0009, 104f) [PET upper_axial_acc] SL
# 3 -> 3
# k
# (0009, 1050) [PET lower_coinc_limit] SL
# -6 -> -6
# k
# (0009, 1051) [PET upper_coinc_limit] SL
# 6 -> 6
# k
# (0009, 1052) [PET coinc_delay_offset] SL
# 56 -> 56
# k
# (0009, 1053) [PET coinc_output_mode] SL
# 800 -> 800
# k
# (0009, 1054) [PET upper_energy_limit] SL
# 650 -> 650
# k
# (0009, 1055) [PET lower_energy_limit] SL
# 300 -> 300
# k
# (0009, 1056) [PET normal_cal_id] UI
# 2.25.123243193449557081272248750181113773558 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.253482574392820404431587552030
# Changed
# ======================
# (0009, 1057) [PET normal_2d_cal_id] UI
# 2.25.123243193449557081272248750181113773558 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.253482574392820404431587552030
# Changed
# ======================
# (0009, 1059) [PET wc_cal_id] UI
# 2.25.213209411470738399326124834704347217398 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.311596803672227427076301360168
# Changed
# ======================
# (0009, 105a) [PET derived] SL
# 0 -> 0
# k
# (0009, 105c) [PET frame_id] UI
# 2.25.332749614551381879684506021735672954358 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.114174361231861731643841183334
# Changed
# ======================
# (0009, 105d) [PET scan_id] UI
# 2.25.173228199981161944442560079805241998838 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.380972221829913586024126040548
# Changed
# ======================
# (0009, 105e) [PET exam_id] UI
# 2.25.274128889631512605961383205193865870838 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.295597077400414441954848071527
# Changed
# ======================
# (0009, 1060) [PET compatible_version] SH
# 05.00 -> 05.00
# k
# (0009, 1061) [PET software_version] SH
# 16.01 -> 16.01
# k
# (0009, 1066) [PET table_height] FL
# 148.5 -> 148.5
# k
# (0009, 1067) [PET table_z_position] FL
# 1329.5 -> 1329.5
# k
# (0009, 1068) [PET landmark_datetime] DT
#  ->
# k
# (0009, 1069) [PET slice_count] SL
# 35 -> 35
# k
# (0009, 106a) [PET start_location] FL
# -867.0 -> -867.0
# k
# (0009, 106b) [PET acq_delay] SL
# 0 -> 0
# k
# (0009, 106c) [PET acq_start] DT
#  ->
# k
# (0009, 106d) [PET acq_duration] SL
# 300 -> 300
# k
# (0009, 1070) [PET actual_stop_cond] SL
# 0 -> 0
# k
# (0009, 1073) [PET frame_valid] SL
# 1 -> 1
# k
# (0009, 1074) [PET validity_info] SL
# 255 -> 255
# k
# (0009, 1075) [PET archived] SL
# 0 -> 0
# k
# (0009, 1076) [PET compression] SL
# 0 -> 0
# k
# (0009, 1077) [PET uncompressed_size] SL
# 6714624 -> 6714624
# k
# (0009, 1079) [PET compatible_version] SH
# 05.00 -> 05.00
# k
# (0009, 107a) [PET software_version] SH
# 16.01 -> 16.01
# k
# (0009, 107b) [PET is_datetime] DT
#  ->
# k
# (0009, 107c) [PET is_source] SL
# 0 -> 0
# k
# (0009, 107d) [PET is_contents] SL
# 2 -> 2
# k
# (0009, 107e) [PET is_type] SL
# 0 -> 0
# k
# (0009, 107f) [PET is_reference] DS
# [0, 0, -0] -> [0, 0, -0]
# k
# (0009, 1080) [PET multi_patient] SL
# 0 -> 0
# k
# (0009, 1084) [PET rotate] FL
# 0.0 -> 0.0
# k
# (0009, 1085) [PET flip] SL
# 0 -> 0
# k
# (0009, 1086) [PET zoom] FL
# 1.0 -> 1.0
# k
# (0009, 1087) [PET pan_x] SL
# 0 -> 0
# k
# (0009, 1088) [PET pan_y] SL
# 0 -> 0
# k
# (0009, 108b) [PET recon_method] SL
# 2 -> 2
# k
# (0009, 108c) [PET attenuation] SL
# 2 -> 2
# k
# (0009, 108d) [PET atten_coefficient] FL
# 0.09600000083446503 -> 0.09600000083446503
# k
# (0009, 108e) [PET bp_filter] SL
# 0 -> 0
# k
# (0009, 1090) [PET bp_filter_order] SL
# 0 -> 0
# k
# (0009, 1091) [PET bp_center_l] FL
# 0.0 -> 0.0
# k
# (0009, 1092) [PET bp_center_p] FL
# 0.0 -> 0.0
# k
# (0009, 1093) [PET atten_smooth] SL
# 0 -> 0
# k
# (0009, 1094) [PET atten_smooth_param] SL
# 0 -> 0
# k
# (0009, 1095) [PET angle_smooth_param] SL
# 0 -> 0
# k
# (0009, 1097) [PET trans_scan_id] UI
# 2.25.32209428229083310683762472666109951478 -> Not Available
# Changed
# ======================
# (0009, 1098) [PET norm_cal_id] UI
# 2.25.123243193449557081272248750181113773558 -> 1.3.6.1.4.1.14519.5.2.1.8700.9668.253482574392820404431587552030
# Changed
# ======================
# (0009, 109a) [PET cac_edge_threshold] FL
# 0.0 -> 0.0
# k
# (0009, 109b) [PET cac_skull_offset] FL
# 0.0 -> 0.0
# k
# (0009, 10a4) [PET compatible_version] SH
# 05.00 -> 05.00
# k
# (0009, 10a5) [PET software_version] SH
# 16.01 -> 16.01
# k
# (0009, 10a6) [PET slice_number] SL
# 35 -> 35
# k
# (0009, 10a7) [PET total_counts] FL
# 50889.0 -> 50889.0
# k
# (0009, 10aa) [PET archived] SL
# 0 -> 0
# k
# (0009, 10ab) [PET bp_center_x] FL
# 0.0 -> 0.0
# k
# (0009, 10ac) [PET bp_center_y] FL
# 0.0 -> 0.0
# k
# (0009, 10ad) [PET trans_frame_id] UI
# 2.25.311117323437628424903073727978227219958 -> Not Available
# Changed
# ======================
# (0009, 10b2) [PET ir_num_iterations] SS
# None -> None
# k
# (0009, 10b3) [PET ir_num_subsets] SS
# None -> None
# k
# (0009, 10b4) [PET ir_recon_fov] FL
# 50.0 -> 50.0
# k
# (0009, 10b6) [PET ir_loop_filter] SS
# None -> None
# k
# (0009, 10b8) [PET ir_loop_filt_parm] FL
# 0.0 -> 0.0
# k
# (0009, 10b9) [PET response_filt_parm] FL
# 4.0 -> 4.0
# k
# (0009, 10ba) [PET post_filter] SS
# None -> None
# k
# (0009, 10bb) [PET post_filt_parm] FL
# 5.449999809265137 -> 5.449999809265137
# k
# (0009, 10c7) [PET overlap] SL
# 0 -> 0
# k
# (0009, 10cb) [PET vqc_x_axis_trans] FL
# 0.0 -> 0.0
# k
# (0009, 10cc) [PET vqc_x_axis_tilt] FL
# 0.0 -> 0.0
# k
# (0009, 10cd) [PET vqc_y_axis_trans] FL
# 0.0 -> 0.0
# k
# (0009, 10ce) [PET vqc_y_axis_swivel] FL
# 0.0 -> 0.0
# k
# (0009, 10cf) [PET vqc_z_axis_trans] FL
# 61.0 -> 61.0
# k
# (0009, 10d0) [PET vqc_z_axis_roll] FL
# 0.0 -> 0.0
# k
# (0009, 10d5) [PET loop_filter_parm] FL
# 3.9100000858306885 -> 3.9100000858306885
# k
# (0011, 0010) Private Creator LO
# GEMS_PETD_01 -> GEMS_PETD_01
# k
# (0013, 0010) Private Creator LO
# CTP -> CTP
# k
# (0013, 1010) Private tag data LO
# Pseudo-PHI-DICOM-Data -> Pseudo-PHI-DICOM-Data
# k
# (0013, 1013) Private tag data LO
# 87009668 -> 87009668
# k
