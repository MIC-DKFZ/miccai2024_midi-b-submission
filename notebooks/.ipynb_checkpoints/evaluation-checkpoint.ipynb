# %%
import sys
 
# setting path
sys.path.append('../')
import csv

from utils.dataloaders import MIDIEvalDataLoader
from utils.display import display_dicom
from dcm_anonymizers.utils import list_all_files

from pathlib import Path

# %%
root_data_dir = '/home/r079a/Desktop/de-identification/dataset'

loader = MIDIEvalDataLoader(
    rawimagespath=Path(root_data_dir, 'images/manifest-1617826555824'),
    deidimagespath=Path(root_data_dir, 'images-2/manifest-1617826161202'),
    uidsmappath=Path(root_data_dir, 'Pseudo-PHI-DICOM-Dataset-uid_crosswalk.csv'),
)

# %%
(rawdcm, metadata), (deiddcm, deiddcm_metadata) = loader.get_raw_n_deid_patient(2, include_metadata=True)

# %%
deiddcm_metadata
# Out:
# {'Series UID': '1.3.6.1.4.1.14519.5.2.1.8700.9668.102593168701928701393977739873',
#  'Collection': 'Pseudo-PHI-DICOM-Data',
#  '3rd Party Analysis': 'NO',
#  'Data Description URI': 'https://doi.org/10.7937/s17zr072',
#  'Subject ID': 'Pseudo-PHI-005',
#  'Study UID': '1.3.6.1.4.1.14519.5.2.1.8700.9668.295597077400414441954848071527',
#  'Study Description': 'PET-CT STUDY',
#  'Study Date': '06-18-1951',
#  'Series Description': 'PET-CT SERIES',
#  'Manufacturer': 'GE MEDICAL SYSTEMS',
#  'Modality': 'PT',
#  'SOP Class Name': 'Positron Emission Tomography Image Storage',
#  'SOP Class UID': '1.2.840.10008.5.1.4.1.1.128',
#  'Number of Images': 174,
#  'File Size': '6.74 MB',
#  'File Location': './Pseudo-PHI-DICOM-Data/Pseudo-PHI-005/06-18-1951-NA-PET-CT STUDY-71527/PET-CT SERIES-39873',
#  'Download Timestamp': '2024-06-03T18:25:22.37'}

# %%
display_dicom(rawdcm[0])

# %%
display_dicom(deiddcm[0])

# %%
# for element in rawdcm[0]:
#     if element.VR == 'OW' or element.VR == 'UI':
#         continue
        
#     thisval = element.value
#     deidval = ''
#     if element.tag in deiddcm[0]:
#         deidval = deiddcm[0][element.tag].value

#     if deidval != thisval:
#         print(element.tag, element.name, element.VR)
#         print(f"{thisval} --> {deidval}")

# %%
from dicomanonymizer.anonymizer import anonymize
from pathlib import Path
import os

# %%
rootdir = '/home/r079a/Desktop/de-identification/'

raw_img_path = Path(rootdir, 'dataset/images/manifest-1617826555824', metadata['File Location'])
output_path = Path(rootdir, 'dicom-output')

# %%
first_dcm_name = os.listdir(raw_img_path)[0]
first_dcm_name
# Out:
# '1-001.dcm'

# %%
anonymize(
    Path(raw_img_path, first_dcm_name), output_path, {}, True,
)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 52.39it/s]

# %%
from pydicom import dcmread
import pandas as pd

# %%
with open(Path(output_path, first_dcm_name), 'rb') as infile:
    ds = dcmread(infile)

# %%
tagvalues = []
for element in rawdcm[0]:
    if element.VR == 'OW':
        continue
    deidval = "Not available"
    if element.tag in deiddcm[0]:
        deidval = str(deiddcm[0][element.tag].value)
    dcmannonval = "Not available"
    if element.tag in ds:
        dcmannonval = str(ds[element.tag].value)
    changed = False
    # if str(element.value) != deidval or str(element.value) != dcmannonval:
    if str(element.value) != deidval:
        changed = True
    values_tuple = (str(element.tag), element.name, str(element.value), deidval, dcmannonval, changed)
    tagvalues.append(values_tuple)

# %%
valus_df = pd.DataFrame(tagvalues, columns =['Tag', 'Name', 'Raw Metadata', 'Ground Truth Anonimization', 'Dicom Anonymizer', 'Changed'])

# %%
pd.set_option('display.max_rows', 82)
valus_df[valus_df['Changed']]
# Out:
#               Tag                                     Name  \
# 2    (0008, 0012)                   Instance Creation Date
# 4    (0008, 0014)                     Instance Creator UID
# 6    (0008, 0018)                         SOP Instance UID
# 7    (0008, 0020)                               Study Date
# 8    (0008, 0021)                              Series Date
# 9    (0008, 0022)                         Acquisition Date
# 10   (0008, 0023)                             Content Date
# 15   (0008, 0050)                         Accession Number
# 18   (0008, 0080)                         Institution Name
# 19   (0008, 0081)                      Institution Address
# 20   (0008, 0090)               Referring Physician's Name
# 21   (0008, 0092)            Referring Physician's Address
# 22   (0008, 0094)  Referring Physician's Telephone Numbers
# 23   (0008, 1030)                        Study Description
# 25   (0008, 1050)              Performing Physician's Name
# 26   (0008, 1070)                          Operators' Name
# 33   (0009, 1007)                            [PET exam_id]
# 36   (0009, 100a)                            [PET scan_id]
# 41   (0009, 100f)                   [PET scan_description]
# 44   (0009, 1013)                     [PET for_identifier]
# 93   (0009, 1056)                      [PET normal_cal_id]
# 94   (0009, 1057)                   [PET normal_2d_cal_id]
# 95   (0009, 1059)                          [PET wc_cal_id]
# 97   (0009, 105c)                           [PET frame_id]
# 98   (0009, 105d)                            [PET scan_id]
# 99   (0009, 105e)                            [PET exam_id]
# 139  (0009, 1097)                      [PET trans_scan_id]
# 140  (0009, 1098)                        [PET norm_cal_id]
# 150  (0009, 10ad)                     [PET trans_frame_id]
# 167  (0010, 0010)                           Patient's Name
# 168  (0010, 0020)                               Patient ID
# 169  (0010, 0030)                     Patient's Birth Date
# 174  (0010, 2154)              Patient's Telephone Numbers
# 177  (0012, 0050)             Clinical Trial Time Point ID
# 178  (0012, 0051)    Clinical Trial Time Point Description
# 200  (0020, 000d)                       Study Instance UID
# 201  (0020, 000e)                      Series Instance UID
# 202  (0020, 0010)                                 Study ID
# 207  (0020, 0052)                   Frame of Reference UID
#
#                                           Raw Metadata  \
# 2                                             19610705
# 4         2.25.167528535081124457136479351275624447478
# 6         2.25.136713102155481595503528170385131027958
# 7                                             19610705
# 8                                             19610705
# 9                                             19610705
# 10                                            19610705
# 15                                     19610707E512330
# 18                              Collins Medical Center
# 19              584 Martinez Lake New Edward, AR 53239
# 20                                      BENNETT^JOSEPH
# 21   193 Alicia Locks Apt. 326 West Daleburgh, NV 2...
# 22                                      1-014-099-5877
# 23                     PET-CT STUDY for Shelly Wallace
# 25                                         MOLINA^ALEX
# 26                                    RICHARDS^BRIANNA
# 33        2.25.274128889631512605961383205193865870838
# 36        2.25.173228199981161944442560079805241998838
# 41                         PET CT INFERIOR TO SUPERIOR
# 44        2.25.151640615734952038741545071028091862518
# 93        2.25.123243193449557081272248750181113773558
# 94        2.25.123243193449557081272248750181113773558
# 95        2.25.213209411470738399326124834704347217398
# 97        2.25.332749614551381879684506021735672954358
# 98        2.25.173228199981161944442560079805241998838
# 99        2.25.274128889631512605961383205193865870838
# 139        2.25.32209428229083310683762472666109951478
# 140       2.25.123243193449557081272248750181113773558
# 150       2.25.311117323437628424903073727978227219958
# 167                                     WALLACE^SHELLY
# 168                                         3642991663
# 169                                           19210606
# 174                                   (139)060-6894x33
# 177                                                  0
# 178                         Days offset from diagnosis
# 200       2.25.274128889631512605961383205193865870838
# 201        2.25.16889725737787757262937018243711876598
# 202                                             345678
# 207       2.25.151640615734952038741545071028091862518
#
#                             Ground Truth Anonimization  \
# 2                                             19510618
# 4    1.3.6.1.4.1.14519.5.2.1.8700.9668.196238836601...
# 6    1.3.6.1.4.1.14519.5.2.1.8700.9668.650452479778...
# 7                                             19510618
# 8                                             19510618
# 9                                             19510618
# 10                                            19510618
# 15
# 18                                       Not available
# 19                                       Not available
# 20
# 21                                       Not available
# 22                                       Not available
# 23                                        PET-CT STUDY
# 25                                       Not available
# 26                                       Not available
# 33   1.3.6.1.4.1.14519.5.2.1.8700.9668.295597077400...
# 36   1.3.6.1.4.1.14519.5.2.1.8700.9668.380972221829...
# 41                                       Not available
# 44   1.3.6.1.4.1.14519.5.2.1.8700.9668.299460966432...
# 93   1.3.6.1.4.1.14519.5.2.1.8700.9668.253482574392...
# 94   1.3.6.1.4.1.14519.5.2.1.8700.9668.253482574392...
# 95   1.3.6.1.4.1.14519.5.2.1.8700.9668.311596803672...
# 97   1.3.6.1.4.1.14519.5.2.1.8700.9668.114174361231...
# 98   1.3.6.1.4.1.14519.5.2.1.8700.9668.380972221829...
# 99   1.3.6.1.4.1.14519.5.2.1.8700.9668.295597077400...
# 139                                      Not available
# 140  1.3.6.1.4.1.14519.5.2.1.8700.9668.253482574392...
# 150                                      Not available
# 167                                     Pseudo-PHI-005
# 168                                     Pseudo-PHI-005
# 169
# 174                                      Not available
# 177
# 178                                      Not available
# 200  1.3.6.1.4.1.14519.5.2.1.8700.9668.295597077400...
# 201  1.3.6.1.4.1.14519.5.2.1.8700.9668.102593168701...
# 202
# 207  1.3.6.1.4.1.14519.5.2.1.8700.9668.299460966432...
#
#                                  Dicom Anonymizer  Changed
# 2                                        00010101     True
# 4    2.25.186129764232211447736182365660938153656     True
# 6    2.25.244656022709676072683323985853966324235     True
# 7                                        00010101     True
# 8                                        00010101     True
# 9                                        00010101     True
# 10                                       00010101     True
# 15                                                    True
# 18                                     ANONYMIZED     True
# 19                                  Not available     True
# 20                                                    True
# 21                                  Not available     True
# 22                                  Not available     True
# 23                                  Not available     True
# 25                                  Not available     True
# 26                                     ANONYMIZED     True
# 33                                  Not available     True
# 36                                  Not available     True
# 41                                  Not available     True
# 44                                  Not available     True
# 93                                  Not available     True
# 94                                  Not available     True
# 95                                  Not available     True
# 97                                  Not available     True
# 98                                  Not available     True
# 99                                  Not available     True
# 139                                 Not available     True
# 140                                 Not available     True
# 150                                 Not available     True
# 167                                                   True
# 168                                                   True
# 169                                      00010101     True
# 174                                 Not available     True
# 177                                                   True
# 178                                 Not available     True
# 200   2.25.14502238138713938394963734035044834984     True
# 201  2.25.190595762798334980029378293273682855622     True
# 202                                                   True
# 207  2.25.106185688184950683504938521171477215155     True

# %%
# targettag = (0x0018,0xa001)
# print(rawdcm[0][targettag].value)
# print(deiddcm[0][targettag].value)
# print(ds[targettag].value)

# %% [markdown]
# ### Evaluate PS_3_3 Anonymizer

# %%
(rawdcm, metadata), (deiddcm, deiddcm_metadata) = loader.get_raw_n_deid_patient(5, include_metadata=True)

raw_dcm = rawdcm[0]
deid_dcm = deiddcm[0]

# %%
metadata
# Out:
# {'Series UID': '2.25.165719506958352694947877011193729760758',
#  'Collection': 'Pseudo-PHI-DICOM-Data',
#  '3rd Party Analysis': 'NO',
#  'Data Description URI': 'https://doi.org/10.7937/s17zr072',
#  'Subject ID': 339833062,
#  'Study UID': '2.25.541629416691863029175036346640219638',
#  'Study Description': nan,
#  'Study Date': '07-05-2001',
#  'Series Description': nan,
#  'Manufacturer': 'GE MEDICAL SYSTEMS',
#  'Modality': 'DX',
#  'SOP Class Name': 'Digital X-Ray Image Storage - For Presentation',
#  'SOP Class UID': '1.2.840.10008.5.1.4.1.1.1.1',
#  'Number of Images': 7,
#  'File Size': '57.25 MB',
#  'File Location': './Pseudo-PHI-DICOM-Data/339833062/07-05-2001-NA-NA-19638/3001578.000000-NA-60758',
#  'Download Timestamp': '2024-06-03T18:21:00.189'}

# %%
deiddcm_metadata
# Out:
# {'Series UID': '1.3.6.1.4.1.14519.5.2.1.8700.9668.176589230337490151550363211908',
#  'Collection': 'Pseudo-PHI-DICOM-Data',
#  '3rd Party Analysis': 'NO',
#  'Data Description URI': 'https://doi.org/10.7937/s17zr072',
#  'Subject ID': 'Pseudo-PHI-002',
#  'Study UID': '1.3.6.1.4.1.14519.5.2.1.8700.9668.218004556460571348344200465823',
#  'Study Description': nan,
#  'Study Date': '06-18-1991',
#  'Series Description': nan,
#  'Manufacturer': 'GE MEDICAL SYSTEMS',
#  'Modality': 'DX',
#  'SOP Class Name': 'Digital X-Ray Image Storage - For Presentation',
#  'SOP Class UID': '1.2.840.10008.5.1.4.1.1.1.1',
#  'Number of Images': 7,
#  'File Size': '57.26 MB',
#  'File Location': './Pseudo-PHI-DICOM-Data/Pseudo-PHI-002/06-18-1991-NA-NA-65823/3001578.000000-NA-11908',
#  'Download Timestamp': '2024-06-03T18:25:12.081'}

# %%
anonymizer_output_path = Path(root_data_dir, 'anonymizer-output/Pseudo-PHI-DICOM-Data-8-private-tags')

# %%
path_mapping_file = Path(anonymizer_output_path, 'mappings/path_mapping.csv')

def id_map_csv_to_dict(csvfile: str):
    id_map = {}
    with open(path_mapping_file, mode ='r')as file:
      mapping = csv.reader(file)
      for idx, lines in enumerate(mapping):
          if idx == 0:
              continue
          id_map[lines[0]] = lines[1]
    return id_map 

series_output_map = id_map_csv_to_dict(path_mapping_file)

def get_first_dcm_path_from_series(seriesUID: str):
    series_path = series_output_map.get(seriesUID, '')
    if series_path == "":
        print(f"No path found for given series id {seriesUID}")
        return
    full_series_path = anonymizer_output_path / 'data' / series_path
    alldcms = list_all_files(full_series_path)
    print(full_series_path)
    if len(alldcms) == 0:
        print(f"No dicom found for given series id {seriesUID}")
        return
    return alldcms[0]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 13
#      10           id_map[lines[0]] = lines[1]
#      11     return id_map
# ---> 13 series_output_map = id_map_csv_to_dict(path_mapping_file)
#      15 def get_first_dcm_path_from_series(seriesUID: str):
#      16     series_path = series_output_map.get(seriesUID, '')
#
# Cell In[22], line 5, in id_map_csv_to_dict(csvfile)
#       3 def id_map_csv_to_dict(csvfile: str):
#       4     id_map = {}
# ----> 5     with open(path_mapping_file, mode ='r')as file:
#       6       mapping = csv.reader(file)
#       7       for idx, lines in enumerate(mapping):
#
# File ~/Desktop/de-identification/repo/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/r079a/Desktop/de-identification/dataset/anonymizer-output/Pseudo-PHI-DICOM-Data-8-private-tags/mappings/path_mapping.csv'

# %%
deidentfied_dcm_path = get_first_dcm_path_from_series(metadata['Series UID'])
print(deidentfied_dcm_path)
with open(deidentfied_dcm_path, 'rb') as infile:
    deidentfied_dcm = dcmread(infile)

# %%
display_dicom(raw_dcm)

# %%
display_dicom(deid_dcm)

# %%
display_dicom(deidentfied_dcm)

# %%
# tagvalues = []
# for element in raw_dcm:
#     if element.VR == 'OW':
#         print(element.name)
#         continue
#     deidval = "Not available"
#     if element.tag in deid_dcm:
#         deidval = str(deid_dcm[element.tag].value)
#     dcmannonval = "Not available"
#     if element.tag in deidentfied_dcm:
#         dcmannonval = str(deidentfied_dcm[element.tag].value)
#     changed = False
#     if str(element.value) != deidval:
#         changed = True
#     values_tuple = (str(element.tag), element.name, str(element.value), deidval, dcmannonval, changed)
#     tagvalues.append(values_tuple)

# %%
import pydicom

# %%
tagvalues = []
    
def extract_tags(dcm, gt_ds, annon_ds):
    elements = dcm
    gt_elements = gt_ds
    annon_elements = annon_ds
    parent_tag = None
    
    if isinstance(dcm, pydicom.dataelem.DataElement):
        parent_tag = dcm.tag
        if len(dcm.value) == 0:
            return
        
        elements = dcm.value[0]
        gt_elements = None
        if gt_ds and len(gt_ds.value) > 0:
            gt_elements = gt_ds.value[0]
        
        annon_elements = None
        if annon_ds and len(annon_ds.value) > 0:
            annon_elements = annon_ds.value[0] if annon_ds else None
        
    for element in elements:
        deidelem = gt_elements.get(element.tag) if gt_elements else None
        dcmannonelem = annon_elements.get(element.tag) if annon_elements else None
        
        if element.VR == 'OW':
            continue
        elif element.VR == 'SQ':
            extract_tags(element, deidelem, dcmannonelem)
            continue
        # targettags.append(element.tag)
        
        deidval = "Not available"
        if deidelem:
            deidval = str(deidelem.value)
        dcmannonval = "Not available"
        if dcmannonelem:
            dcmannonval = str(dcmannonelem.value)
        changed = False
        if dcmannonval != deidval:
            changed = True

        element_tag_str = str(element.tag)
        if parent_tag:
            element_tag_str = f"{str(parent_tag)} - {str(element.tag)}"
        values_tuple = (element_tag_str, element.VR, element.name, str(element.value), deidval, dcmannonval, changed)
        tagvalues.append(values_tuple)

extract_tags(raw_dcm, deid_dcm, deidentfied_dcm)

# %%
valus_df = pd.DataFrame(tagvalues, columns =['Tag', 'VR', 'Name', 'Raw Metadata', 'Ground Truth Anonimization', 'PS 3.3 Anonymizer', 'Changed'])

# %%
changed_df = valus_df[valus_df['Changed']]
changed_df

# %%
n_mismatched = 0
mismatched_tags = []

for index, row in valus_df.iterrows():
    gt_val = row['Ground Truth Anonimization']
    target_val = row['PS 3.3 Anonymizer']

    if gt_val != target_val:
        if row['VR'] == 'UI' and not (gt_val == "" or target_val == ""):
            continue
        elif row['VR'] in ('DA', 'DT', 'TM') and not (gt_val == "" or target_val == ""):
            if len(gt_val) != len(target_val):
                pass
            continue
        elif row['Tag'] in ('(0010, 0010)', '(0010, 0020)'):
            continue
        n_mismatched += 1
        mismatched_tags.append(row['Name'])

print(n_mismatched)
print(mismatched_tags)
