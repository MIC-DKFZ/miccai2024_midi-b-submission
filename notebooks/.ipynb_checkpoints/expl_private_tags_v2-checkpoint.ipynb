# %%
import re
import pandas as pd
from pprint import pprint
import math

# %%
private_tags_table = pd.read_csv('../docs/TCIAPrivateTagKB-02-01-2024-formatted.csv')

private_tags_table['vr'] = private_tags_table['vr'].astype('category')
private_tags_table['private_disposition'] = private_tags_table['private_disposition'].astype('category')

# %%
private_tags_table
# Out:
#                                     element_sig_pattern  \
# 0     (0008,1084)[<0>](312f,"Ramsoft Diagnosis Datet...
# 1     (0008,1084)[<0>](312f,Ramsoft Diagnosis Dateti...
# 2     (0008,1084)[<0>](3131,Ramsoft Diagnosis Modifi...
# 3     (0008,1084)[<0>](3131,Ramsoft Diagnosis Modifi...
# 4     (0008,1084)[<0>](3133,Ramsoft Diagnosis Status...
# ...                                                 ...
# 8782              (8053,Unnamed Private Block - 10",00)
# 8783                              (f215,PB group A",17)
# 8784                              (f215,PB group A",17)
# 8785                              (f215,PB group A",18)
# 8786                              (f215,PB group A",18)
#
#                                        tag_name  vr private_disposition
# 0     Admitting Diagnoses Code Sequence:Unknown  DA                   d
# 1     Admitting Diagnoses Code Sequence:Unknown  TM                   d
# 2     Admitting Diagnoses Code Sequence:Unknown  DA                   d
# 3     Admitting Diagnoses Code Sequence:Unknown  TM                   d
# 4     Admitting Diagnoses Code Sequence:Unknown  IS                   d
# ...                                         ...  ..                 ...
# 8782                                    Unknown  OB                   d
# 8783                                    Unknown  DA                   d
# 8784                                    Unknown  UN                   d
# 8785                                    Unknown  TM                   d
# 8786                                    Unknown  UN                   d
#
# [8787 rows x 4 columns]

# %%
private_tags_table['private_disposition'].value_counts()
# Out:
# private_disposition
# d     4585
# k     3811
# na     210
# h       84
# o       46
#  k      23
# oi       9
# D        2
# K        2
# Name: count, dtype: int64

# %%
# private_tag_dict = {}

# def get_tag_n_creator_from_element_str(elemnt_str):
#     cleaned_tag = elemnt_str.strip('(').strip(')')
#     splitted = cleaned_tag.split(',')
    
#     private_creator = 'empty'
#     if len(splitted) == 3 and splitted[1].strip() != '':            
#         private_creator = splitted[1].strip('"')
#     elif len(splitted) > 3:
#         private_creator = ''.join(splitted[1:-1]).strip('"')

#     if len(splitted) == 2:
#         tag = f"({splitted[0]},{splitted[-1]})"
#     else:
#         tag = f"({splitted[0]},{splitted[-1][-2:]})"

#     return tag, private_creator.lower()

# conflict_tags_count = {}

# for index, row in private_tags_table.iterrows():
#     element_pattern = row['element_sig_pattern']
#     element_tags = re.split(r'\[\<\d+\>\]', element_pattern)
    
#     tag, _ = get_tag_n_creator_from_element_str(element_tags[-1])
#     private_creator = 'empty'
#     all_tags = []
#     for eltag in element_tags:
#         ptag, prcreator  = get_tag_n_creator_from_element_str(eltag)
#         all_tags.append(ptag)
#         if private_creator == 'empty' and prcreator != 'empty':
#            private_creator = prcreator
    
#     disposition_val = row['private_disposition']
#     if not isinstance(disposition_val, str):
#         disposition_val = 'k'

#     vr = row['vr']
#     if not isinstance(vr, str):
#         vr = 'UN'

#     disposition_val = disposition_val.strip().lower()
        
#     tag_dict = {
#         'tag': tag,
#         'pattern': element_pattern,
#         'tag_name': row['tag_name'],
#         'vr': vr,
#         'private_disposition': disposition_val
#     }
    
    
#     private_creator_dict = {}
#     if private_creator in private_tag_dict.keys():
#         private_creator_dict = private_tag_dict[private_creator]

#     unique_tag_key = f"{'_'.join(all_tags)}_{row['vr']}"

#     if unique_tag_key in private_creator_dict.keys():
#         if element_pattern.lower() == private_creator_dict[unique_tag_key]['pattern'].lower():
#             pass
#         else:
#             conflict_tags_count[unique_tag_key] = f"{element_pattern} / {private_creator_dict[unique_tag_key]['pattern']}"
#             print(f'WARNING!! {unique_tag_key} already exist in the private creator dict "{private_creator}"')
#             print(element_pattern)
#             print(private_creator_dict[unique_tag_key]['pattern'])
#             print('====================================================')

#     private_creator_dict[unique_tag_key] = tag_dict
#     private_tag_dict[private_creator] = private_creator_dict

#     # if index >= 1000:
#     #     break

# print(len(conflict_tags_count.keys()))

# %%
private_tag_dict = {}
conflict_tags_count = {}

for index, row in private_tags_table.iterrows():
    element_pattern = row['element_sig_pattern']
    splitted = element_pattern.split(',')
    splitted = [s.strip('"').strip().lower() for s in splitted]
    pattern_cleaned = ','.join(splitted)

    disposition_val = row['private_disposition']
    if not isinstance(disposition_val, str):
        disposition_val = 'k'

    vr = row['vr']
    if not isinstance(vr, str):
        vr = 'UN'

    disposition_val = disposition_val.strip().lower()
        
    tag_dict = {
        'pattern': element_pattern,
        'tag_name': row['tag_name'],
        'vr': vr,
        'private_disposition': disposition_val
    }

    unique_tag_key = f"{pattern_cleaned}_{row['vr']}"
    
    if unique_tag_key in private_tag_dict.keys():
        if disposition_val == private_tag_dict[unique_tag_key]['private_disposition']:
            pass
        else:
            conflict_tags_count[unique_tag_key] = f"{element_pattern} / {private_tag_dict[unique_tag_key]['pattern']}"
            print(f'WARNING!! {unique_tag_key} already exist in the private_tag_dict as "{element_pattern}"')
            print(f"{private_tag_dict[unique_tag_key]['private_disposition']} -> {disposition_val}")
            print('====================================================')

    private_tag_dict[unique_tag_key] = tag_dict

print(len(conflict_tags_count.keys()))
# Out:
# WARNING!! (2005,philips mr imaging dd 001,18)_LO already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",18)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,35)_CS already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",35)"
# d -> k
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,35)_SS already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",35)"
# d -> k
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,5f)_CS already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",5f)"
# d -> k
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,5f)_SQ already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",5f)"
# d -> k
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,70)_LO already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",70)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,80)[<0>](2005,philips mr imaging dd 001,40)_SL already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",80)[<0>](2005,"PHILIPS MR IMAGING DD 001",40)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,80)[<0>](2005,philips mr imaging dd 001,41)_SL already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",80)[<0>](2005,"PHILIPS MR IMAGING DD 001",41)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,80)[<0>](2005,philips mr imaging dd 001,42)_SL already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",80)[<0>](2005,"PHILIPS MR IMAGING DD 001",42)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,80)[<0>](2005,philips mr imaging dd 001,43)_CS already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",80)[<0>](2005,"PHILIPS MR IMAGING DD 001",43)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,80)[<0>](2005,philips mr imaging dd 001,44)_SL already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",80)[<0>](2005,"PHILIPS MR IMAGING DD 001",44)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,80)[<0>](2005,philips mr imaging dd 001,45)_SL already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",80)[<0>](2005,"PHILIPS MR IMAGING DD 001",45)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,80)[<0>](2005,philips mr imaging dd 001,46)_CS already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",80)[<0>](2005,"PHILIPS MR IMAGING DD 001",46)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,80)[<0>](2005,philips mr imaging dd 001,47)_SL already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",80)[<0>](2005,"PHILIPS MR IMAGING DD 001",47)"
# k -> d
# ====================================================
# WARNING!! (2005,philips mr imaging dd 001,84)[<0>](2005,philips mr imaging dd 001,66)_CS already exist in the private_tag_dict as "(2005,PHILIPS MR IMAGING DD 001",84)[<0>](2005,"PHILIPS MR IMAGING DD 001",66)"
# k -> d
# ====================================================
# 15

# %%
# import json

# with open('../docs/tcia_private_tags_dict.json', 'w', encoding='utf-8') as f:
#     json.dump(private_tag_dict, f, ensure_ascii=False, indent=4)

# %%
import pydicom
from pydicom.dataset import Dataset, DataElement
from pydicom.sequence import Sequence

from pydicom import dcmread

from pathlib import Path

# %%
validation_data_path = "/home/r079a/Desktop/de-identification/dataset/midi-validation-data"
sample_dicom = Path(validation_data_path, 'input_data/2663440963/1.3.984.1.0.3271391.3.552.1032524404977493356/1.3.984.1.0.3271391.3.552.1757728462147515590/00000007.dcm')

# sample_dicom = Path(validation_data_path, 'input_data/2951928526/2.1.846.0.0.0624952.3.426.1171423858789191618/2.1.846.0.0.0624952.3.426.4666769529569841014/00000001.dcm')

print(sample_dicom)
# Out:
# /home/r079a/Desktop/de-identification/dataset/midi-validation-data/input_data/6736708662/3.4.911.0.0.7452303.1.901.9848250898230174418/3.4.911.0.0.7452303.1.901.2921419100524330748/00000013.dcm

# %%
dataset = dcmread(sample_dicom)

# %%
def extract_private_groups_n_creators(dataset):
    creators = []
    groups = []
    for element in dataset:
        if element.VR == 'OW':
            continue
        if element.tag.is_private:
            groups.append(f"{element.tag.group:04x}")
            if element.name == 'Private Creator' and element.value not in creators:                
                creators.append(element.value)

    groups = list(set(groups))

    return groups, creators

# %%
groups, creators = extract_private_groups_n_creators(dataset)

print(groups)
print(creators)
# Out:
# ['0019', '0017', '0009']
# ['GEMS_PETD_01', '20190720150450']

# %%
for element in dataset:
    if element.VR == 'OW':
        continue
    if element.tag.is_private:
        print(element)
# Out:
# (0009, 0010) Private Creator                     LO: 'GEMS_PETD_01'
# (0009, 1005) [PET patient_datetime]              DT: ''
# (0009, 100a) [PET scan_id]                       UI: 3.4.911.0.0.7452303.1.901.1025823112389872458
# (0009, 100d) [PET scan_datetime]                 DT: ''
# (0009, 100e) [PET scan_ready]                    DT: ''
# (0009, 1013) [PET for_identifier]                UI: 3.4.911.0.0.7452303.1.901.2919808965208501865
# (0009, 1014) [PET landmark_name]                 LO: 'Sternal Notch'
# (0009, 1015) [PET landmark_abbrev]               SH: 'SN'
# (0009, 1016) [PET patient_position]              SL: 0
# (0009, 1017) [PET scan_perspective]              SL: 0
# (0009, 1018) [PET scan_type]                     SL: 0
# (0009, 1019) [PET scan_mode]                     SL: 1
# (0009, 101a) [PET start_condition]               SL: 1
# (0009, 101b) [PET start_cond_data]               SL: 0
# (0009, 101c) [PET sel_stop_cond]                 SL: 1
# (0009, 101d) [PET sel_stop_cond_data]            SL: 0
# (0009, 101e) [PET collect_deadtime]              SL: 1
# (0009, 101f) [PET collect_singles]               SL: 1
# (0009, 1020) [PET collect_countrate]             SL: 0
# (0009, 1021) [PET countrate_period]              SL: 1
# (0009, 1022) [PET delayed_events]                SL: 0
# (0009, 1023) [PET delayed_bias]                  SL: 0
# (0009, 1024) [PET word_size]                     SL: 1
# (0009, 1025) [PET axial_acceptance]              SL: 2
# (0009, 1026) [PET axial_angle_3d]                SL: 23
# (0009, 1027) [PET theta_compression]             SL: 1
# (0009, 1028) [PET axial_compression]             SL: 1
# (0009, 1029) [PET gantry_tilt_angle]             FL: 0.0
# (0009, 102a) [PET collimation]                   SL: 0
# (0009, 102b) [PET scan_fov]                      SL: 70
# (0009, 102c) [PET axial_fov]                     SL: 153
# (0009, 102d) [PET event_separation]              SL: 0
# (0009, 102e) [PET mask_width]                    SL: 0
# (0009, 1034) [PET triggers_acquired]             SL: 0
# (0009, 1035) [PET triggers_rejected]             SL: 0
# (0009, 1036) [PET tracer_name]                   LO: 'F- -- Fluorine'
# (0009, 1037) [PET batch_description]             LO: ''
# (0009, 1038) [PET tracer_activity]               FL: 187.5900115966797
# (0009, 1039) [PET meas_datetime]                 DT: ''
# (0009, 103a) [PET pre_inj_volume]                FL: 0.0
# (0009, 103b) [PET admin_datetime]                DT: ''
# (0009, 103c) [PET post_inj_activity]             FL: 9.508999824523926
# (0009, 103d) [PET post_inj_datetime]             DT: ''
# (0009, 103e) [PET radionuclide_name]             SH: '18F'
# (0009, 103f) [PET half_life]                     FL: 6588.0
# (0009, 1040) [PET positron_fraction]             FL: 0.9700000286102295
# (0009, 104d) [PET emission_present]              SL: 0
# (0009, 104e) [PET lower_axial_acc]               SL: 23
# (0009, 104f) [PET upper_axial_acc]               SL: 23
# (0009, 1050) [PET lower_coinc_limit]             SL: 7
# (0009, 1051) [PET upper_coinc_limit]             SL: 7
# (0009, 1052) [PET coinc_delay_offset]            SL: 32
# (0009, 1053) [PET coinc_output_mode]             SL: 800
# (0009, 1054) [PET upper_energy_limit]            SL: 650
# (0009, 1055) [PET lower_energy_limit]            SL: 425
# (0009, 1056) [PET normal_cal_id]                 UI: 3.4.911.0.0.7452303.1.901.1893100274861709659
# (0009, 1057) [PET normal_2d_cal_id]              UI: 3.4.911.0.0.7452303.1.901.2892979316798253024
# (0009, 1059) [PET wc_cal_id]                     UI: 3.4.911.0.0.7452303.1.901.7216891879207058590
# (0009, 105a) [PET derived]                       SL: 0
# (0009, 105c) [PET frame_id]                      UI: 3.4.911.0.0.7452303.1.901.1283288930126092887
# (0009, 105d) [PET scan_id]                       UI: 3.4.911.0.0.7452303.1.901.4694931217595356474
# (0009, 105e) [PET exam_id]                       UI: 3.4.911.0.0.7452303.1.901.2060902001753012630
# (0009, 1066) [PET table_height]                  FL: 150.0
# (0009, 1067) [PET table_z_position]              FL: -214.94700622558594
# (0009, 1068) [PET landmark_datetime]             DT: ''
# (0009, 1069) [PET slice_count]                   SL: 553
# (0009, 106a) [PET start_location]                FL: -214.9199981689453
# (0009, 106b) [PET acq_delay]                     SL: 0
# (0009, 106c) [PET acq_start]                     DT: ''
# (0009, 106d) [PET acq_duration]                  SL: 180
# (0009, 1070) [PET actual_stop_cond]              SL: 0
# (0009, 1073) [PET frame_valid]                   SL: 1
# (0009, 1074) [PET validity_info]                 SL: 255
# (0009, 107c) [PET is_source]                     SL: 0
# (0009, 107d) [PET is_contents]                   SL: 2
# (0009, 107e) [PET is_type]                       SL: 0
# (0009, 107f) [PET is_reference]                  DS: '0.0'
# (0009, 1080) [PET multi_patient]                 SL: 0
# (0009, 1081) [PET number_of_normals]             SL: 0
# (0009, 108b) [PET recon_method]                  SL: 5
# (0009, 108c) [PET attenuation]                   SL: 2
# (0009, 108d) [PET atten_coefficient]             FL: 0.09600000083446503
# (0009, 108e) [PET bp_filter]                     SL: 0
# (0009, 108f) [PET bp_filter_cutoff]              FL: 0.0
# (0009, 1090) [PET bp_filter_order]               SL: 0
# (0009, 1091) [PET bp_center_l]                   FL: 0.0
# (0009, 1092) [PET bp_center_p]                   FL: 0.0
# (0009, 1093) [PET atten_smooth]                  SL: 0
# (0009, 1094) [PET atten_smooth_param]            SL: 0
# (0009, 1095) [PET angle_smooth_param]            SL: 0
# (0009, 1097) [PET trans_scan_id]                 UI: 3.4.911.0.0.7452303.1.901.2245378148777465223
# (0009, 1098) [PET norm_cal_id]                   UI: 3.4.911.0.0.7452303.1.901.1893100274861709659
# (0009, 109a) [PET cac_edge_threshold]            FL: 0.0
# (0009, 109b) [PET cac_skull_offset]              FL: 0.0
# (0009, 109c) [PET emiss_sub_id]                  UI: ''
# (0009, 109d) [PET radial_filter_3d]              SL: 0
# (0009, 109e) [PET radial_cutoff_3d]              FL: 0.0
# (0009, 109f) [PET axial_filter_3d]               SL: 0
# (0009, 10a0) [PET axial_cutoff_3d]               FL: 0.0
# (0009, 10a1) [PET axial_start]                   FL: 0.0
# (0009, 10a2) [PET axial_spacing]                 FL: 0.0
# (0009, 10a3) [PET axial_angles_used]             SL: 0
# (0009, 10a6) [PET slice_number]                  SL: 36
# (0009, 10a7) [PET total_counts]                  FL: 0.0
# (0009, 10ab) [PET bp_center_x]                   FL: -0.0
# (0009, 10ac) [PET bp_center_y]                   FL: 0.0
# (0009, 10ad) [PET trans_frame_id]                UI: ''
# (0009, 10ae) [PET tpluse_frame_id]               UI: ''
# (0009, 10b2) [PET ir_num_iterations]             SL: 0
# (0009, 10b3) [PET ir_num_subsets]                SL: 0
# (0009, 10b4) [PET ir_recon_fov]                  FL: 55.0
# (0009, 10b5) [PET ir_corr_model]                 SL: 0
# (0009, 10b6) [PET ir_loop_filter]                SL: 0
# (0009, 10b7) [PET ir_pre_filt_parm]              FL: 0.0
# (0009, 10b8) [PET ir_loop_filt_parm]             SL: 0
# (0009, 10b9) [PET response_filt_parm]            FL: 0.0
# (0009, 10ba) [PET post_filter]                   SL: 0
# (0009, 10bb) [PET post_filt_parm]                FL: 7.0
# (0009, 10bc) [PET ir_regularize]                 SL: 0
# (0009, 10bd) [PET regularize_parm]               FL: 0.0
# (0009, 10be) [PET ac_bp_filter]                  SL: 0
# (0009, 10bf) [PET ac_bp_filt_cut_off]            FL: 0.0
# (0009, 10c0) [PET ac_bp_filt_order]              SL: 0
# (0009, 10c1) [PET ac_img_smooth]                 SL: 0
# (0009, 10c2) [PET ac_img_smooth_parm]            FL: 0.0
# (0009, 10c3) [PET scatter_method]                SL: 0
# (0009, 10c4) [PET scatter_num_iter]              SL: 0
# (0009, 10c5) [PET scatter_parm]                  FL: 0.0
# (0009, 10c6) [PET seg_qc_parm]                   SL: 0
# (0009, 10c7) [PET overlap]                       SL: 0
# (0009, 10cb) [PET vqc_x_axis_trans]              FL: -0.5840979814529419
# (0009, 10cc) [PET vqc_x_axis_tilt]               FL: 0.0649769976735115
# (0009, 10cd) [PET vqc_y_axis_trans]              FL: -1.4640460014343262
# (0009, 10ce) [PET vqc_y_axis_swivel]             FL: -0.13874100148677826
# (0009, 10cf) [PET vqc_z_axis_trans]              FL: 1.5
# (0009, 10d0) [PET vqc_z_axis_roll]               FL: 0.029458999633789062
# (0009, 10d5) [PET loop_filter_parm]              FL: 0.0
# (0009, 10d6) [PET image_one_loc]                 FL: -64.5
# (0009, 10d7) [PET image_index_loc]               FL: -214.9199981689453
# (0009, 10d8) [PET frame_number]                  SL: 36
# (0009, 10db) [PET ir_z_filter_flag]              SL: 2
# (0009, 10dc) [PET ir_z_filter_ratio]             FL: 4.0
# (0009, 10df) [PET num_of_slices]                 US: 47
# (0009, 10e0) [PET num_of_time_slices]            US: 45
# (0009, 10e2) [PET rest_stress]                   SL: 10
# (0009, 10e5) [PET left shift]                    FL: 0.0
# (0009, 10e6) [PET posterior shift]               FL: 0.0
# (0009, 10e7) [PET superior shift]                FL: 0.0
# (0009, 10e9) [PET acq_bin_dur_percent]           SL: 0
# (0017, 0010) Private Creator                     LO: 'GEMS_PETD_01'
# (0017, 1004) [PET cal_datetime]                  DT: ''
# (0019, 0010) Private Creator                     LO: '20190720150450'
# (0019, 1004) Private tag data                    DT: ''

# %%
# def element_to_tag_str(element, trimmed_element_tag: bool = True, use_pattern: bool = False):
#     # Convert to hexadecimal string format
#     group_str = f"{element.tag.group:04x}"   # Output: '0010'
#     element_str = f"{element.tag.element:04x}" # Output: '0010'

#     if use_pattern:
#         return f"({group_str},.*{element_str[-2:]})"
#     elif trimmed_element_tag:
#         return f"({group_str},{element_str[-2:]})"
#     else:
#         return f"({group_str},{element_str})"

# def get_dict_key_from_element(element, parent_elements: list):
#     parent_elem_str = ''
#     for elem in parent_elements:
#         parent_elem_str += f"{element_to_tag_str(elem)}_"

#     tag_str = element_to_tag_str(element)
    
#     return f"{parent_elem_str}{tag_str}_{element.VR}"

# def get_key_pattern_from_element(element, parent_elements: list):
#     parent_elem_str = ''
#     for elem in parent_elements:
#         parent_elem_str += f"{element_to_tag_str(elem, use_pattern=True)}_"

#     tag_str = element_to_tag_str(element, use_pattern=True)
    
#     return f"{parent_elem_str}{tag_str}_{element.VR}" 

# def get_private_tags_disposition_from_dict(dict_key: str, dict_pattrn: str = ''):
#     found_dict = None
#     for creator in creators:
#         creator_dict = private_tag_dict[creator.lower()]
#         if dict_key in creator_dict:
#             found_dict = creator_dict[dict_key]
#             break

def get_element_block_tag(element, private_block_name=None):
    group_str = f"{element.tag.group:04x}"   # Output: '0010'
    element_str = f"{element.tag.element:04x}" # Output: '0010'

    if private_block_name is None:
        return f"({group_str},{element_str})"
    else:
        return f"({group_str},{private_block_name.lower()},{element_str[-2:]})"

def get_element_block_tag_with_parents(element, private_block_name=None, parent_blocks: list = []):
    parent_block_str = ""
    for idx, parent_tuple in enumerate(parent_blocks):
        parent_block_tag = get_element_block_tag(parent_tuple[0], parent_tuple[1])
        parent_block_str += f"{parent_block_tag}[<{idx}>]"

    element_block_tag = get_element_block_tag(element, private_block_name)
    return f"{parent_block_str}{element_block_tag}_{element.VR}"

def get_dispoistion_val_from_block_tag(block_tag: str, element: pydicom.DataElement):
    private_rules = private_tag_dict.get(block_tag)
    if private_rules is None:
        if element.name.lower() != "private creator":
            print(f"'{block_tag}' not found")
        return 'k'

    return private_rules['private_disposition']

    
def traverse_dataset(dataset, parent_elements=[], is_root=True):
    private_creator_block_name = None
    for elem in dataset:
        tag = elem.tag
        VR = elem.VR
        value = elem.value
        name = elem.name

        # Check if the root element is private
        if is_root:
            if not elem.tag.is_private:
                continue

        if name == "Private Creator":
            private_creator_block_name = value
        elif len(parent_elements) > 0:
            immidiate_parent = parent_elements[-1]
            private_creator_block_name = immidiate_parent[1]
           
        
        # Process the element
        if isinstance(value, Sequence):
            # If the value is a Sequence, recursively traverse each Dataset in the Sequence
            # print(f"Sequence: {name} (Tag: {tag})")
            updated_parent_elements = parent_elements.copy()
            updated_parent_elements.append((elem, private_creator_block_name))
            for i, item in enumerate(value):
                # print(f"  Item {i} (Parent: {name})")
                traverse_dataset(item, parent_elements=updated_parent_elements, is_root=False)
        else:
            # process the data element
            # dict_key = get_dict_key_from_element(elem, parent_elements)
            # key_pattern = get_key_pattern_from_element(elem, parent_elements)
            block_tag = get_element_block_tag_with_parents(elem, private_creator_block_name, parent_elements)
            private_disposition = get_dispoistion_val_from_block_tag(block_tag, elem)
            print(f"{elem.tag}, {elem.name}, {block_tag}, {private_disposition}")
            
            # get_private_tags_disposition_from_dict(dict_key, key_pattern)
            # patterns = create_pattents_from_element(elem, parent_elements)
            # print(patterns)
            print("------------------")

# %%
traverse_dataset(dataset)
# Out:
# (0009, 0010), Private Creator, (0009,gems_petd_01,10)_LO, d
# ------------------
# (0009, 1005), [PET patient_datetime], (0009,gems_petd_01,05)_DT, o
# ------------------
# (0009, 100a), [PET scan_id], (0009,gems_petd_01,0a)_UI, h
# ------------------
# (0009, 100d), [PET scan_datetime], (0009,gems_petd_01,0d)_DT, o
# ------------------
# (0009, 100e), [PET scan_ready], (0009,gems_petd_01,0e)_DT, o
# ------------------
# (0009, 1013), [PET for_identifier], (0009,gems_petd_01,13)_UI, h
# ------------------
# (0009, 1014), [PET landmark_name], (0009,gems_petd_01,14)_LO, k
# ------------------
# (0009, 1015), [PET landmark_abbrev], (0009,gems_petd_01,15)_SH, k
# ------------------
# (0009, 1016), [PET patient_position], (0009,gems_petd_01,16)_SL, k
# ------------------
# (0009, 1017), [PET scan_perspective], (0009,gems_petd_01,17)_SL, k
# ------------------
# (0009, 1018), [PET scan_type], (0009,gems_petd_01,18)_SL, k
# ------------------
# (0009, 1019), [PET scan_mode], (0009,gems_petd_01,19)_SL, k
# ------------------
# (0009, 101a), [PET start_condition], (0009,gems_petd_01,1a)_SL, k
# ------------------
# (0009, 101b), [PET start_cond_data], (0009,gems_petd_01,1b)_SL, k
# ------------------
# (0009, 101c), [PET sel_stop_cond], (0009,gems_petd_01,1c)_SL, k
# ------------------
# (0009, 101d), [PET sel_stop_cond_data], (0009,gems_petd_01,1d)_SL, k
# ------------------
# (0009, 101e), [PET collect_deadtime], (0009,gems_petd_01,1e)_SL, k
# ------------------
# (0009, 101f), [PET collect_singles], (0009,gems_petd_01,1f)_SL, k
# ------------------
# (0009, 1020), [PET collect_countrate], (0009,gems_petd_01,20)_SL, k
# ------------------
# (0009, 1021), [PET countrate_period], (0009,gems_petd_01,21)_SL, k
# ------------------
# (0009, 1022), [PET delayed_events], (0009,gems_petd_01,22)_SL, k
# ------------------
# (0009, 1023), [PET delayed_bias], (0009,gems_petd_01,23)_SL, k
# ------------------
# (0009, 1024), [PET word_size], (0009,gems_petd_01,24)_SL, k
# ------------------
# (0009, 1025), [PET axial_acceptance], (0009,gems_petd_01,25)_SL, k
# ------------------
# (0009, 1026), [PET axial_angle_3d], (0009,gems_petd_01,26)_SL, k
# ------------------
# (0009, 1027), [PET theta_compression], (0009,gems_petd_01,27)_SL, k
# ------------------
# (0009, 1028), [PET axial_compression], (0009,gems_petd_01,28)_SL, k
# ------------------
# (0009, 1029), [PET gantry_tilt_angle], (0009,gems_petd_01,29)_FL, k
# ------------------
# (0009, 102a), [PET collimation], (0009,gems_petd_01,2a)_SL, k
# ------------------
# (0009, 102b), [PET scan_fov], (0009,gems_petd_01,2b)_SL, k
# ------------------
# (0009, 102c), [PET axial_fov], (0009,gems_petd_01,2c)_SL, k
# ------------------
# (0009, 102d), [PET event_separation], (0009,gems_petd_01,2d)_SL, k
# ------------------
# (0009, 102e), [PET mask_width], (0009,gems_petd_01,2e)_SL, k
# ------------------
# (0009, 1034), [PET triggers_acquired], (0009,gems_petd_01,34)_SL, k
# ------------------
# (0009, 1035), [PET triggers_rejected], (0009,gems_petd_01,35)_SL, k
# ------------------
# (0009, 1036), [PET tracer_name], (0009,gems_petd_01,36)_LO, k
# ------------------
# (0009, 1037), [PET batch_description], (0009,gems_petd_01,37)_LO, k
# ------------------
# (0009, 1038), [PET tracer_activity], (0009,gems_petd_01,38)_FL, k
# ------------------
# (0009, 1039), [PET meas_datetime], (0009,gems_petd_01,39)_DT, o
# ------------------
# (0009, 103a), [PET pre_inj_volume], (0009,gems_petd_01,3a)_FL, k
# ------------------
# (0009, 103b), [PET admin_datetime], (0009,gems_petd_01,3b)_DT, o
# ------------------
# (0009, 103c), [PET post_inj_activity], (0009,gems_petd_01,3c)_FL, k
# ------------------
# (0009, 103d), [PET post_inj_datetime], (0009,gems_petd_01,3d)_DT, o
# ------------------
# (0009, 103e), [PET radionuclide_name], (0009,gems_petd_01,3e)_SH, k
# ------------------
# (0009, 103f), [PET half_life], (0009,gems_petd_01,3f)_FL, k
# ------------------
# (0009, 1040), [PET positron_fraction], (0009,gems_petd_01,40)_FL, k
# ------------------
# (0009, 104d), [PET emission_present], (0009,gems_petd_01,4d)_SL, k
# ------------------
# (0009, 104e), [PET lower_axial_acc], (0009,gems_petd_01,4e)_SL, k
# ------------------
# (0009, 104f), [PET upper_axial_acc], (0009,gems_petd_01,4f)_SL, k
# ------------------
# (0009, 1050), [PET lower_coinc_limit], (0009,gems_petd_01,50)_SL, k
# ------------------
# (0009, 1051), [PET upper_coinc_limit], (0009,gems_petd_01,51)_SL, k
# ------------------
# (0009, 1052), [PET coinc_delay_offset], (0009,gems_petd_01,52)_SL, k
# ------------------
# (0009, 1053), [PET coinc_output_mode], (0009,gems_petd_01,53)_SL, k
# ------------------
# (0009, 1054), [PET upper_energy_limit], (0009,gems_petd_01,54)_SL, k
# ------------------
# (0009, 1055), [PET lower_energy_limit], (0009,gems_petd_01,55)_SL, k
# ------------------
# (0009, 1056), [PET normal_cal_id], (0009,gems_petd_01,56)_UI, h
# ------------------
# (0009, 1057), [PET normal_2d_cal_id], (0009,gems_petd_01,57)_UI, h
# ------------------
# (0009, 1059), [PET wc_cal_id], (0009,gems_petd_01,59)_UI, h
# ------------------
# (0009, 105a), [PET derived], (0009,gems_petd_01,5a)_SL, k
# ------------------
# (0009, 105c), [PET frame_id], (0009,gems_petd_01,5c)_UI, h
# ------------------
# (0009, 105d), [PET scan_id], (0009,gems_petd_01,5d)_UI, h
# ------------------
# (0009, 105e), [PET exam_id], (0009,gems_petd_01,5e)_UI, h
# ------------------
# (0009, 1066), [PET table_height], (0009,gems_petd_01,66)_FL, k
# ------------------
# (0009, 1067), [PET table_z_position], (0009,gems_petd_01,67)_FL, k
# ------------------
# (0009, 1068), [PET landmark_datetime], (0009,gems_petd_01,68)_DT, o
# ------------------
# (0009, 1069), [PET slice_count], (0009,gems_petd_01,69)_SL, k
# ------------------
# (0009, 106a), [PET start_location], (0009,gems_petd_01,6a)_FL, k
# ------------------
# (0009, 106b), [PET acq_delay], (0009,gems_petd_01,6b)_SL, k
# ------------------
# (0009, 106c), [PET acq_start], (0009,gems_petd_01,6c)_DT, o
# ------------------
# (0009, 106d), [PET acq_duration], (0009,gems_petd_01,6d)_SL, k
# ------------------
# (0009, 1070), [PET actual_stop_cond], (0009,gems_petd_01,70)_SL, k
# ------------------
# (0009, 1073), [PET frame_valid], (0009,gems_petd_01,73)_SL, k
# ------------------
# (0009, 1074), [PET validity_info], (0009,gems_petd_01,74)_SL, k
# ------------------
# (0009, 107c), [PET is_source], (0009,gems_petd_01,7c)_SL, k
# ------------------
# (0009, 107d), [PET is_contents], (0009,gems_petd_01,7d)_SL, k
# ------------------
# (0009, 107e), [PET is_type], (0009,gems_petd_01,7e)_SL, k
# ------------------
# (0009, 107f), [PET is_reference], (0009,gems_petd_01,7f)_DS, k
# ------------------
# (0009, 1080), [PET multi_patient], (0009,gems_petd_01,80)_SL, k
# ------------------
# (0009, 1081), [PET number_of_normals], (0009,gems_petd_01,81)_SL, k
# ------------------
# (0009, 108b), [PET recon_method], (0009,gems_petd_01,8b)_SL, k
# ------------------
# (0009, 108c), [PET attenuation], (0009,gems_petd_01,8c)_SL, k
# ------------------
# (0009, 108d), [PET atten_coefficient], (0009,gems_petd_01,8d)_FL, k
# ------------------
# (0009, 108e), [PET bp_filter], (0009,gems_petd_01,8e)_SL, k
# ------------------
# (0009, 108f), [PET bp_filter_cutoff], (0009,gems_petd_01,8f)_FL, k
# ------------------
# (0009, 1090), [PET bp_filter_order], (0009,gems_petd_01,90)_SL, k
# ------------------
# (0009, 1091), [PET bp_center_l], (0009,gems_petd_01,91)_FL, k
# ------------------
# (0009, 1092), [PET bp_center_p], (0009,gems_petd_01,92)_FL, k
# ------------------
# (0009, 1093), [PET atten_smooth], (0009,gems_petd_01,93)_SL, k
# ------------------
# (0009, 1094), [PET atten_smooth_param], (0009,gems_petd_01,94)_SL, k
# ------------------
# (0009, 1095), [PET angle_smooth_param], (0009,gems_petd_01,95)_SL, k
# ------------------
# (0009, 1097), [PET trans_scan_id], (0009,gems_petd_01,97)_UI, h
# ------------------
# (0009, 1098), [PET norm_cal_id], (0009,gems_petd_01,98)_UI, h
# ------------------
# (0009, 109a), [PET cac_edge_threshold], (0009,gems_petd_01,9a)_FL, k
# ------------------
# (0009, 109b), [PET cac_skull_offset], (0009,gems_petd_01,9b)_FL, k
# ------------------
# (0009, 109c), [PET emiss_sub_id], (0009,gems_petd_01,9c)_UI, h
# ------------------
# (0009, 109d), [PET radial_filter_3d], (0009,gems_petd_01,9d)_SL, k
# ------------------
# (0009, 109e), [PET radial_cutoff_3d], (0009,gems_petd_01,9e)_FL, k
# ------------------
# (0009, 109f), [PET axial_filter_3d], (0009,gems_petd_01,9f)_SL, k
# ------------------
# (0009, 10a0), [PET axial_cutoff_3d], (0009,gems_petd_01,a0)_FL, k
# ------------------
# (0009, 10a1), [PET axial_start], (0009,gems_petd_01,a1)_FL, k
# ------------------
# (0009, 10a2), [PET axial_spacing], (0009,gems_petd_01,a2)_FL, k
# ------------------
# (0009, 10a3), [PET axial_angles_used], (0009,gems_petd_01,a3)_SL, k
# ------------------
# (0009, 10a6), [PET slice_number], (0009,gems_petd_01,a6)_SL, k
# ------------------
# (0009, 10a7), [PET total_counts], (0009,gems_petd_01,a7)_FL, k
# ------------------
# (0009, 10ab), [PET bp_center_x], (0009,gems_petd_01,ab)_FL, k
# ------------------
# (0009, 10ac), [PET bp_center_y], (0009,gems_petd_01,ac)_FL, k
# ------------------
# (0009, 10ad), [PET trans_frame_id], (0009,gems_petd_01,ad)_UI, h
# ------------------
# (0009, 10ae), [PET tpluse_frame_id], (0009,gems_petd_01,ae)_UI, k
# ------------------
# (0009, 10b2), [PET ir_num_iterations], (0009,gems_petd_01,b2)_SL, k
# ------------------
# (0009, 10b3), [PET ir_num_subsets], (0009,gems_petd_01,b3)_SL, k
# ------------------
# (0009, 10b4), [PET ir_recon_fov], (0009,gems_petd_01,b4)_FL, k
# ------------------
# (0009, 10b5), [PET ir_corr_model], (0009,gems_petd_01,b5)_SL, k
# ------------------
# (0009, 10b6), [PET ir_loop_filter], (0009,gems_petd_01,b6)_SL, k
# ------------------
# (0009, 10b7), [PET ir_pre_filt_parm], (0009,gems_petd_01,b7)_FL, k
# ------------------
# (0009, 10b8), [PET ir_loop_filt_parm], (0009,gems_petd_01,b8)_SL, k
# ------------------
# (0009, 10b9), [PET response_filt_parm], (0009,gems_petd_01,b9)_FL, k
# ------------------
# (0009, 10ba), [PET post_filter], (0009,gems_petd_01,ba)_SL, k
# ------------------
# (0009, 10bb), [PET post_filt_parm], (0009,gems_petd_01,bb)_FL, k
# ------------------
# (0009, 10bc), [PET ir_regularize], (0009,gems_petd_01,bc)_SL, k
# ------------------
# (0009, 10bd), [PET regularize_parm], (0009,gems_petd_01,bd)_FL, k
# ------------------
# (0009, 10be), [PET ac_bp_filter], (0009,gems_petd_01,be)_SL, k
# ------------------
# (0009, 10bf), [PET ac_bp_filt_cut_off], (0009,gems_petd_01,bf)_FL, k
# ------------------
# (0009, 10c0), [PET ac_bp_filt_order], (0009,gems_petd_01,c0)_SL, k
# ------------------
# (0009, 10c1), [PET ac_img_smooth], (0009,gems_petd_01,c1)_SL, k
# ------------------
# (0009, 10c2), [PET ac_img_smooth_parm], (0009,gems_petd_01,c2)_FL, k
# ------------------
# (0009, 10c3), [PET scatter_method], (0009,gems_petd_01,c3)_SL, k
# ------------------
# (0009, 10c4), [PET scatter_num_iter], (0009,gems_petd_01,c4)_SL, k
# ------------------
# (0009, 10c5), [PET scatter_parm], (0009,gems_petd_01,c5)_FL, k
# ------------------
# (0009, 10c6), [PET seg_qc_parm], (0009,gems_petd_01,c6)_SL, k
# ------------------
# (0009, 10c7), [PET overlap], (0009,gems_petd_01,c7)_SL, k
# ------------------
# (0009, 10cb), [PET vqc_x_axis_trans], (0009,gems_petd_01,cb)_FL, k
# ------------------
# (0009, 10cc), [PET vqc_x_axis_tilt], (0009,gems_petd_01,cc)_FL, k
# ------------------
# (0009, 10cd), [PET vqc_y_axis_trans], (0009,gems_petd_01,cd)_FL, k
# ------------------
# (0009, 10ce), [PET vqc_y_axis_swivel], (0009,gems_petd_01,ce)_FL, k
# ------------------
# (0009, 10cf), [PET vqc_z_axis_trans], (0009,gems_petd_01,cf)_FL, k
# ------------------
# (0009, 10d0), [PET vqc_z_axis_roll], (0009,gems_petd_01,d0)_FL, k
# ------------------
# (0009, 10d5), [PET loop_filter_parm], (0009,gems_petd_01,d5)_FL, k
# ------------------
# (0009, 10d6), [PET image_one_loc], (0009,gems_petd_01,d6)_FL, k
# ------------------
# (0009, 10d7), [PET image_index_loc], (0009,gems_petd_01,d7)_FL, k
# ------------------
# (0009, 10d8), [PET frame_number], (0009,gems_petd_01,d8)_SL, k
# ------------------
# (0009, 10db), [PET ir_z_filter_flag], (0009,gems_petd_01,db)_SL, k
# ------------------
# (0009, 10dc), [PET ir_z_filter_ratio], (0009,gems_petd_01,dc)_FL, k
# ------------------
# (0009, 10df), [PET num_of_slices], (0009,gems_petd_01,df)_US, k
# ------------------
# (0009, 10e0), [PET num_of_time_slices], (0009,gems_petd_01,e0)_US, k
# ------------------
# (0009, 10e2), [PET rest_stress], (0009,gems_petd_01,e2)_SL, k
# ------------------
# (0009, 10e5), [PET left shift], (0009,gems_petd_01,e5)_FL, k
# ------------------
# (0009, 10e6), [PET posterior shift], (0009,gems_petd_01,e6)_FL, k
# ------------------
# (0009, 10e7), [PET superior shift], (0009,gems_petd_01,e7)_FL, k
# ------------------
# (0009, 10e9), [PET acq_bin_dur_percent], (0009,gems_petd_01,e9)_SL, k
# ------------------
# (0017, 0010), Private Creator, (0017,gems_petd_01,10)_LO, k
# ------------------
# (0017, 1004), [PET cal_datetime], (0017,gems_petd_01,04)_DT, o
# ------------------
# (0019, 0010), Private Creator, (0019,20190720150450,10)_LO, k
# ------------------
# (0019, 1004), Private tag data, (0019,20190720150450,04)_DT, d
# ------------------
