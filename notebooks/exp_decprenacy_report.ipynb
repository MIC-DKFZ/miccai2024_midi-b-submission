# %%
import pandas as pd
from pprint import pprint

# %%
report_path = '/home/r079a/Desktop/de-identification/dataset/midi-validation-data/output_data_tcia_private_tags_06/discrepancy_report_participant.csv'

# %%
report_df = pd.read_csv(report_path)

# %%
report_df
# Out:
#          index  check_passed  check_score         tag_ds  \
# 0          168             0          0.0  <(0012,0051)>
# 1          363             0          0.0  <(0012,0051)>
# 2          558             0          0.0  <(0012,0051)>
# 3          753             0          0.0  <(0012,0051)>
# 4          948             0          0.0  <(0012,0051)>
# ...        ...           ...          ...            ...
# 26610  6172313             0          0.0  <(0012,0051)>
# 26611  6172527             0          0.0  <(0012,0051)>
# 26612  6172741             0          0.0  <(0012,0051)>
# 26613  6172955             0          0.0  <(0012,0051)>
# 26614  6173169             0          0.0  <(0012,0051)>
#
#                                       tag_name                    file_value  \
# 0      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 1      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 2      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 3      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 4      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# ...                                        ...                           ...
# 26610  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 26611  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 26612  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 26613  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 26614  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
#
#                        answer_value          action  \
# 0      <Days offset from diagnosis>  <text_removed>
# 1      <Days offset from diagnosis>  <text_removed>
# 2      <Days offset from diagnosis>  <text_removed>
# 3      <Days offset from diagnosis>  <text_removed>
# 4      <Days offset from diagnosis>  <text_removed>
# ...                             ...             ...
# 26610  <Days offset from diagnosis>  <text_removed>
# 26611  <Days offset from diagnosis>  <text_removed>
# 26612  <Days offset from diagnosis>  <text_removed>
# 26613  <Days offset from diagnosis>  <text_removed>
# 26614  <Days offset from diagnosis>  <text_removed>
#
#                         action_text category      subcategory modality  \
# 0      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# 1      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# 2      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# 3      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# 4      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# ...                             ...      ...              ...      ...
# 26610  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 26611  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 26612  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 26613  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 26614  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
#
#                                class           patient  \
# 0        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# 1        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# 2        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# 3        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# 4        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# ...                              ...               ...
# 26610  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
# 26611  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
# 26612  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
# 26613  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
# 26614  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
#
#                                                    study  \
# 0      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# 1      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# 2      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# 3      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# 4      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# ...                                                  ...
# 26610  <1.2.826.0.1.3680043.8.498.1335144844187578048...
# 26611  <1.2.826.0.1.3680043.8.498.1335144844187578048...
# 26612  <1.2.826.0.1.3680043.8.498.1335144844187578048...
# 26613  <1.2.826.0.1.3680043.8.498.1335144844187578048...
# 26614  <1.2.826.0.1.3680043.8.498.1335144844187578048...
#
#                                                   series  \
# 0      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# 1      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# 2      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# 3      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# 4      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# ...                                                  ...
# 26610  <1.2.826.0.1.3680043.8.498.7837430973606737012...
# 26611  <1.2.826.0.1.3680043.8.498.7837430973606737012...
# 26612  <1.2.826.0.1.3680043.8.498.7837430973606737012...
# 26613  <1.2.826.0.1.3680043.8.498.7837430973606737012...
# 26614  <1.2.826.0.1.3680043.8.498.7837430973606737012...
#
#                                                 instance       file_name
# 0      <1.2.826.0.1.3680043.8.498.9051348305064708278...  <00000047.dcm>
# 1      <1.2.826.0.1.3680043.8.498.4934817474968831648...  <00000053.dcm>
# 2      <1.2.826.0.1.3680043.8.498.2566888822188840988...  <00000084.dcm>
# 3      <1.2.826.0.1.3680043.8.498.1192406619679474748...  <00000090.dcm>
# 4      <1.2.826.0.1.3680043.8.498.2238372871777685852...  <00000091.dcm>
# ...                                                  ...             ...
# 26610  <1.2.826.0.1.3680043.8.498.1244558540776177145...  <00001148.dcm>
# 26611  <1.2.826.0.1.3680043.8.498.9605138307693723995...  <00000256.dcm>
# 26612  <1.2.826.0.1.3680043.8.498.9474358496365754257...  <00000530.dcm>
# 26613  <1.2.826.0.1.3680043.8.498.5401665236300063982...  <00000901.dcm>
# 26614  <1.2.826.0.1.3680043.8.498.9424628047897647490...  <00000915.dcm>
#
# [26615 rows x 18 columns]

# %%
report_df['tag_name'].value_counts().head(50)
# Out:
# tag_name
# <Clinical Trial Time Point Description>    17645
# <Study Description>                         1714
# <Protocol Name>                             1634
# <Series Description>                        1341
# <Position Reference Indicator>               878
# <KVP>                                        601
# <Acquisition Number>                         601
# <[PET batch_description]>                    547
# <Requested Procedure Comments>               353
# <Additional Patient History>                 280
# <Derivation Description>                     214
# <Scheduled Procedure Step Description>       177
# <Performed Procedure Step Description>       126
# <Requested Procedure Description>             98
# <[Actual series data time stamp]>             68
# <Presentation LUT Shape>                      50
# <Presentation Intent Type>                    50
# <Referenced SOP Class UID>                    45
# <[PET countrate_period]>                      35
# <[PET collimation]>                           35
# <Text Value>                                  27
# <Referenced Segment Number>                   10
# <Verifying Organization>                      10
# <Comments on Radiation Dose>                   8
# <Image Laterality>                             8
# <Detector Type>                                6
# <Detector ID>                                  5
# <Series Number>                                4
# <Image Comments>                               4
# <Graphic Data>                                 4
# <Coding Scheme UID>                            4
# <Reason for Study>                             3
# <Reason for the Requested Procedure>           2
# <Contrast/Bolus Agent>                         2
# <View Position>                                1
# <Gantry ID>                                    1
# Name: count, dtype: int64

# %% [markdown]
# #### Priority List:
#
# * `<[Actual series data time stamp]>` covered
# * `<Clinical Trial Sponsor Name>`, // need to verify if it required in custom rules
# * `<Scheduled Procedure Step ID>`, // need to verify if it is required in custom rules
# * `<[Suite id]>` // Private tags needs to search with creators
# * `<Mapping Resource UID>` // Covered, added to custom rules
# * `<Code Value>` // Covered, by only checking element with Date(Time)? in its name
# * `<Requested Procedure Comments>` // MRI BREAST getting removed
# * `<KVP>` // not present in the original dataset
# * `<Acquisition Number> ` // not present in the original dataset
# * `<Referenced SOP Class UID>` // tag not present in the original dataset
# * `<Position Reference Indicator>` // tag not present in the original dataset
# * `<Presentation Intent Type>` // Tag not present in the original dataset
# * `<Presentation LUT Shape>` // Tag not present in the original dataset

# %%
report_df[(report_df['patient'] == '<Pseudo-PHI-013>') & (report_df['file_name'] == '<00000098.dcm>')]
# Out:
#        index  check_passed  check_score         tag_ds  \
# 2410  827494             0          0.0  <(0020,1040)>
#
#                             tag_name file_value answer_value          action  \
# 2410  <Position Reference Indicator>        NaN          NaN  <tag_retained>
#
#      action_text category  subcategory modality                        class  \
# 2410         NaN    dicom  DICOM-IOD-2     <MR>  <1.2.840.10008.5.1.4.1.1.4>
#
#                patient                                              study  \
# 2410  <Pseudo-PHI-013>  <1.2.826.0.1.3680043.8.498.7391429258473033697...
#
#                                                  series  \
# 2410  <1.2.826.0.1.3680043.8.498.5235983570443929011...
#
#                                                instance       file_name
# 2410  <1.2.826.0.1.3680043.8.498.1125780429296355802...  <00000098.dcm>

# %%
report_df[(report_df['tag_name'] == '<Presentation Intent Type>')]
# Out:
#          index  check_passed  check_score         tag_ds  \
# 36        7055             0          0.0  <(0008,0068)>
# 38        7080             0          0.0  <(0008,0068)>
# 3886   1058760             0          0.0  <(0008,0068)>
# 3888   1058785             0          0.0  <(0008,0068)>
# 3890   1058925             0          0.0  <(0008,0068)>
# 3892   1058950             0          0.0  <(0008,0068)>
# 3894   1059061             0          0.0  <(0008,0068)>
# 3896   1059086             0          0.0  <(0008,0068)>
# 4097   1133923             0          0.0  <(0008,0068)>
# 4100   1133950             0          0.0  <(0008,0068)>
# 4102   1134076             0          0.0  <(0008,0068)>
# 4105   1134103             0          0.0  <(0008,0068)>
# 5035   1295613             0          0.0  <(0008,0068)>
# 5037   1295638             0          0.0  <(0008,0068)>
# 13784  3600793             0          0.0  <(0008,0068)>
# 13787  3600820             0          0.0  <(0008,0068)>
# 14121  3667500             0          0.0  <(0008,0068)>
# 14124  3667527             0          0.0  <(0008,0068)>
# 15258  4069021             0          0.0  <(0008,0068)>
# 15261  4069046             0          0.0  <(0008,0068)>
# 15263  4069176             0          0.0  <(0008,0068)>
# 15266  4069201             0          0.0  <(0008,0068)>
# 15268  4069335             0          0.0  <(0008,0068)>
# 15271  4069360             0          0.0  <(0008,0068)>
# 15978  4304180             0          0.0  <(0008,0068)>
# 15980  4304205             0          0.0  <(0008,0068)>
# 17034  4516357             0          0.0  <(0008,0068)>
# 17036  4516382             0          0.0  <(0008,0068)>
# 17039  4516492             0          0.0  <(0008,0068)>
# 17041  4516517             0          0.0  <(0008,0068)>
# 17402  4591327             0          0.0  <(0008,0068)>
# 17404  4591352             0          0.0  <(0008,0068)>
# 17416  4595549             0          0.0  <(0008,0068)>
# 17418  4595574             0          0.0  <(0008,0068)>
# 18464  4833866             0          0.0  <(0008,0068)>
# 18467  4833893             0          0.0  <(0008,0068)>
# 18469  4834021             0          0.0  <(0008,0068)>
# 18472  4834048             0          0.0  <(0008,0068)>
# 19907  5071407             0          0.0  <(0008,0068)>
# 19909  5071432             0          0.0  <(0008,0068)>
# 21313  5239003             0          0.0  <(0008,0068)>
# 21315  5239028             0          0.0  <(0008,0068)>
# 21513  5286815             0          0.0  <(0008,0068)>
# 21515  5286840             0          0.0  <(0008,0068)>
# 21519  5287353             0          0.0  <(0008,0068)>
# 21521  5287378             0          0.0  <(0008,0068)>
# 21523  5287588             0          0.0  <(0008,0068)>
# 21525  5287613             0          0.0  <(0008,0068)>
# 21527  5287724             0          0.0  <(0008,0068)>
# 21529  5287749             0          0.0  <(0008,0068)>
#
#                          tag_name file_value answer_value          action  \
# 36     <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 38     <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 3886   <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 3888   <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 3890   <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 3892   <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 3894   <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 3896   <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 4097   <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 4100   <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 4102   <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 4105   <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 5035   <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 5037   <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 13784  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 13787  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 14121  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 14124  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 15258  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 15261  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 15263  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 15266  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 15268  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 15271  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 15978  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 15980  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 17034  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 17036  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 17039  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 17041  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 17402  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 17404  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 17416  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 17418  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 18464  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 18467  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 18469  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 18472  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 19907  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 19909  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 21313  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 21315  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 21513  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 21515  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 21519  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 21521  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 21523  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 21525  <Presentation Intent Type>        NaN          NaN  <text_notnull>
# 21527  <Presentation Intent Type>        NaN          NaN  <tag_retained>
# 21529  <Presentation Intent Type>        NaN          NaN  <text_notnull>
#
#       action_text category  subcategory modality  \
# 36            NaN    dicom  DICOM-IOD-1     <DX>
# 38            NaN    dicom  DICOM-IOD-1     <DX>
# 3886          NaN    dicom  DICOM-IOD-1     <DX>
# 3888          NaN    dicom  DICOM-IOD-1     <DX>
# 3890          NaN    dicom  DICOM-IOD-1     <DX>
# 3892          NaN    dicom  DICOM-IOD-1     <DX>
# 3894          NaN    dicom  DICOM-IOD-1     <DX>
# 3896          NaN    dicom  DICOM-IOD-1     <DX>
# 4097          NaN    dicom  DICOM-IOD-1     <DX>
# 4100          NaN    dicom  DICOM-IOD-1     <DX>
# 4102          NaN    dicom  DICOM-IOD-1     <DX>
# 4105          NaN    dicom  DICOM-IOD-1     <DX>
# 5035          NaN    dicom  DICOM-IOD-1     <DX>
# 5037          NaN    dicom  DICOM-IOD-1     <DX>
# 13784         NaN    dicom  DICOM-IOD-1     <DX>
# 13787         NaN    dicom  DICOM-IOD-1     <DX>
# 14121         NaN    dicom  DICOM-IOD-1     <DX>
# 14124         NaN    dicom  DICOM-IOD-1     <DX>
# 15258         NaN    dicom  DICOM-IOD-1     <DX>
# 15261         NaN    dicom  DICOM-IOD-1     <DX>
# 15263         NaN    dicom  DICOM-IOD-1     <DX>
# 15266         NaN    dicom  DICOM-IOD-1     <DX>
# 15268         NaN    dicom  DICOM-IOD-1     <DX>
# 15271         NaN    dicom  DICOM-IOD-1     <DX>
# 15978         NaN    dicom  DICOM-IOD-1     <DX>
# 15980         NaN    dicom  DICOM-IOD-1     <DX>
# 17034         NaN    dicom  DICOM-IOD-1     <DX>
# 17036         NaN    dicom  DICOM-IOD-1     <DX>
# 17039         NaN    dicom  DICOM-IOD-1     <DX>
# 17041         NaN    dicom  DICOM-IOD-1     <DX>
# 17402         NaN    dicom  DICOM-IOD-1     <DX>
# 17404         NaN    dicom  DICOM-IOD-1     <DX>
# 17416         NaN    dicom  DICOM-IOD-1     <DX>
# 17418         NaN    dicom  DICOM-IOD-1     <DX>
# 18464         NaN    dicom  DICOM-IOD-1     <DX>
# 18467         NaN    dicom  DICOM-IOD-1     <DX>
# 18469         NaN    dicom  DICOM-IOD-1     <DX>
# 18472         NaN    dicom  DICOM-IOD-1     <DX>
# 19907         NaN    dicom  DICOM-IOD-1     <DX>
# 19909         NaN    dicom  DICOM-IOD-1     <DX>
# 21313         NaN    dicom  DICOM-IOD-1     <DX>
# 21315         NaN    dicom  DICOM-IOD-1     <DX>
# 21513         NaN    dicom  DICOM-IOD-1     <DX>
# 21515         NaN    dicom  DICOM-IOD-1     <DX>
# 21519         NaN    dicom  DICOM-IOD-1     <DX>
# 21521         NaN    dicom  DICOM-IOD-1     <DX>
# 21523         NaN    dicom  DICOM-IOD-1     <DX>
# 21525         NaN    dicom  DICOM-IOD-1     <DX>
# 21527         NaN    dicom  DICOM-IOD-1     <DX>
# 21529         NaN    dicom  DICOM-IOD-1     <DX>
#
#                                class           patient  \
# 36     <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 38     <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 3886   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-028>
# 3888   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-028>
# 3890   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-028>
# 3892   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-028>
# 3894   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-028>
# 3896   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-028>
# 4097   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-023>
# 4100   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-023>
# 4102   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-023>
# 4105   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-023>
# 5035   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-042>
# 5037   <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-042>
# 13784  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-077>
# 13787  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-077>
# 14121  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-077>
# 14124  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-077>
# 15258  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-093>
# 15261  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-093>
# 15263  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-093>
# 15266  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-093>
# 15268  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-093>
# 15271  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-093>
# 15978  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-110>
# 15980  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-110>
# 17034  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-124>
# 17036  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-124>
# 17039  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-124>
# 17041  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-124>
# 17402  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-130>
# 17404  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-130>
# 17416  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-134>
# 17418  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-134>
# 18464  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-157>
# 18467  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-157>
# 18469  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-157>
# 18472  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-157>
# 19907  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-170>
# 19909  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-170>
# 21313  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-193>
# 21315  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-193>
# 21513  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-180>
# 21515  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-180>
# 21519  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-183>
# 21521  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-183>
# 21523  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-185>
# 21525  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-185>
# 21527  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-185>
# 21529  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-185>
#
#                                                    study  \
# 36     <1.2.826.0.1.3680043.8.498.5827023641732231903...
# 38     <1.2.826.0.1.3680043.8.498.5827023641732231903...
# 3886   <1.2.826.0.1.3680043.8.498.7724762914695360464...
# 3888   <1.2.826.0.1.3680043.8.498.7724762914695360464...
# 3890   <1.2.826.0.1.3680043.8.498.7034774253100631056...
# 3892   <1.2.826.0.1.3680043.8.498.7034774253100631056...
# 3894   <1.2.826.0.1.3680043.8.498.5143537391059801681...
# 3896   <1.2.826.0.1.3680043.8.498.5143537391059801681...
# 4097   <1.2.826.0.1.3680043.8.498.5545290878073090578...
# 4100   <1.2.826.0.1.3680043.8.498.5545290878073090578...
# 4102   <1.2.826.0.1.3680043.8.498.5545290878073090578...
# 4105   <1.2.826.0.1.3680043.8.498.5545290878073090578...
# 5035   <1.2.826.0.1.3680043.8.498.4468860098150826163...
# 5037   <1.2.826.0.1.3680043.8.498.4468860098150826163...
# 13784  <1.2.826.0.1.3680043.8.498.1236985781740126887...
# 13787  <1.2.826.0.1.3680043.8.498.1236985781740126887...
# 14121  <1.2.826.0.1.3680043.8.498.1236985781740126887...
# 14124  <1.2.826.0.1.3680043.8.498.1236985781740126887...
# 15258  <1.2.826.0.1.3680043.8.498.7378167850127630665...
# 15261  <1.2.826.0.1.3680043.8.498.7378167850127630665...
# 15263  <1.2.826.0.1.3680043.8.498.7378167850127630665...
# 15266  <1.2.826.0.1.3680043.8.498.7378167850127630665...
# 15268  <1.2.826.0.1.3680043.8.498.7378167850127630665...
# 15271  <1.2.826.0.1.3680043.8.498.7378167850127630665...
# 15978  <1.2.826.0.1.3680043.8.498.8192469584648757237...
# 15980  <1.2.826.0.1.3680043.8.498.8192469584648757237...
# 17034  <1.2.826.0.1.3680043.8.498.1241097440305801989...
# 17036  <1.2.826.0.1.3680043.8.498.1241097440305801989...
# 17039  <1.2.826.0.1.3680043.8.498.9726391608999689994...
# 17041  <1.2.826.0.1.3680043.8.498.9726391608999689994...
# 17402  <1.2.826.0.1.3680043.8.498.1215342847430181293...
# 17404  <1.2.826.0.1.3680043.8.498.1215342847430181293...
# 17416  <1.2.826.0.1.3680043.8.498.7865563377780194264...
# 17418  <1.2.826.0.1.3680043.8.498.7865563377780194264...
# 18464  <1.2.826.0.1.3680043.8.498.9985151081384113816...
# 18467  <1.2.826.0.1.3680043.8.498.9985151081384113816...
# 18469  <1.2.826.0.1.3680043.8.498.9985151081384113816...
# 18472  <1.2.826.0.1.3680043.8.498.9985151081384113816...
# 19907  <1.2.826.0.1.3680043.8.498.1692821537994570932...
# 19909  <1.2.826.0.1.3680043.8.498.1692821537994570932...
# 21313  <1.2.826.0.1.3680043.8.498.2439020839689651061...
# 21315  <1.2.826.0.1.3680043.8.498.2439020839689651061...
# 21513  <1.2.826.0.1.3680043.8.498.4180311968724202725...
# 21515  <1.2.826.0.1.3680043.8.498.4180311968724202725...
# 21519  <1.2.826.0.1.3680043.8.498.2176459599691716362...
# 21521  <1.2.826.0.1.3680043.8.498.2176459599691716362...
# 21523  <1.2.826.0.1.3680043.8.498.1218831318308663626...
# 21525  <1.2.826.0.1.3680043.8.498.1218831318308663626...
# 21527  <1.2.826.0.1.3680043.8.498.1218831318308663626...
# 21529  <1.2.826.0.1.3680043.8.498.1218831318308663626...
#
#                                                   series  \
# 36     <1.2.826.0.1.3680043.8.498.4285501952439855590...
# 38     <1.2.826.0.1.3680043.8.498.4285501952439855590...
# 3886   <1.2.826.0.1.3680043.8.498.3923894919820484261...
# 3888   <1.2.826.0.1.3680043.8.498.3923894919820484261...
# 3890   <1.2.826.0.1.3680043.8.498.4554150814997752175...
# 3892   <1.2.826.0.1.3680043.8.498.4554150814997752175...
# 3894   <1.2.826.0.1.3680043.8.498.8622664136742832748...
# 3896   <1.2.826.0.1.3680043.8.498.8622664136742832748...
# 4097   <1.2.826.0.1.3680043.8.498.1261519804810771773...
# 4100   <1.2.826.0.1.3680043.8.498.1261519804810771773...
# 4102   <1.2.826.0.1.3680043.8.498.1261519804810771773...
# 4105   <1.2.826.0.1.3680043.8.498.1261519804810771773...
# 5035   <1.2.826.0.1.3680043.8.498.9417105740465047448...
# 5037   <1.2.826.0.1.3680043.8.498.9417105740465047448...
# 13784  <1.2.826.0.1.3680043.8.498.9773843017160904737...
# 13787  <1.2.826.0.1.3680043.8.498.9773843017160904737...
# 14121  <1.2.826.0.1.3680043.8.498.9773843017160904737...
# 14124  <1.2.826.0.1.3680043.8.498.9773843017160904737...
# 15258  <1.2.826.0.1.3680043.8.498.6802206120901560292...
# 15261  <1.2.826.0.1.3680043.8.498.6802206120901560292...
# 15263  <1.2.826.0.1.3680043.8.498.7230796066650468531...
# 15266  <1.2.826.0.1.3680043.8.498.7230796066650468531...
# 15268  <1.2.826.0.1.3680043.8.498.1283939882911706752...
# 15271  <1.2.826.0.1.3680043.8.498.1283939882911706752...
# 15978  <1.2.826.0.1.3680043.8.498.4809529574742391994...
# 15980  <1.2.826.0.1.3680043.8.498.4809529574742391994...
# 17034  <1.2.826.0.1.3680043.8.498.2953994660242571872...
# 17036  <1.2.826.0.1.3680043.8.498.2953994660242571872...
# 17039  <1.2.826.0.1.3680043.8.498.5203461275269967180...
# 17041  <1.2.826.0.1.3680043.8.498.5203461275269967180...
# 17402  <1.2.826.0.1.3680043.8.498.1689225017349928393...
# 17404  <1.2.826.0.1.3680043.8.498.1689225017349928393...
# 17416  <1.2.826.0.1.3680043.8.498.7429030734139761937...
# 17418  <1.2.826.0.1.3680043.8.498.7429030734139761937...
# 18464  <1.2.826.0.1.3680043.8.498.1080832397661198978...
# 18467  <1.2.826.0.1.3680043.8.498.1080832397661198978...
# 18469  <1.2.826.0.1.3680043.8.498.1080832397661198978...
# 18472  <1.2.826.0.1.3680043.8.498.1080832397661198978...
# 19907  <1.2.826.0.1.3680043.8.498.5241051075096790394...
# 19909  <1.2.826.0.1.3680043.8.498.5241051075096790394...
# 21313  <1.2.826.0.1.3680043.8.498.9691360486847411337...
# 21315  <1.2.826.0.1.3680043.8.498.9691360486847411337...
# 21513  <1.2.826.0.1.3680043.8.498.6948476725982679255...
# 21515  <1.2.826.0.1.3680043.8.498.6948476725982679255...
# 21519  <1.2.826.0.1.3680043.8.498.1253876044793644638...
# 21521  <1.2.826.0.1.3680043.8.498.1253876044793644638...
# 21523  <1.2.826.0.1.3680043.8.498.4410329635952461175...
# 21525  <1.2.826.0.1.3680043.8.498.4410329635952461175...
# 21527  <1.2.826.0.1.3680043.8.498.4410329635952461175...
# 21529  <1.2.826.0.1.3680043.8.498.4410329635952461175...
#
#                                                 instance       file_name
# 36     <1.2.826.0.1.3680043.8.498.1169463787369508988...  <00000001.dcm>
# 38     <1.2.826.0.1.3680043.8.498.1169463787369508988...  <00000001.dcm>
# 3886   <1.2.826.0.1.3680043.8.498.2242443291322280586...  <00000001.dcm>
# 3888   <1.2.826.0.1.3680043.8.498.2242443291322280586...  <00000001.dcm>
# 3890   <1.2.826.0.1.3680043.8.498.8430998371217520140...  <00000001.dcm>
# 3892   <1.2.826.0.1.3680043.8.498.8430998371217520140...  <00000001.dcm>
# 3894   <1.2.826.0.1.3680043.8.498.7502217944391810557...  <00000001.dcm>
# 3896   <1.2.826.0.1.3680043.8.498.7502217944391810557...  <00000001.dcm>
# 4097   <1.2.826.0.1.3680043.8.498.5650268554686469506...  <00000001.dcm>
# 4100   <1.2.826.0.1.3680043.8.498.5650268554686469506...  <00000001.dcm>
# 4102   <1.2.826.0.1.3680043.8.498.4073911606249969722...  <00000002.dcm>
# 4105   <1.2.826.0.1.3680043.8.498.4073911606249969722...  <00000002.dcm>
# 5035   <1.2.826.0.1.3680043.8.498.1086099911907777083...  <00000001.dcm>
# 5037   <1.2.826.0.1.3680043.8.498.1086099911907777083...  <00000001.dcm>
# 13784  <1.2.826.0.1.3680043.8.498.5952181932292153270...  <00000002.dcm>
# 13787  <1.2.826.0.1.3680043.8.498.5952181932292153270...  <00000002.dcm>
# 14121  <1.2.826.0.1.3680043.8.498.1039739687196238606...  <00000001.dcm>
# 14124  <1.2.826.0.1.3680043.8.498.1039739687196238606...  <00000001.dcm>
# 15258  <1.2.826.0.1.3680043.8.498.9269506029226554523...  <00000001.dcm>
# 15261  <1.2.826.0.1.3680043.8.498.9269506029226554523...  <00000001.dcm>
# 15263  <1.2.826.0.1.3680043.8.498.6469762126472926685...  <00000001.dcm>
# 15266  <1.2.826.0.1.3680043.8.498.6469762126472926685...  <00000001.dcm>
# 15268  <1.2.826.0.1.3680043.8.498.9092036977465612075...  <00000001.dcm>
# 15271  <1.2.826.0.1.3680043.8.498.9092036977465612075...  <00000001.dcm>
# 15978  <1.2.826.0.1.3680043.8.498.4485975880837087092...  <00000001.dcm>
# 15980  <1.2.826.0.1.3680043.8.498.4485975880837087092...  <00000001.dcm>
# 17034  <1.2.826.0.1.3680043.8.498.1236590481172644375...  <00000001.dcm>
# 17036  <1.2.826.0.1.3680043.8.498.1236590481172644375...  <00000001.dcm>
# 17039  <1.2.826.0.1.3680043.8.498.9164798039386315661...  <00000001.dcm>
# 17041  <1.2.826.0.1.3680043.8.498.9164798039386315661...  <00000001.dcm>
# 17402  <1.2.826.0.1.3680043.8.498.1854256192196409884...  <00000001.dcm>
# 17404  <1.2.826.0.1.3680043.8.498.1854256192196409884...  <00000001.dcm>
# 17416  <1.2.826.0.1.3680043.8.498.4635478522073089732...  <00000001.dcm>
# 17418  <1.2.826.0.1.3680043.8.498.4635478522073089732...  <00000001.dcm>
# 18464  <1.2.826.0.1.3680043.8.498.6239501108114770208...  <00000001.dcm>
# 18467  <1.2.826.0.1.3680043.8.498.6239501108114770208...  <00000001.dcm>
# 18469  <1.2.826.0.1.3680043.8.498.1010598209518804182...  <00000002.dcm>
# 18472  <1.2.826.0.1.3680043.8.498.1010598209518804182...  <00000002.dcm>
# 19907  <1.2.826.0.1.3680043.8.498.1218306711775335423...  <00000001.dcm>
# 19909  <1.2.826.0.1.3680043.8.498.1218306711775335423...  <00000001.dcm>
# 21313  <1.2.826.0.1.3680043.8.498.9481950413802648978...  <00000001.dcm>
# 21315  <1.2.826.0.1.3680043.8.498.9481950413802648978...  <00000001.dcm>
# 21513  <1.2.826.0.1.3680043.8.498.1069165051702191964...  <00000001.dcm>
# 21515  <1.2.826.0.1.3680043.8.498.1069165051702191964...  <00000001.dcm>
# 21519  <1.2.826.0.1.3680043.8.498.4207750629756036268...  <00000001.dcm>
# 21521  <1.2.826.0.1.3680043.8.498.4207750629756036268...  <00000001.dcm>
# 21523  <1.2.826.0.1.3680043.8.498.1069361818387426347...  <00000001.dcm>
# 21525  <1.2.826.0.1.3680043.8.498.1069361818387426347...  <00000001.dcm>
# 21527  <1.2.826.0.1.3680043.8.498.1078236053933878018...  <00000002.dcm>
# 21529  <1.2.826.0.1.3680043.8.498.1078236053933878018...  <00000002.dcm>
