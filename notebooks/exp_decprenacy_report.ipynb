# %%
import pandas as pd
from pprint import pprint

# %%
report_path = '/home/r079a/Desktop/de-identification/dataset/midi-validation-data/output_data/discrepancy_report_participant.csv'

# %%
report_df = pd.read_csv(report_path)

# %%
report_df
# Out:
#          index  check_passed  check_score         tag_ds  \
# 0        26434             0          0.0  <(0008,0068)>
# 1        26435             0          0.0  <(2050,0020)>
# 2        26459             0          0.0  <(0008,0068)>
# 3        26460             0          0.0  <(2050,0020)>
# 4        26668             0          0.0  <(0018,1030)>
# ...        ...           ...          ...            ...
# 16573  5711583             0          0.0  <(0018,1030)>
# 16574  5711714             0          0.5  <(0008,1030)>
# 16575  5711725             0          0.0  <(0018,1030)>
# 16576  5711856             0          0.5  <(0008,1030)>
# 16577  5711867             0          0.0  <(0018,1030)>
#
#                          tag_name         file_value  \
# 0      <Presentation Intent Type>                NaN
# 1        <Presentation LUT Shape>                NaN
# 2      <Presentation Intent Type>                NaN
# 3        <Presentation LUT Shape>                NaN
# 4                 <Protocol Name>              <for>
# ...                           ...                ...
# 16573             <Protocol Name>               <at>
# 16574         <Study Description>  <Abdomen^ (Adult>
# 16575             <Protocol Name>               <at>
# 16576         <Study Description>  <Abdomen^ (Adult>
# 16577             <Protocol Name>               <at>
#
#                                             answer_value           action  \
# 0                                                    NaN   <tag_retained>
# 1                                                    NaN   <tag_retained>
# 2                                                    NaN   <text_notnull>
# 3                                                    NaN   <text_notnull>
# 4                           <PRONE BREAST for 359554021>  <text_retained>
# ...                                                  ...              ...
# 16573                   <24ACRIN_Colo_IRB2415-04 at FGH>  <text_retained>
# 16574  <Abdomen^24ACRIN_Colo_IRB2415-04 (Adult) 20190...  <text_retained>
# 16575                   <24ACRIN_Colo_IRB2415-04 at FGH>  <text_retained>
# 16576  <Abdomen^24ACRIN_Colo_IRB2415-04 (Adult) 20190...  <text_retained>
# 16577                   <24ACRIN_Colo_IRB2415-04 at FGH>  <text_retained>
#
#                                      action_text category      subcategory  \
# 0                                            NaN    dicom      DICOM-IOD-1
# 1                                            NaN    dicom      DICOM-IOD-1
# 2                                            NaN    dicom      DICOM-IOD-1
# 3                                            NaN    dicom      DICOM-IOD-1
# 4                                 <PRONE BREAST>     tcia  TCIA-P15-DESC-C
# ...                                          ...      ...              ...
# 16573                  <24ACRIN_Colo_IRB2415-04>     tcia  TCIA-P15-DESC-C
# 16574  <Abdomen^24ACRIN_Colo_IRB2415-04 (Adult)>     tcia  TCIA-P15-DESC-C
# 16575                  <24ACRIN_Colo_IRB2415-04>     tcia  TCIA-P15-DESC-C
# 16576  <Abdomen^24ACRIN_Colo_IRB2415-04 (Adult)>     tcia  TCIA-P15-DESC-C
# 16577                  <24ACRIN_Colo_IRB2415-04>     tcia  TCIA-P15-DESC-C
#
#       modality                          class           patient  \
# 0         <DX>  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 1         <DX>  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 2         <DX>  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 3         <DX>  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 4         <PT>  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-004>
# ...        ...                            ...               ...
# 16573     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
# 16574     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
# 16575     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
# 16576     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
# 16577     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
#
#                                                    study  \
# 0      <1.2.826.0.1.3680043.8.498.1276397175806145025...
# 1      <1.2.826.0.1.3680043.8.498.1276397175806145025...
# 2      <1.2.826.0.1.3680043.8.498.1276397175806145025...
# 3      <1.2.826.0.1.3680043.8.498.1276397175806145025...
# 4      <1.2.826.0.1.3680043.8.498.5535254164756283863...
# ...                                                  ...
# 16573  <1.2.826.0.1.3680043.8.498.5615732608803205897...
# 16574  <1.2.826.0.1.3680043.8.498.5615732608803205897...
# 16575  <1.2.826.0.1.3680043.8.498.5615732608803205897...
# 16576  <1.2.826.0.1.3680043.8.498.5615732608803205897...
# 16577  <1.2.826.0.1.3680043.8.498.5615732608803205897...
#
#                                                   series  \
# 0      <1.2.826.0.1.3680043.8.498.9183734604385232042...
# 1      <1.2.826.0.1.3680043.8.498.9183734604385232042...
# 2      <1.2.826.0.1.3680043.8.498.9183734604385232042...
# 3      <1.2.826.0.1.3680043.8.498.9183734604385232042...
# 4      <1.2.826.0.1.3680043.8.498.9089704647697376038...
# ...                                                  ...
# 16573  <1.2.826.0.1.3680043.8.498.5116962447739610371...
# 16574  <1.2.826.0.1.3680043.8.498.5116962447739610371...
# 16575  <1.2.826.0.1.3680043.8.498.5116962447739610371...
# 16576  <1.2.826.0.1.3680043.8.498.5116962447739610371...
# 16577  <1.2.826.0.1.3680043.8.498.5116962447739610371...
#
#                                                 instance       file_name
# 0      <1.2.826.0.1.3680043.8.498.1018095246988930209...  <00000001.dcm>
# 1      <1.2.826.0.1.3680043.8.498.1018095246988930209...  <00000001.dcm>
# 2      <1.2.826.0.1.3680043.8.498.1018095246988930209...  <00000001.dcm>
# 3      <1.2.826.0.1.3680043.8.498.1018095246988930209...  <00000001.dcm>
# 4      <1.2.826.0.1.3680043.8.498.9888364222060322440...  <00000059.dcm>
# ...                                                  ...             ...
# 16573  <1.2.826.0.1.3680043.8.498.1018423416934899509...  <00000336.dcm>
# 16574  <1.2.826.0.1.3680043.8.498.1154788089217509987...  <00000322.dcm>
# 16575  <1.2.826.0.1.3680043.8.498.1154788089217509987...  <00000322.dcm>
# 16576  <1.2.826.0.1.3680043.8.498.5031711560719326183...  <00000444.dcm>
# 16577  <1.2.826.0.1.3680043.8.498.5031711560719326183...  <00000444.dcm>
#
# [16578 rows x 18 columns]

# %%
report_df['tag_name'].value_counts().head(50)
# Out:
# tag_name
# <[PET scan_description]>                       4900
# <Study Description>                            1720
# <Protocol Name>                                1612
# <Clinical Trial Sponsor Name>                  1578
# <Series Description>                           1367
# <Position Reference Indicator>                  878
# <KVP>                                           601
# <Acquisition Number>                            601
# <[PET batch_description]>                       547
# <Requested Procedure Comments>                  353
# <[Suite id]>                                    300
# <Additional Patient History>                    296
# <Derivation Description>                        214
# <Scheduled Procedure Step Description>          183
# <[PET scan_id]>                                 140
# <[PET exam_id]>                                 140
# <Performed Procedure Step Description>          125
# <Requested Procedure Description>                96
# <[PET wc_cal_id]>                                70
# <[PET frame_id]>                                 70
# <[PET for_identifier]>                           70
# <[PET norm_cal_id]>                              70
# <[PET normal_cal_id]>                            70
# <[PET normal_2d_cal_id]>                         70
# <[Actual series data time stamp]>                68
# <Scheduled Procedure Step ID>                    64
# <Presentation Intent Type>                       50
# <Presentation LUT Shape>                         50
# <Referenced SOP Class UID>                       45
# <[PET collimation]>                              35
# <[PET countrate_period]>                         35
# <Text Value>                                     27
# <[Series from which prescribed]>                 13
# <[Series from which Prescribed]>                 13
# <[Service id]>                                   13
# <Verifying Organization>                         10
# <Referenced Segment Number>                      10
# <Comments on Radiation Dose>                      8
# <Image Laterality>                                8
# <Detector Type>                                   6
# <Detector ID>                                     5
# <Series Number>                                   4
# <Image Comments>                                  4
# <Graphic Data>                                    4
# <Coding Scheme UID>                               4
# <Reason for the Requested Procedure>              2
# <Contrast/Bolus Agent>                            2
# <Acquisition Device Processing Description>       1
# <View Position>                                   1
# <Gantry ID>                                       1
# Name: count, dtype: int64

# %% [markdown]
# #### Priority List:
#
# * `<Clinical Trial Sponsor Name>`, // need to verify if it required in custom rules
# * `<Scheduled Procedure Step ID>`, // need to verify if it is required in custom rules
# * `<[Suite id]>` // Private tags needs to search with creators
# * `<Mapping Resource UID>` // Covered, added to custom rules
# * `<Code Value>` // Covered, by only checking element with Date(Time)? in its name
# * `<Requested Procedure Comments>` // MRI BREAST getting removed
# * `<KVP>` // not present in the original dataset
# * `<Acquisition Number> ` // not present in the original dataset
# * `<Referenced SOP Class UID>` // tag not present in the original dataset
# * `<Position Reference Indicator>` // tag not present in the original dataset
# * `<Presentation Intent Type>` // Tag not present in the original dataset
# * `<Presentation LUT Shape>` // Tag not present in the original dataset

# %%
report_df[(report_df['patient'] == '<Pseudo-PHI-002>') & (report_df['file_name'] == '<0000005.dcm>')]
# Out:
# Empty DataFrame
# Columns: [index, check_passed, check_score, tag_ds, tag_name, file_value, answer_value, action, action_text, category, subcategory, modality, class, patient, study, series, instance, file_name]
# Index: []

# %%
report_df[(report_df['tag_name'] == '<[PET scan_description]>')]['tag_ds'].unique()
# Out:
# array(['<(0009,"GEMS_PETD_01",0f)>'], dtype=object)
