# %%
import pandas as pd
from pprint import pprint

# %%
report_path = '/home/r079a/Desktop/de-identification/dataset/midi-validation-data/output_data_tcia_private_tags_06/discrepancy_report_participant.csv'

# %%
report_df = pd.read_csv(report_path)

# %%
report_df
# Out:
#          index  check_passed  check_score         tag_ds  \
# 0          168             0          0.0  <(0012,0051)>
# 1          363             0          0.0  <(0012,0051)>
# 2          558             0          0.0  <(0012,0051)>
# 3          753             0          0.0  <(0012,0051)>
# 4          948             0          0.0  <(0012,0051)>
# ...        ...           ...          ...            ...
# 26610  6172313             0          0.0  <(0012,0051)>
# 26611  6172527             0          0.0  <(0012,0051)>
# 26612  6172741             0          0.0  <(0012,0051)>
# 26613  6172955             0          0.0  <(0012,0051)>
# 26614  6173169             0          0.0  <(0012,0051)>
#
#                                       tag_name                    file_value  \
# 0      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 1      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 2      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 3      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 4      <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# ...                                        ...                           ...
# 26610  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 26611  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 26612  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 26613  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 26614  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
#
#                        answer_value          action  \
# 0      <Days offset from diagnosis>  <text_removed>
# 1      <Days offset from diagnosis>  <text_removed>
# 2      <Days offset from diagnosis>  <text_removed>
# 3      <Days offset from diagnosis>  <text_removed>
# 4      <Days offset from diagnosis>  <text_removed>
# ...                             ...             ...
# 26610  <Days offset from diagnosis>  <text_removed>
# 26611  <Days offset from diagnosis>  <text_removed>
# 26612  <Days offset from diagnosis>  <text_removed>
# 26613  <Days offset from diagnosis>  <text_removed>
# 26614  <Days offset from diagnosis>  <text_removed>
#
#                         action_text category      subcategory modality  \
# 0      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# 1      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# 2      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# 3      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# 4      <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <MR>
# ...                             ...      ...              ...      ...
# 26610  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 26611  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 26612  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 26613  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 26614  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
#
#                                class           patient  \
# 0        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# 1        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# 2        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# 3        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# 4        <1.2.840.10008.5.1.4.1.1.4>  <Pseudo-PHI-002>
# ...                              ...               ...
# 26610  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
# 26611  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
# 26612  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
# 26613  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
# 26614  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-216>
#
#                                                    study  \
# 0      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# 1      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# 2      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# 3      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# 4      <1.2.826.0.1.3680043.8.498.6957585337911014590...
# ...                                                  ...
# 26610  <1.2.826.0.1.3680043.8.498.1335144844187578048...
# 26611  <1.2.826.0.1.3680043.8.498.1335144844187578048...
# 26612  <1.2.826.0.1.3680043.8.498.1335144844187578048...
# 26613  <1.2.826.0.1.3680043.8.498.1335144844187578048...
# 26614  <1.2.826.0.1.3680043.8.498.1335144844187578048...
#
#                                                   series  \
# 0      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# 1      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# 2      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# 3      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# 4      <1.2.826.0.1.3680043.8.498.1066608227555053187...
# ...                                                  ...
# 26610  <1.2.826.0.1.3680043.8.498.7837430973606737012...
# 26611  <1.2.826.0.1.3680043.8.498.7837430973606737012...
# 26612  <1.2.826.0.1.3680043.8.498.7837430973606737012...
# 26613  <1.2.826.0.1.3680043.8.498.7837430973606737012...
# 26614  <1.2.826.0.1.3680043.8.498.7837430973606737012...
#
#                                                 instance       file_name
# 0      <1.2.826.0.1.3680043.8.498.9051348305064708278...  <00000047.dcm>
# 1      <1.2.826.0.1.3680043.8.498.4934817474968831648...  <00000053.dcm>
# 2      <1.2.826.0.1.3680043.8.498.2566888822188840988...  <00000084.dcm>
# 3      <1.2.826.0.1.3680043.8.498.1192406619679474748...  <00000090.dcm>
# 4      <1.2.826.0.1.3680043.8.498.2238372871777685852...  <00000091.dcm>
# ...                                                  ...             ...
# 26610  <1.2.826.0.1.3680043.8.498.1244558540776177145...  <00001148.dcm>
# 26611  <1.2.826.0.1.3680043.8.498.9605138307693723995...  <00000256.dcm>
# 26612  <1.2.826.0.1.3680043.8.498.9474358496365754257...  <00000530.dcm>
# 26613  <1.2.826.0.1.3680043.8.498.5401665236300063982...  <00000901.dcm>
# 26614  <1.2.826.0.1.3680043.8.498.9424628047897647490...  <00000915.dcm>
#
# [26615 rows x 18 columns]

# %%
report_df['tag_name'].value_counts().head(50)
# Out:
# tag_name
# <Clinical Trial Time Point Description>    17645
# <Study Description>                         1714
# <Protocol Name>                             1634
# <Series Description>                        1341
# <Position Reference Indicator>               878
# <KVP>                                        601
# <Acquisition Number>                         601
# <[PET batch_description]>                    547
# <Requested Procedure Comments>               353
# <Additional Patient History>                 280
# <Derivation Description>                     214
# <Scheduled Procedure Step Description>       177
# <Performed Procedure Step Description>       126
# <Requested Procedure Description>             98
# <[Actual series data time stamp]>             68
# <Presentation LUT Shape>                      50
# <Presentation Intent Type>                    50
# <Referenced SOP Class UID>                    45
# <[PET countrate_period]>                      35
# <[PET collimation]>                           35
# <Text Value>                                  27
# <Referenced Segment Number>                   10
# <Verifying Organization>                      10
# <Comments on Radiation Dose>                   8
# <Image Laterality>                             8
# <Detector Type>                                6
# <Detector ID>                                  5
# <Series Number>                                4
# <Image Comments>                               4
# <Graphic Data>                                 4
# <Coding Scheme UID>                            4
# <Reason for Study>                             3
# <Reason for the Requested Procedure>           2
# <Contrast/Bolus Agent>                         2
# <View Position>                                1
# <Gantry ID>                                    1
# Name: count, dtype: int64

# %% [markdown]
# #### Priority List:
#
# * `<[Actual series data time stamp]>` covered
# * `<Clinical Trial Sponsor Name>`, // need to verify if it required in custom rules
# * `<Scheduled Procedure Step ID>`, // need to verify if it is required in custom rules
# * `<[Suite id]>` // Private tags needs to search with creators
# * `<Mapping Resource UID>` // Covered, added to custom rules
# * `<Code Value>` // Covered, by only checking element with Date(Time)? in its name
# * `<Requested Procedure Comments>` // MRI BREAST getting removed
# * `<KVP>` // not present in the original dataset
# * `<Acquisition Number> ` // not present in the original dataset
# * `<Referenced SOP Class UID>` // tag not present in the original dataset
# * `<Position Reference Indicator>` // tag not present in the original dataset
# * `<Presentation Intent Type>` // Tag not present in the original dataset
# * `<Presentation LUT Shape>` // Tag not present in the original dataset

# %%
report_df[(report_df['patient'] == '<Pseudo-PHI-072>') & (report_df['file_name'] == '<00000039.dcm>')]
# Out:
#          index  check_passed  check_score                              tag_ds  \
# 9481   2705320             0          0.0                       <(0012,0051)>
# 9540   2716876             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9541   2716928             0          0.0                       <(0012,0051)>
# 10223  2853617             0          0.0                       <(0012,0051)>
# 11590  3147115             0          0.0                       <(0012,0051)>
# 11685  3164074             0          0.0                       <(0012,0051)>
# 12338  3301828             0          0.0                       <(0012,0051)>
#
#                                       tag_name                    file_value  \
# 9481   <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 9540                <Referenced SOP Class UID>                           NaN
# 9541   <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 10223  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 11590  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 11685  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
# 12338  <Clinical Trial Time Point Description>  <Days offset from diagnosis>
#
#                        answer_value           action  \
# 9481   <Days offset from diagnosis>   <text_removed>
# 9540      <1.2.840.10008.3.1.2.1.1>  <text_retained>
# 9541   <Days offset from diagnosis>   <text_removed>
# 10223  <Days offset from diagnosis>   <text_removed>
# 11590  <Days offset from diagnosis>   <text_removed>
# 11685  <Days offset from diagnosis>   <text_removed>
# 12338  <Days offset from diagnosis>   <text_removed>
#
#                         action_text category      subcategory modality  \
# 9481   <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 9540      <1.2.840.10008.3.1.2.1.1>     tcia         TCIA-REV     <CT>
# 9541   <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <CT>
# 10223  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 11590  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <CT>
# 11685  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
# 12338  <Days offset from diagnosis>     tcia  TCIA-P15-DESC-C     <PT>
#
#                                class           patient  \
# 9481   <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-072>
# 9540     <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9541     <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 10223  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-072>
# 11590    <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 11685  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-072>
# 12338  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-072>
#
#                                                    study  \
# 9481   <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9540   <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9541   <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 10223  <1.2.826.0.1.3680043.8.498.1035286656777553556...
# 11590  <1.2.826.0.1.3680043.8.498.1035286656777553556...
# 11685  <1.2.826.0.1.3680043.8.498.1035286656777553556...
# 12338  <1.2.826.0.1.3680043.8.498.1035286656777553556...
#
#                                                   series  \
# 9481   <1.2.826.0.1.3680043.8.498.2607096036577912922...
# 9540   <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9541   <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 10223  <1.2.826.0.1.3680043.8.498.2337386939003278571...
# 11590  <1.2.826.0.1.3680043.8.498.1339795140677350800...
# 11685  <1.2.826.0.1.3680043.8.498.1183086077750344933...
# 12338  <1.2.826.0.1.3680043.8.498.5978556547525274096...
#
#                                                 instance       file_name
# 9481   <1.2.826.0.1.3680043.8.498.1224926337485183924...  <00000039.dcm>
# 9540   <1.2.826.0.1.3680043.8.498.1202193422666953895...  <00000039.dcm>
# 9541   <1.2.826.0.1.3680043.8.498.1202193422666953895...  <00000039.dcm>
# 10223  <1.2.826.0.1.3680043.8.498.6575262393286489558...  <00000039.dcm>
# 11590  <1.2.826.0.1.3680043.8.498.1322205287929427615...  <00000039.dcm>
# 11685  <1.2.826.0.1.3680043.8.498.2599645945689590112...  <00000039.dcm>
# 12338  <1.2.826.0.1.3680043.8.498.1105204494421933118...  <00000039.dcm>

# %%
report_df[(report_df['tag_name'] == '<Referenced SOP Class UID>')]
# Out:
#         index  check_passed  check_score                              tag_ds  \
# 9465  2703514             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9467  2703652             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9469  2703790             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9471  2703928             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9473  2704066             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9475  2704204             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9532  2716328             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9534  2716465             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9536  2716602             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9538  2716739             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9540  2716876             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9542  2717014             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9544  2717151             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9546  2717288             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9548  2717425             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9550  2717562             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9552  2717700             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9554  2717837             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9556  2717975             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9558  2718113             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9560  2718250             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9562  2718385             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9564  2718523             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9566  2718659             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9568  2718795             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9570  2718933             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9572  2719071             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9574  2719209             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9576  2719347             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9578  2719485             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9580  2719623             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9582  2719761             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9584  2719899             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9586  2720037             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9588  2720175             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9590  2720313             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9592  2720451             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9594  2720589             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9596  2720726             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9598  2720863             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9600  2721001             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9602  2721139             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9604  2721277             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9606  2721415             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
# 9608  2721553             0          0.0  <(0008,1120)>[<0000>]<(0008,1150)>
#
#                         tag_name file_value               answer_value  \
# 9465  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9467  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9469  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9471  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9473  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9475  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9532  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9534  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9536  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9538  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9540  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9542  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9544  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9546  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9548  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9550  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9552  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9554  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9556  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9558  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9560  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9562  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9564  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9566  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9568  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9570  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9572  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9574  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9576  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9578  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9580  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9582  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9584  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9586  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9588  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9590  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9592  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9594  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9596  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9598  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9600  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9602  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9604  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9606  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
# 9608  <Referenced SOP Class UID>        NaN  <1.2.840.10008.3.1.2.1.1>
#
#                action                action_text category subcategory  \
# 9465  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9467  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9469  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9471  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9473  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9475  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9532  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9534  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9536  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9538  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9540  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9542  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9544  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9546  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9548  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9550  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9552  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9554  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9556  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9558  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9560  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9562  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9564  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9566  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9568  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9570  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9572  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9574  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9576  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9578  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9580  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9582  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9584  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9586  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9588  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9590  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9592  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9594  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9596  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9598  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9600  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9602  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9604  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9606  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
# 9608  <text_retained>  <1.2.840.10008.3.1.2.1.1>     tcia    TCIA-REV
#
#      modality                        class           patient  \
# 9465     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9467     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9469     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9471     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9473     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9475     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9532     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9534     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9536     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9538     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9540     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9542     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9544     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9546     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9548     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9550     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9552     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9554     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9556     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9558     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9560     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9562     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9564     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9566     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9568     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9570     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9572     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9574     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9576     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9578     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9580     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9582     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9584     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9586     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9588     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9590     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9592     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9594     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9596     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9598     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9600     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9602     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9604     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9606     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
# 9608     <CT>  <1.2.840.10008.5.1.4.1.1.7>  <Pseudo-PHI-072>
#
#                                                   study  \
# 9465  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9467  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9469  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9471  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9473  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9475  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9532  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9534  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9536  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9538  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9540  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9542  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9544  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9546  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9548  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9550  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9552  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9554  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9556  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9558  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9560  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9562  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9564  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9566  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9568  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9570  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9572  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9574  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9576  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9578  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9580  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9582  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9584  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9586  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9588  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9590  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9592  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9594  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9596  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9598  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9600  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9602  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9604  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9606  <1.2.826.0.1.3680043.8.498.3211851894263245190...
# 9608  <1.2.826.0.1.3680043.8.498.3211851894263245190...
#
#                                                  series  \
# 9465  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9467  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9469  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9471  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9473  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9475  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9532  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9534  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9536  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9538  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9540  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9542  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9544  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9546  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9548  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9550  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9552  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9554  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9556  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9558  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9560  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9562  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9564  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9566  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9568  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9570  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9572  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9574  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9576  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9578  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9580  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9582  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9584  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9586  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9588  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9590  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9592  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9594  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9596  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9598  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9600  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9602  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9604  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9606  <1.2.826.0.1.3680043.8.498.6630907885119881637...
# 9608  <1.2.826.0.1.3680043.8.498.6630907885119881637...
#
#                                                instance       file_name
# 9465  <1.2.826.0.1.3680043.8.498.5529377235147783924...  <00000044.dcm>
# 9467  <1.2.826.0.1.3680043.8.498.3670306604611253203...  <00000045.dcm>
# 9469  <1.2.826.0.1.3680043.8.498.7962985030971583685...  <00000042.dcm>
# 9471  <1.2.826.0.1.3680043.8.498.7046944286375352631...  <00000043.dcm>
# 9473  <1.2.826.0.1.3680043.8.498.8110772866193287960...  <00000041.dcm>
# 9475  <1.2.826.0.1.3680043.8.498.7676534035539644248...  <00000040.dcm>
# 9532  <1.2.826.0.1.3680043.8.498.6810319344202872562...  <00000012.dcm>
# 9534  <1.2.826.0.1.3680043.8.498.9433048790415188128...  <00000006.dcm>
# 9536  <1.2.826.0.1.3680043.8.498.2484339763727568316...  <00000007.dcm>
