# %%
import pandas as pd
from pprint import pprint

# %%
report_path = '/home/r079a/Desktop/de-identification/dataset/midi-validation-data/output_data/discrepancy_report_participant.csv'

# %%
report_df = pd.read_csv(report_path)

# %%
report_df
# Out:
#          index  check_passed  check_score                              tag_ds  \
# 0          290             0          0.0  <(0008,1140)>[<0000>]<(0008,1155)>
# 1          291             0          0.0  <(0008,1140)>[<0001>]<(0008,1155)>
# 2          292             0          0.0  <(0008,1140)>[<0002>]<(0008,1155)>
# 3          485             0          0.0  <(0008,1140)>[<0000>]<(0008,1155)>
# 4          486             0          0.0  <(0008,1140)>[<0001>]<(0008,1155)>
# ...        ...           ...          ...                                 ...
# 34230  6172772             0          0.0  <(0008,1111)>[<0000>]<(0008,1155)>
# 34231  6172981             0          0.0  <(0008,1110)>[<0000>]<(0008,1155)>
# 34232  6172982             0          0.0  <(0008,1111)>[<0000>]<(0008,1155)>
# 34233  6173191             0          0.0  <(0008,1110)>[<0000>]<(0008,1155)>
# 34234  6173192             0          0.0  <(0008,1111)>[<0000>]<(0008,1155)>
#
# ...

# %%
report_df['tag_name'].value_counts().head(30)
# Out:
# tag_name
# <Referenced SOP Instance UID>                    13716
# <[PET scan_description]>                          4900
# <Context Group Version>                           1892
# <Study Description>                               1714
# <Protocol Name>                                   1612
# <Clinical Trial Sponsor Name>                     1578
# <Series Description>                              1367
# <Position Reference Indicator>                     878
# <KVP>                                              601
# <Acquisition Number>                               601
# <[PET batch_description]>                          547
# <Requested Procedure Comments>                     353
# <[Suite id]>                                       300
# <Additional Patient History>                       296
# <Derivation Description>                           214
# <Scheduled Procedure Step Description>             176
# <Radiopharmaceutical Start DateTime>               166
# ...

# %%
report_df[(report_df['patient'] == '<Pseudo-PHI-002>') & (report_df['file_name'] == '<0000005.dcm>')]
# Out:
# Empty DataFrame
# Columns: [index, check_passed, check_score, tag_ds, tag_name, file_value, answer_value, action, action_text, category, subcategory, modality, class, patient, study, series, instance, file_name]
# Index: []

# %%
report_df[(report_df['tag_name'] == '<Context Group Version>')]
# Out:
#          index  check_passed  check_score  \
# 14542  3628082             0          0.0
# 14543  3628083             0          0.0
# 14544  3628084             0          0.0
# 14545  3628085             0          0.0
# 14546  3628281             0          0.0
# ...        ...           ...          ...
# 25046  5060146             0          0.0
# 25047  5060340             0          0.0
# 25048  5060341             0          0.0
# 25049  5060342             0          0.0
# 25050  5060343             0          0.0
#
#                                                   tag_ds  \
# 14542  <(0054,0016)>[<0000>]<(0054,0300)>[<0000>]<(00...
# 14543                 <(0054,0410)>[<0000>]<(0008,0106)>
# 14544  <(0054,0410)>[<0000>]<(0054,0412)>[<0000>]<(00...
# 14545                 <(0054,0414)>[<0000>]<(0008,0106)>
# 14546  <(0054,0016)>[<0000>]<(0054,0300)>[<0000>]<(00...
# ...                                                  ...
# ...
