# %%
import pandas as pd
from pprint import pprint

# %%
report_path = '/home/r079a/Desktop/de-identification/dataset/midi-validation-data/output_data/discrepancy_report_participant.csv'

# %%
report_df = pd.read_csv(report_path)

# %%
report_df
# Out:
#          index  check_passed  check_score         tag_ds  \
# 0        26434             0          0.0  <(0008,0068)>
# 1        26435             0          0.0  <(2050,0020)>
# 2        26459             0          0.0  <(0008,0068)>
# 3        26460             0          0.0  <(2050,0020)>
# 4        26668             0          0.0  <(0018,1030)>
# ...        ...           ...          ...            ...
# 20546  5722276             0          0.0  <(0018,1030)>
# 20547  5722407             0          0.5  <(0008,1030)>
# 20548  5722418             0          0.0  <(0018,1030)>
# 20549  5722549             0          0.5  <(0008,1030)>
# 20550  5722560             0          0.0  <(0018,1030)>
#
#                          tag_name         file_value  \
# 0      <Presentation Intent Type>                NaN
# 1        <Presentation LUT Shape>                NaN
# 2      <Presentation Intent Type>                NaN
# 3        <Presentation LUT Shape>                NaN
# 4                 <Protocol Name>              <for>
# ...                           ...                ...
# 20546             <Protocol Name>               <at>
# 20547         <Study Description>  <Abdomen^ (Adult>
# 20548             <Protocol Name>               <at>
# 20549         <Study Description>  <Abdomen^ (Adult>
# 20550             <Protocol Name>               <at>
#
#                                             answer_value           action  \
# 0                                                    NaN   <tag_retained>
# 1                                                    NaN   <tag_retained>
# 2                                                    NaN   <text_notnull>
# 3                                                    NaN   <text_notnull>
# 4                           <PRONE BREAST for 359554021>  <text_retained>
# ...                                                  ...              ...
# 20546                   <24ACRIN_Colo_IRB2415-04 at FGH>  <text_retained>
# 20547  <Abdomen^24ACRIN_Colo_IRB2415-04 (Adult) 20190...  <text_retained>
# 20548                   <24ACRIN_Colo_IRB2415-04 at FGH>  <text_retained>
# 20549  <Abdomen^24ACRIN_Colo_IRB2415-04 (Adult) 20190...  <text_retained>
# 20550                   <24ACRIN_Colo_IRB2415-04 at FGH>  <text_retained>
#
#                                      action_text category      subcategory  \
# 0                                            NaN    dicom      DICOM-IOD-1
# 1                                            NaN    dicom      DICOM-IOD-1
# 2                                            NaN    dicom      DICOM-IOD-1
# 3                                            NaN    dicom      DICOM-IOD-1
# 4                                 <PRONE BREAST>     tcia  TCIA-P15-DESC-C
# ...                                          ...      ...              ...
# 20546                  <24ACRIN_Colo_IRB2415-04>     tcia  TCIA-P15-DESC-C
# 20547  <Abdomen^24ACRIN_Colo_IRB2415-04 (Adult)>     tcia  TCIA-P15-DESC-C
# 20548                  <24ACRIN_Colo_IRB2415-04>     tcia  TCIA-P15-DESC-C
# 20549  <Abdomen^24ACRIN_Colo_IRB2415-04 (Adult)>     tcia  TCIA-P15-DESC-C
# 20550                  <24ACRIN_Colo_IRB2415-04>     tcia  TCIA-P15-DESC-C
#
#       modality                          class           patient  \
# 0         <DX>  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 1         <DX>  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 2         <DX>  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 3         <DX>  <1.2.840.10008.5.1.4.1.1.1.1>  <Pseudo-PHI-003>
# 4         <PT>  <1.2.840.10008.5.1.4.1.1.128>  <Pseudo-PHI-004>
# ...        ...                            ...               ...
# 20546     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
# 20547     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
# 20548     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
# 20549     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
# 20550     <CT>    <1.2.840.10008.5.1.4.1.1.2>  <Pseudo-PHI-213>
#
#                                                    study  \
# 0      <1.2.826.0.1.3680043.8.498.1059318622575357121...
# 1      <1.2.826.0.1.3680043.8.498.1059318622575357121...
# 2      <1.2.826.0.1.3680043.8.498.1059318622575357121...
# 3      <1.2.826.0.1.3680043.8.498.1059318622575357121...
# 4      <1.2.826.0.1.3680043.8.498.5516370690941788085...
# ...                                                  ...
# 20546  <1.2.826.0.1.3680043.8.498.4065986276770522689...
# 20547  <1.2.826.0.1.3680043.8.498.4065986276770522689...
# 20548  <1.2.826.0.1.3680043.8.498.4065986276770522689...
# 20549  <1.2.826.0.1.3680043.8.498.4065986276770522689...
# 20550  <1.2.826.0.1.3680043.8.498.4065986276770522689...
#
#                                                   series  \
# 0      <1.2.826.0.1.3680043.8.498.3057566981264051958...
# 1      <1.2.826.0.1.3680043.8.498.3057566981264051958...
# 2      <1.2.826.0.1.3680043.8.498.3057566981264051958...
# 3      <1.2.826.0.1.3680043.8.498.3057566981264051958...
# 4      <1.2.826.0.1.3680043.8.498.5852303600872012898...
# ...                                                  ...
# 20546  <1.2.826.0.1.3680043.8.498.2855402118746072476...
# 20547  <1.2.826.0.1.3680043.8.498.2855402118746072476...
# 20548  <1.2.826.0.1.3680043.8.498.2855402118746072476...
# 20549  <1.2.826.0.1.3680043.8.498.2855402118746072476...
# 20550  <1.2.826.0.1.3680043.8.498.2855402118746072476...
#
#                                                 instance       file_name
# 0      <1.2.826.0.1.3680043.8.498.9699606243108259629...  <00000001.dcm>
# 1      <1.2.826.0.1.3680043.8.498.9699606243108259629...  <00000001.dcm>
# 2      <1.2.826.0.1.3680043.8.498.9699606243108259629...  <00000001.dcm>
# 3      <1.2.826.0.1.3680043.8.498.9699606243108259629...  <00000001.dcm>
# 4      <1.2.826.0.1.3680043.8.498.8623252570975797810...  <00000059.dcm>
# ...                                                  ...             ...
# 20546  <1.2.826.0.1.3680043.8.498.6729399455443097258...  <00000336.dcm>
# 20547  <1.2.826.0.1.3680043.8.498.4340968638621213073...  <00000322.dcm>
# 20548  <1.2.826.0.1.3680043.8.498.4340968638621213073...  <00000322.dcm>
# 20549  <1.2.826.0.1.3680043.8.498.9237109226173965955...  <00000444.dcm>
# 20550  <1.2.826.0.1.3680043.8.498.9237109226173965955...  <00000444.dcm>
#
# [20551 rows x 18 columns]

# %%
report_df['tag_name'].value_counts().head(50)
# Out:
# tag_name
# <[PET scan_description]>                       4900
# <Code Value>                                   3972
# <Study Description>                            1720
# <Protocol Name>                                1612
# <Clinical Trial Sponsor Name>                  1578
# <Series Description>                           1367
# <Position Reference Indicator>                  878
# <KVP>                                           601
# <Acquisition Number>                            601
# <[PET batch_description]>                       547
# <Requested Procedure Comments>                  353
# <[Suite id]>                                    300
# <Additional Patient History>                    296
# <Derivation Description>                        214
# <Scheduled Procedure Step Description>          183
# <[PET scan_id]>                                 140
# <[PET exam_id]>                                 140
# <Performed Procedure Step Description>          125
# <Requested Procedure Description>                96
# <[PET norm_cal_id]>                              70
# <[PET frame_id]>                                 70
# <[PET wc_cal_id]>                                70
# <[PET for_identifier]>                           70
# <[PET normal_2d_cal_id]>                         70
# <[PET normal_cal_id]>                            70
# <[Actual series data time stamp]>                68
# <Presentation Intent Type>                       50
# <Presentation LUT Shape>                         50
# <Scheduled Procedure Step ID>                    45
# <Referenced SOP Class UID>                       45
# <[PET collimation]>                              35
# <[PET countrate_period]>                         35
# <Text Value>                                     27
# <Mapping Resource UID>                           20
# <[Series from which prescribed]>                 13
# <[Series from which Prescribed]>                 13
# <[Service id]>                                   13
# <Verifying Organization>                         10
# <Referenced Segment Number>                      10
# <Comments on Radiation Dose>                      8
# <Image Laterality>                                8
# <Detector Type>                                   6
# <Detector ID>                                     5
# <Series Number>                                   4
# <Image Comments>                                  4
# <Graphic Data>                                    4
# <Coding Scheme UID>                               4
# <Reason for the Requested Procedure>              2
# <Contrast/Bolus Agent>                            2
# <Acquisition Device Processing Description>       1
# Name: count, dtype: int64

# %% [markdown]
# #### Priority List:
#
# * `<Clinical Trial Sponsor Name>`, // need to verify if it required in custom rules
# * `<Scheduled Procedure Step ID>`, // need to verify if it is required in custom rules
# * `<[Suite id]>` // Private tags needs to search with creators
# * `<Mapping Resource UID>` // Covered, added to custom rules
# * `<Code Value>` // Covered, by only checking element with Date(Time)? in its name
# * `<Requested Procedure Comments>` // MRI BREAST getting removed
# * `<KVP>` // not present in the original dataset
# * `<Acquisition Number> ` // not present in the original dataset
# * `<Referenced SOP Class UID>` // tag not present in the original dataset
# * `<Position Reference Indicator>` // tag not present in the original dataset
# * `<Presentation Intent Type>` // Tag not present in the original dataset
# * `<Presentation LUT Shape>` // Tag not present in the original dataset

# %%
report_df[(report_df['patient'] == '<Pseudo-PHI-002>') & (report_df['file_name'] == '<0000005.dcm>')]
# Out:
# Empty DataFrame
# Columns: [index, check_passed, check_score, tag_ds, tag_name, file_value, answer_value, action, action_text, category, subcategory, modality, class, patient, study, series, instance, file_name]
# Index: []

# %%
report_df[(report_df['tag_name'] == '<[PET scan_description]>')]
# Out:
#          index  check_passed  check_score                      tag_ds  \
# 3890   1126018             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# 3891   1126363             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# 3892   1126707             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# 3893   1127051             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# 3894   1127396             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# ...        ...           ...          ...                         ...
# 13989  4574261             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# 13990  4574610             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# 13991  4574960             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# 13992  4575309             0          0.0  <(0009,"GEMS_PETD_01",0f)>
# 13993  4575658             0          0.0  <(0009,"GEMS_PETD_01",0f)>
#
#                        tag_name file_value                   answer_value  \
# 3890   <[PET scan_description]>        NaN                   <2D FLT DYN>
# 3891   <[PET scan_description]>        NaN                   <2D FLT DYN>
# 3892   <[PET scan_description]>        NaN                   <2D FLT DYN>
# 3893   <[PET scan_description]>        NaN                   <2D FLT DYN>
# 3894   <[PET scan_description]>        NaN                   <2D FLT DYN>
# ...                         ...        ...                            ...
# 13989  <[PET scan_description]>        NaN  <PET CT INFERIOR TO SUPERIOR>
# 13990  <[PET scan_description]>        NaN  <PET CT INFERIOR TO SUPERIOR>
# 13991  <[PET scan_description]>        NaN  <PET CT INFERIOR TO SUPERIOR>
# 13992  <[PET scan_description]>        NaN  <PET CT INFERIOR TO SUPERIOR>
# 13993  <[PET scan_description]>        NaN  <PET CT INFERIOR TO SUPERIOR>
#
#                 action                    action_text category  subcategory  \
# 3890   <text_retained>                   <2D FLT DYN>     tcia  TCIA-PTKB-K
# 3891   <text_retained>                   <2D FLT DYN>     tcia  TCIA-PTKB-K
# 3892   <text_retained>                   <2D FLT DYN>     tcia  TCIA-PTKB-K
# 3893   <text_retained>                   <2D FLT DYN>     tcia  TCIA-PTKB-K
